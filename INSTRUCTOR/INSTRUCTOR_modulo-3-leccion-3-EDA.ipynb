# %%
# importando librerias
import pandas as pd

pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %% [markdown]
# # ENTENDER LOS DATOS!

# %%
# Primeros para entender los datos, vamos a traer los datos....puede ser titanic!

df = pd.read_csv("titanic.csv")

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df.tail(2)
# Out:
#      PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 889          890         1       1  Behr, Mr. Karl Howell  male  26.0      0
# 890          891         0       3    Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket   Fare Cabin Embarked
# 889      0  111369  30.00  C148        C
# 890      0  370376   7.75   NaN        Q

# %%
df.shape
# Out:
# (891, 12)

# %%
df.sample(4)
# Out:
#      PassengerId  Survived  Pclass  \
# 617          618         0       3
# 621          622         1       1
# 465          466         0       3
# 21            22         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 617  Lobb, Mrs. William Arthur (Cordelia K Stanlick)  female  26.0      1
# 621                     Kimball, Mr. Edwin Nelson Jr    male  42.0      1
# 465                  Goncalves, Mr. Manuel Estanslas    male  38.0      0
# 21                             Beesley, Mr. Lawrence    male  34.0      0
#
#      Parch              Ticket     Fare Cabin Embarked
# 617      0           A/5. 3336  16.1000   NaN        S
# 621      0               11753  52.5542   D19        S
# 465      0  SOTON/O.Q. 3101306   7.0500   NaN        S
# 21       0              248698  13.0000   D56        S

# %%
ejemplo = df.sample(4)
ejemplo
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 415          416         0       3  Meek, Mrs. Thomas (Annie Louise Rowley)
# 468          469         0       3                       Scanlan, Mr. James
# 480          481         0       3           Goodwin, Master. Harold Victor
# 616          617         0       3                Danbom, Mr. Ernst Gilbert
#
#         Sex   Age  SibSp  Parch   Ticket    Fare Cabin Embarked
# 415  female   NaN      0      0   343095   8.050   NaN        S
# 468    male   NaN      0      0    36209   7.725   NaN        Q
# 480    male   9.0      5      2  CA 2144  46.900   NaN        S
# 616    male  34.0      1      1   347080  14.400   NaN        S

# %%
ejemplo
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 415          416         0       3  Meek, Mrs. Thomas (Annie Louise Rowley)
# 468          469         0       3                       Scanlan, Mr. James
# 480          481         0       3           Goodwin, Master. Harold Victor
# 616          617         0       3                Danbom, Mr. Ernst Gilbert
#
#         Sex   Age  SibSp  Parch   Ticket    Fare Cabin Embarked
# 415  female   NaN      0      0   343095   8.050   NaN        S
# 468    male   NaN      0      0    36209   7.725   NaN        Q
# 480    male   9.0      5      2  CA 2144  46.900   NaN        S
# 616    male  34.0      1      1   347080  14.400   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
mis_columnas  = df.columns

# %%
mis_columnas
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# ese metodo es................??????????????????

df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe(include="object") # QUIERO MIS VALORES NO NUMERICOS PROMO HEDY!!!!!
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df.describe().T
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
# me gustaria hacer analisis mas precisos de cada columna ... "Embarked"

df["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
# quiero contar esos valores unicos...

df["Embarked"].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# quiero ver nulos en una columna en particular....en este caso "Age"

df["Age"].isnull().sum()
# Out:
# 177

# %%
df["Age"].isnull().sum()
# Out:
# 177

# %%
# quiero ver NO nulos en una columna en particular....en este caso "Age"

df["Age"].notnull().sum()
# Out:
# 714

# %%
# quiero ver duplicados a nivel dataframe....me refiero a todas las filas

df.duplicated().sum()
# Out:
# 0

# %%
# quiero ver duplicados a nivel columna.... "Embarked"

df.duplicated(subset="Embarked").sum()
# Out:
# 887

# %%
# eliminando columnas!!! spoilert de ayer!!!

df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# como eliminamos las columas Pclass y SibSp????

df_nuevo = df.drop(["Pclass","SibSp"],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[56], line 3
#       1 # como eliminamos las columas Pclass y SibSp????
# ----> 3 df_nuevo = df.drop(["Pclass","SibSp"],axis=1,inplace=True)
#
# File c:\Users\Ignacio\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Users\Ignacio\anaconda3\lib\site-packages\pandas\core\frame.py:4906, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4774 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4775 def drop(
# ...

# %%
df
# Out:
#      PassengerId  Survived                                               Name  \
# 0              1         0                            Braund, Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         1                             Heikkinen, Miss. Laina
# 3              4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5         0                           Allen, Mr. William Henry
# ..           ...       ...                                                ...
# 886          887         0                              Montvila, Rev. Juozas
# 887          888         1                       Graham, Miss. Margaret Edith
# 888          889         0           Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1                              Behr, Mr. Karl Howell
# 890          891         0                                Dooley, Mr. Patrick
#
# ...

# %% [markdown]
# <h1>Tabla de Contenidos<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#¿Qué-es-el-Web-Scrapping?" data-toc-modified-id="¿Qué-es-el-Web-Scrapping?-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>¿Qué es el <strong>Web Scrapping</strong>?</a></span></li><li><span><a href="#¿Qué-es-HTML?" data-toc-modified-id="¿Qué-es-HTML?-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>¿Qué es HTML?</a></span></li><li><span><a href="#¿Qué-es-Beautiful-Soup?" data-toc-modified-id="¿Qué-es-Beautiful-Soup?-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>¿Qué es <em>Beautiful Soup</em>?</a></span></li><li><span><a href="#Métodos-importantes-de-Beautiful-Soup" data-toc-modified-id="Métodos-importantes-de-Beautiful-Soup-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Métodos importantes de <em>Beautiful Soup</em></a></span></li><li><span><a href="#Datos-de-moviles-de-Ebay" data-toc-modified-id="Datos-de-moviles-de-Ebay-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Datos de moviles de Ebay</a></span><ul class="toc-item"><li><span><a href="#Pandas" data-toc-modified-id="Pandas-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Pandas</a></span></li></ul></li><li><span><a href="#Sacando-datos-de-una-tabla" data-toc-modified-id="Sacando-datos-de-una-tabla-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Sacando datos de una tabla</a></span></li><li><span><a href="#Resumen-de-los-métodos-aprendidos-de-Pandas" data-toc-modified-id="Resumen-de-los-métodos-aprendidos-de-Pandas-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Resumen de los métodos aprendidos de Pandas</a></span></li><li><span><a href="#Ejercicios" data-toc-modified-id="Ejercicios-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Ejercicios</a></span></li></ul></div>

# %% [markdown]
# # ¿Qué es el **Web Scrapping**?
#
# El *web scraping* es una técnica utilizada para extraer información de sitios web de forma automática. Consiste en escribir un programa o utilizar herramientas para recorrer y analizar el código HTML o XML de una página web, y luego extraer los datos relevantes de manera estructurada.
#
# El objetivo del *web scraping* es obtener datos específicos de una página web de manera eficiente y automatizada, en lugar de realizar la extracción manualmente. Esta técnica puede ser utilizada para diversas finalidades, como recopilar datos para análisis, realizar comparaciones de precios, monitorizar contenido, obtener información de noticias, entre otras aplicaciones.
#
# Existen varias bibliotecas en Python que son ampliamente utilizadas para realizar *web scraping*. Algunas de las bibliotecas más populares y útiles son:
#
# 1. **Beautiful Soup**: Es una biblioteca muy utilizada para el análisis y extracción de datos de páginas web. Proporciona una interfaz fácil de usar para analizar y manipular el HTML y XML de una página web. Beautiful Soup permite buscar elementos utilizando etiquetas, atributos y contenido, lo que facilita la extracción de datos específicos.
#
# 2. **Selenium**: Es una biblioteca que se utiliza para automatizar el navegador web. Selenium es útil cuando el contenido que se desea extraer está generado dinámicamente a través de JavaScript u otras interacciones del lado del cliente. Proporciona funciones para interactuar con elementos de la página, hacer clic en botones, enviar formularios y más.
#
# 3. **Scrapy**: Es un framework de scraping web de alto nivel que ofrece una arquitectura completa y flexible para realizar tareas de web scraping de manera eficiente. Scrapy facilita la extracción de datos estructurados a gran escala y ofrece funcionalidades avanzadas como gestión de sesiones, almacenamiento de datos, manejo de errores y más.
#
# 4. **lxml**: Es una biblioteca de procesamiento de XML y HTML en Python. Proporciona una interfaz rápida y eficiente para analizar y extraer datos de documentos XML/HTML utilizando XPath y selectores CSS.
#
# 5. **PyQuery**: Es una biblioteca inspirada en jQuery que permite utilizar expresiones jQuery para analizar y manipular documentos HTML/XML. PyQuery es útil para seleccionar y extraer elementos específicos de una página web de manera similar a como se haría con jQuery en JavaScript.
#
#
# Estas son solo algunas de las bibliotecas más populares para realizar **web scraping** en Python. Cada una tiene sus propias fortalezas y características, y la elección de la biblioteca dependerá de los requisitos y la complejidad de la tarea de *scraping*. En las próximas lecciones nos centraremos en dos de las librerías más utilizadas para extraer datos de una página web, las cuales son **Beautiful Soup** y **Selenium**.
#
# [Video de la lección de hoy](https://www.youtube.com/watch?v=LcaKKRXYX2U&list=PLhQe2VhfFLJ2pWfdeaAuX0pfhzokrEpuV&index=5)

# %% [markdown]
# # ¿Qué es HTML?
#
# **HTML**, siglas de *Hypertext Markup Language* (Lenguaje de Marcado de Hipertexto), es utilizado para crear páginas web. Se utiliza para estructurar y presentar el contenido de una página web, como texto, imágenes, enlaces, formularios y otros elementos interactivos.
#
# El HTML se basa en una estructura jerárquica de etiquetas, también conocidas como elementos, que definen la estructura y el significado del contenido en una página web. Cada etiqueta tiene un propósito específico y se coloca dentro del código HTML para darle formato y proporcionar información adicional sobre los elementos de la página.
#
# Aquí hay un ejemplo básico de código HTML:
#
# ```html
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Título de la página</title>
# </head>
# <body>
#     <h1>Título principal</h1>
#     <p>Este es un párrafo de ejemplo.</p>
#     <a href="https://www.ejemplo.com">Enlace a Ejemplo.com</a>
#     <img src="imagen.jpg" alt="Descripción de la imagen">
# </body>
# </html>
# ```
#
# En este ejemplo, puedes ver algunas etiquetas HTML comunes:
#
# - `<!DOCTYPE html>`: Declara que el documento es un archivo HTML.
# - `<html>`: Es el elemento raíz que envuelve todo el contenido de la página.
# - `<head>`: Contiene información meta y enlaces a archivos externos, como hojas de estilo CSS o scripts JavaScript.
# - `<title>`: Define el título de la página, que se muestra en la pestaña del navegador.
# - `<body>`: Contiene el contenido visible de la página web.
# - `<h1>`: Define un encabezado de nivel 1.
# - `<p>`: Define un párrafo de texto.
# - `<a>`: Define un enlace a otra página web.
# - `<img>`: Inserta una imagen en la página web.
#
# El HTML es la base fundamental para crear páginas web y entender su estructura es importante para analizar y extraer datos de sitios web durante el proceso de análisis de datos.

# %% [markdown]
# # ¿Qué es *Beautiful Soup*?
#
# *Beautiful Soup* es una biblioteca de Python diseñada para facilitar el análisis y la extracción de datos de archivos HTML y XML. Proporciona una interfaz sencilla y legible que simplifica el proceso de navegación y manipulación de la estructura de estos documentos.
#
# Algunas características y ventajas de *Beautiful Soup*:
#
# 1. **Análisis de documentos HTML/XML**: Beautiful Soup facilita la tarea de analizar documentos HTML/XML y extraer datos específicos de manera eficiente. Proporciona métodos y funciones que permiten acceder a elementos, atributos y contenido dentro de la estructura del documento.
#
# 2. **Interfaz sencilla**: tiene una interfaz fácil de usar y comprender. No requiere conocimientos profundos de programación ni de lenguajes de marcado como HTML o XML. Con solo unas pocas líneas de código, puedes acceder y manipular los datos deseados.
#
# 3. **Soporte para analizadores**: es compatible con varios analizadores HTML/XML, como `html.parser`, `lxml`, `html5lib`, entre otros. Esto significa que puedes elegir el analizador más adecuado según tus necesidades y la complejidad del documento que estás analizando.
#
# 4. **Navegación basada en árbol**: utiliza una estructura de árbol para representar la jerarquía de los elementos en el documento HTML/XML. Esto permite realizar búsquedas y selecciones basadas en etiquetas, atributos, contenido y estructura del documento.
#
# 5. **Filtrado y extracción de datos**: uedes utilizar *Beautiful Soup* para filtrar y extraer datos específicos de una página web. Puedes buscar elementos por su nombre de etiqueta, atributos, clases, contenido y más. Esto te permite extraer información relevante para su posterior análisis.
#
# 6. **Ampliamente utilizado**:  es una de las bibliotecas más populares y ampliamente utilizadas para *web scraping* y análisis de datos en Python. Cuenta con una comunidad activa que brinda soporte y continúa desarrollando la biblioteca.
#
#
# Antes de empezar tendremos que instalar las siguientes librerías en nuestro ordernador, para eso tendremos que abrir la terminal y escribir las siguientes líneas de una en una:
#
# ```
# !pip install beautifulsoup4
# ```
#
# A lo largo de este jupyter veremos varios ejemplos de extracción de datos usando *Beautiful Soup*, en concreto sacaremos información de:
#
# - La página web de Ebay, para sacar información sobre teléfonos móviles.
#
# - Una página de la Bolsa, para sacar un histórico del Ibex 35.

# %%
# antes de empezar importamos las librerías que vamos a usar. 
# Importar librerías para web scraping y manipulación de datos
# -----------------------------------------------------------------------
from bs4 import BeautifulSoup
import requests

# Importar librerías para manipulación y análisis de datos
# -----------------------------------------------------------------------
import pandas as pd

# Configurar pandas para mostrar todas las columnas
pd.set_option('display.max_columns', None)

# Importar librerías para procesamiento de texto
# -----------------------------------------------------------------------
import re

# %% [markdown]
# # Métodos importantes de *Beautiful Soup*
#
# Algunos de los métodos principales de Beautiful Soup:
#
# 1. **BeautifulSoup**: Es el constructor principal de Beautiful Soup. Toma el código HTML o XML como entrada y lo analiza para crear un objeto BeautifulSoup. Su sintaxis básica es:
#    ```python
#    from bs4 import BeautifulSoup
#
#    # Crear un objeto BeautifulSoup
#    soup = BeautifulSoup(html_doc, 'html.parser')
#    ```
#
# 2. **find() y find_all()**: Estos métodos son fundamentales para buscar elementos en un documento analizado con Beautiful Soup.
#    - `find()` **devuelve el primer elemento** que coincide con los criterios de búsqueda.
#
#    - `find_all()` **devuelve una lista de todos los elementos** que coinciden con los criterios de búsqueda.
#
#       ```python
#       # Buscar un elemento por su etiqueta
#       soup.find('a')
#
#       # Buscar todos los elementos <a> en una lista
#       soup.find_all('a')
#       ```
#
# 3.  **select()**: devuelve una lista de objetos Tag que coinciden con el selector CSS especificado. Su sintaxis básica es:
#       ```python
#       # Buscar todos los elementos <a> dentro de elementos <li>
#       enlaces = soup.select('li a')
#       ```
#
# 4. **text** o **getText()**: El atributo `text` devuelve el texto contenido dentro de una etiqueta. Ambos métodos hacen exactamente lo mismo. Accederemos a él de la siguiente manera:
#       ```python
#       # Obtener el texto de un elemento
#       elemento.text
#       ```
#
# 5. **get()**: El método `get()` se utiliza para obtener el valor de un atributo de una etiqueta. Aquí tienes un ejemplo:
#       ```python
#       # Obtener el valor de un atributo
#       elemento.get('href')
#       ```

# %% [markdown]
# # Datos de moviles de Ebay
#
# En este caso, utilizaremos técnicas de web scraping para extraer información específica de la página web de Ebay. En lugar de recopilar manualmente la información, utilizaremos Python y la biblioteca Beautiful Soup para analizar el código fuente de la página web de Ebay y extraer los datos que nos interesan.
#
# El objetivo específico de nuestro proyecto de *web scraping* es obtener datos sobre el total de teléfonos móviles disponibles en el sitio web de Ebay. Para lograr esto, realizaremos los siguientes pasos:
#
# 1. En primer lugar, utilizaremos Python para hacer una solicitud HTTP a la página web de Ebay y obtener su código fuente. Usaremos la biblioteca `requests`.
#
# 2. Una vez que tengamos el código fuente de la página web, crearemos un objeto BeautifulSoup utilizando la biblioteca Beautiful Soup. Este objeto nos permitirá analizar y manipular el código HTML de la página de manera sencilla.
#
# 3. Utilizaremos técnicas de selección de elementos, como selectores CSS o métodos como `find()` y `find_all()`, para localizar los elementos que contienen información sobre los teléfonos móviles en la página web de Ebay. Podemos inspeccionar el código fuente de la página para identificar las etiquetas HTML y los atributos que nos ayudarán a encontrar estos elementos específicos.
#
# 4. Una vez que hayamos localizado los elementos relevantes, extraeremos la información que necesitamos, como el título del producto, el precio o cualquier otro dato que sea relevante para nuestro objetivo.
#
# 5. A medida que extraemos los datos de cada elemento, los almacenaremos en una estructura de datos adecuada, como una lista o un diccionario.
#
#
#
# **Antes de empezar algunas notas importantes que debes recordar**
#
# Cuando realizas una solicitud HTTP utilizando la biblioteca `requests`(como aprendiste en la lección anterior),vamos a obtener una respuesta del servidor. Esta respuesta contiene información sobre el resultado de la solicitud. Una de las propiedades más comunes de la respuesta es `status_code`, que es un código numérico que indica el estado de la respuesta. Recordemos que, cuando usamos la librería `requests` en realidad lo que estamos haciendo es pedir información a un servidor (en este caso es una página web), el método `status_code` nos dice si hemos pedido los datos correctamente o no. Algunos de los códigos más comunes son:
#
# - **200**: Esta respuesta indica que la solicitud fue exitosa. El servidor ha respondido correctamente y ha devuelto los datos solicitados. Esto es generalmente lo que esperamos obtener cuando hacemos una solicitud HTTP exitosa.
#
# - **404**: Este código indica que el recurso solicitado no se encontró en el servidor. Puede ocurrir cuando se accede a una URL incorrecta o cuando el recurso ha sido eliminado o no está disponible.
#
# - **500**: Un código de estado 500 indica un error interno del servidor. Esto puede deberse a un problema en el servidor que impide que se procese correctamente la solicitud. Es posible que necesites comunicarte con el administrador del servidor en este caso.
#
# - **302**: Este código es una redirección temporal. Indica que la URL solicitada ha sido redirigida a otra ubicación.
#
# - **401**: Este código indica que la solicitud requiere autenticación. Significa que no tienes acceso a los recursos solicitados sin proporcionar credenciales válidas, como un nombre de usuario y una contraseña.
#
#
# Al utilizar el método `status_code` en `requests`, podremos verificar el código de estado de la respuesta para determinar si la solicitud fue exitosa o si hubo algún tipo de error. Por ejemplo, si el código de estado es 200, sabremos que la solicitud se completó correctamente y podemos procesar los datos de la respuesta. Si el código de estado es diferente de 200, temdremos que tomar medidas adicionales según el tipo de código de estado. **Es importante verificar el código de estado de la respuesta para asegurarnos de que la solicitud fue exitosa y manejar cualquier error o condición especial según sea necesario.**

# %%
# definimos la url de la página de la vamos a sacar datos
url_moviles = "https://www.ebay.es/sch/15032/i.html?_from=R40&_nkw=celulares"

# hacemos la request a la página de la que queremos sacar la info
res_moviles = requests.get(url_moviles)

# vemos si todo ha ido bien
print("La respuesta de la petición es:", res_moviles.status_code)
# Out:
# La respuesta de la petición es: 200

# %%
# creamos el objeto BeautifulSoup para poder acceder al contenido solicitado
sopa_moviles = BeautifulSoup(res_moviles.content, 'html.parser')

# mostramos por pantalla los resultados del objeto de Beautiful Soup. El método ".prettify()" nos ayuda a visualizar los resultados de una forma más amigable
print(sopa_moviles.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if IE 9]><html class="ie9" lang="es"><![endif]-->
# <!--[if gt IE 9]><!-->
# <html lang="es">
#  <!--<![endif]-->
#  <!--M#s0-2-->
#  <noscript class="x-page-config">
#  </noscript>
#  <!--M/-->
#  <head>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <script>
#    (function () {
#         'use strict';
#         if (window.PerformanceObserver && performance && performance.mark && performance.getEntriesByName) {
#             window.SRP = window.SRP || {};
#             var paintObserver = new window.PerformanceObserver(function (list) {
#                 var paintEntries = list.getEntries();
#                 paintEntries.sort(function (a, b) {
#                     return a.startTime - b.startTime;
#                 });
#                 // begin looking for TTI at first contentful paint
#                 if (!paintEntries || paintEntries.length < 2) {
#                     // to avoid undefined issue on Safari
#                     return;
#                 }
#                 var interactiveWindow = paintEntries[1].startTime;
#                 window.SRP.TTI_TIMER = { lastInteractiveWindow: interactiveWindow };
#                 var longTaskObserver = new window.PerformanceObserver(function (list) {
#                     var longtaskEntries = list.getEntries();
#                     for (var i = 0, len = longtaskEntries.length; i < len; i++) {
#                         // if we find an idle window of >= 5000 ms, the beginning of that window was our timeToInteractive
#                         if (longtaskEntries[i].startTime - interactiveWindow >= 5000) {
#                             window.SRP.TTI_TIMER.timeToInteract = interactiveWindow;
#                             longTaskObserver.disconnect();
#                         }
#                         interactiveWindow = longtaskEntries[i].startTime + longtaskEntries[i].duration;
#                         window.SRP.TTI_TIMER.lastInteractiveWindow = interactiveWindow;
#                     }
#                 });
#                 longTaskObserver.observe({ entryTypes: ['longtask'] });
#                 paintObserver.disconnect();
#             });
#             paintObserver.observe({ entryTypes: ['paint'] });
#         }
#     })();
#   </script>
#   <meta content="102628213125203" property="fb:app_id">
#    <link href="https://i.ebayimg.com" rel="preconnect"/>
#    <meta content="unsafe-url" name="referrer"/>
#    <meta content="Encuentra celulares en venta entre una amplia seleccion de Móviles y telefonía en eBay." name="description"/>
#    <link href="https://ir.ebaystatic.com" rel="preconnect"/>
#    <meta content="34E98E6F27109BE1A9DCF19658EEEE33" name="msvalidate.01"/>
#    <meta content="060ab5e38d266c06" name="y_key"/>
#    <title>
#     celulares en venta - Móviles y telefonía | eBay
#    </title>
#    <meta content="noindex" name="robots"/>
#    <meta content="446Tr7oW9IID7WVwfkU3Nqp8Qb3BaYdlfyaVl4_nng8" name="google-site-verification"/>
#    <!-- NGMARS SIGNATURE -->
#    <link href="//i.ebayimg.com" rel="dns-prefetch"/>
#    <link href="//ir.ebaystatic.com" rel="dns-prefetch"/>
#    <link href="//rover.ebay.com" rel="dns-prefetch"/>
#    <link href="//svcs.ebay.com" rel="dns-prefetch"/>
#    <link href="//pulsar.ebay.com" rel="dns-prefetch"/>
#    <link href="//www.google.com/" rel="dns-prefetch"/>
#    <link href="//tpc.googlesyndication.com" rel="dns-prefetch"/>
#    <link href="//securepubads.g.doubleclick.net" rel="dns-prefetch"/>
#    <meta content="width=device-width, initial-scale=1, minimum-scale=1" name="viewport"/>
#    <link href="//ir.ebaystatic.com" rel="dns-prefetch"/>
#    <link href="//secureir.ebaystatic.com" rel="dns-prefetch"/>
#    <link href="//i.ebayimg.com" rel="dns-prefetch"/>
#    <link href="//rover.ebay.com" rel="dns-prefetch"/>
#    <script>
#     $ssgST=new Date().getTime();!function(){if("PerformanceLongTaskTiming" in window){var g=window.__tti={e:[]};g.o=new PerformanceObserver(function(l){g.e=g.e.concat(l.getEntries())});g.o.observe({entryTypes:["longtask"]})}}();
#    </script>
#    <link href="https://ir.ebaystatic.com/rs/v/awns0123gu5qde1uai2o5r1koyo.css?proc=DU:N" rel="stylesheet" type="text/css"/>
#    <link href="https://ir.ebaystatic.com/rs/c/inception-1lCR8ce3.css" rel="stylesheet"/>
#    <link href="https://ir.ebaystatic.com/rs/c/search-page-large-ih9_2nBH.css" rel="stylesheet"/>
#    <!--M#s0-5-9-->
#    <noscript data-marko-key="@_wbind s0-5-9" id="s0-5-9">
#    </noscript>
#    <!--M/-->
#    <style>
#     .s-item__sep > span {
#             display: block;
#             overflow: hidden;
#         }
#         .s-item__sep > span > span,
#         .s-item__sep > span > span::before {
#             display: inline-block;
#             transform-origin: 0 0;
#         }
#         .s-item__sep > span > span::before {
#             content: attr(data-w);
#         }
#    </style>
#    <style>
#     span[aria-labelledby=s-7nqt848] > span::before {transform: rotate(-5943916.713677053deg);}
#    </style>
#    <style>
#     span[aria-labelledby=s-quyd184] > span {transform: rotate(1615303.1831745536deg);}
#    </style>
#    <style>
#     span[aria-labelledby=s-quyd184] > span::before {transform: rotate(-5488543.9856690215deg);}
#    </style>
#    <style>
#     span[aria-labelledby=s-7nqt848] > span {transform: rotate(-1221630.6607847817deg);}
#    </style>
#    <!--F#f_5-->
#    <script>
#     (function(){ const __b=parseInt,__i='c2xpY2U=',__w='cHJldmlvdXNFbGVtZW50U2libGluZw==',__T='cGFyZW50RWxlbWVudA==',__W='YmVmb3JlYmVnaW4=',__3='cmVtb3ZlQ2hpbGQ=',__l=atob,__9='aWQ=',__B='Z2V0QXR0cmlidXRl',__7='aW5zZXJ0QWRqYWNlbnRFbGVtZW50',__O='c3BsaXQ=',__v='dGV4dENvbnRlbnQ=',__k='cmVtb3ZlQXR0cmlidXRl',__u='YWZ0ZXJlbmQ='; const __f=(__D)=>{ const __5=__D[__l(__O)]('|'); const __M=__l(__5[1])[__l(__O)]('|'); const __G=__b(__M[0]); const __U=__b(__M[1]); return 's-'+__l(__5[0][__l(__i)](__G,__U)); }; const __Q=(__V)=>{ const __A=__f(__V[0]); const __C=__f(__V[1]); try { var __P=document.getElementById(__A), __g=__C===__P[__l(__w)][__l(__B)](__l(__9)), __h=__P[__l(__T)][__l(__3)](__P), __p=__g?__l(__u):__l(__W); __h[__l(__v)]=''; document.getElementById(__C)[__l(__7)](__p,__h); __h[__l(__k)](__l(__9)); } catch (_) {} }; window.addEventListener('load',()=>{ __Q(['s-0.hd2VhYTgyNw==1crajx11rw351|NXwxNw==', 's-0.h1crajx11rwN25xdDg0OA==351|MTV8Mjc=']);__Q(['s-0.h1crajx11rwN25xdDg0OA==351|MTV8Mjc=', 's-0.h1crajx1cXV5ZDE4NA==1rw351|MTJ8MjQ=']);__Q(['s-0.h1crajxazY3MzExOA==11rw351|MTF8MjM=', 's-0.hd2VhYTgyNw==1crajx11rw351|NXwxNw==']); }); }());
#    </script>
#    <!--F/-->
#    <script>
#     (function(w, d, e, u, c, g, a, b){
# w["SSJSConnectorObj"] = w["SSJSConnectorObj"] || {ss_cid : c, domain_info: g};
#     a = d.createElement(e);
#     a.async = true;
#     a.src = u;
#     b = d.getElementsByTagName(e)[0];
#     b.parentNode.insertBefore(a, b);
#   })(window,document,"script","https://ir.ebaystatic.com/rs/v/dxtuvtkk2q3hpkc1xveeo13iaek.js","bjnh","auto");
#    </script>
#   </meta>
#  </head>
#  <body class="s-page no-touch skin-large">
#   <script>
#    "use strict";if(window.SRP=window.SRP||{},window.SRP.metrics={counters:{imageLoadError:{count:0,tag:"imglderr"},imageEmptyError:{count:0,tag:"imgempty"},watchListError:{count:0,tag:"watcherr"},lensClicked:{count:0,tag:"lensclicked"},seekSurveyClicked:{count:0,tag:"seekclicked"},btfAjaxFailures:{count:0,tag:"btfajaxfail"},misMatchedResourceLoaded:{count:0,tag:"mismatched"},misMatchedFallbackFailed:{count:0,tag:"mismatchedfailed"},bosTotalRenderTime:{count:0,tag:"bos_trt"},bosRequestTime:{count:0,tag:"bos_rt"},bosTimeToRequest:{count:0,tag:"bos_ttr"}},static:{riverItemCount:0}},window.SRP.metrics.registerMetric=function(t){"string"==typeof t&&(window.SRP.metrics.counters[t]={count:0,tag:t})},window.SRP.metrics.incrementCounter=function(t,e){var i=window.SRP.metrics.counters;e=e||1,i&&i[t]&&(i[t].count+=e)},window.SRP.metrics.updateMetric=function(t,e){var i=window.SRP.metrics.static;i&&(i[t]=e)},window.SRP.metrics.flushMetrics=function(){var t=window.SRP.metrics.counters;if(window.SRP.isSampledForMonitoring)for(var e in t)if(Object.prototype.hasOwnProperty.call(t,e)){var i=t[e];if(i.count>0){var r=new XMLHttpRequest;r.open("POST","./update",!0),r.setRequestHeader("srt",window.SRP.token);var o={t:i.tag,v:i.count};r.send(JSON.stringify(o)),i.count=0}}},window.sessionStorage){var searchQueryString=window.location.search;window.sessionStorage.getItem("SRP_last_query")!==searchQueryString&&setInterval((function(){window.SRP&&window.SRP.metrics&&window.SRP.metrics.flushMetrics()}),1e4),window.sessionStorage.setItem("SRP_last_query",searchQueryString)};
#   </script>
#   <script>
#    if(window.SRP) {
#     window.SRP.token = '01000900000050befdc98f729ce70a4e3fc6b00cad3dc5028bbf0dc386ff3e27be6b437c8c7fc0afbc71ab0272414da3676f5edda8f38519251b5d2e2456ab9fd03795845af9bcd70700d222aa0c8cd41958ac14108f57';
#     window.SRP.isSampledForMonitoring = false;
# }
#   </script>
#   <!--M#s0-10-1-->
#   <noscript>
#   </noscript>
#   <!--M/-->
#   <!--M#s0-11-->
#   <div class="x-header">
#    <script type="text/javascript">
#     var GHpre = {userAuth:false,si:false}
#    </script>
#    <style>
#     .gh-hide-if-nocss{display:none;}.gh-ar-hdn{color:#fff}
#    </style>
#    <div class="gh-acc-exp-div gh-hide-if-nocss">
#     <a class="gh-acc-a" href="#mainContent" id="gh-hdn-stm">
#      Ir directamente al contenido principal
#     </a>
#    </div>
#    <!--[if lt IE 9]><div id="gh" role="banner" class="gh-IE8 gh-flex gh-pre-js gh-w "><![endif]-->
#    <header class="gh-ui-6-5 gh-flex gh-pre-js gh-w gh-sch-prom" data-treatment="" id="gh" role="banner">
#     <table class="gh-tbl" role="presentation">
#      <tbody>
#       <tr>
#        <td class="gh-td">
#         <a _sp="m570.l2586" href="https://www.ebay.es" id="gh-la">
#          <img alt="Logotipo de eBay" height="200" id="gh-logo" src="https://ir.ebaystatic.com/rs/v/fxxj3ttftm5ltcqnto1o4baovyl.png" style="clip:rect(47px, 118px, 95px, 0px); position:absolute; top:-47px;left:0" width="250"/>
#         </a>
#        </td>
#        <td class="gh-td">
#         <div class="gh-hide-if-nocss" id="gh-shop">
#          <button aria-controls="gh-sbc-o" aria-expanded="false" class="gh-control" id="gh-shop-a">
#           Comprar por categoría
#           <i class="gh-sprRetina" id="gh-shop-ei">
#           </i>
#          </button>
#          <div id="gh-sbc-o">
#           <h2 class="gh-ar-hdn">
#            Comprar por categoría
#           </h2>
#          </div>
#         </div>
#        </td>
#        <td class="gh-td-s">
#         <form action="/sch/i.html" id="gh-f" method="get">
#          <input name="_from" type="hidden" value="R40"/>
#          <input name="_trksid" type="hidden" value="m570.l1313"/>
#          <table class="gh-tbl2" id="gh-search-wrap" role="presentation">
#           <tbody>
#            <tr>
#             <td class="gh-td-s">
#              <div id="gh-ac-box">
#               <div id="gh-ac-box2">
#                <label class="gh-ar-hdn" for="gh-ac">
#                 Introduce la palabra clave de búsqueda
#                </label>
#                <input aria-autocomplete="list" aria-expanded="false" aria-label="Buscar cualquier artículo" autocapitalize="off" autocomplete="off" autocorrect="off" class="gh-tb ui-autocomplete-input" id="gh-ac" maxlength="300" name="_nkw" placeholder="Buscar cualquier artículo" size="50" spellcheck="false" type="text" value="celulares"/>
#                <input style="display:none"/>
#                <script>
#                 if(document.getElementById('gh-ac').value.length !== 0) { document.getElementById('gh-ac-box').classList.add('gh-ac-box-focus'); document.getElementById('gh').classList.add('gh-sch-focus'); }
#                </script>
#                <svg aria-hidden="true" class="icon icon--search gh-search__icon" focusable="false" height="14" width="14">
#                 <use xlink:href="#icon-search">
#                 </use>
#                </svg>
#               </div>
#              </div>
#             </td>
#             <td class="gh-td" id="gh-cat-td">
#              <div id="gh-cat-box">
#               <select aria-label="Selecciona una categoría para limitar la búsqueda" class="gh-sb" id="gh-cat" name="_sacat" size="1">
#                <option value="0">
#                 Todas las categorías
#                </option>
#                <optgroup label="----------------------------------------">
#                </optgroup>
#                <option value="14339">
#                 Artesanía y manualidades
#                </option>
#                <option value="353">
#                 Arte y antigüedades
#                </option>
#                <option value="2984">
#                 Bebés
#                </option>
#                <option value="26395">
#                 Belleza y salud
#                </option>
#                <option value="625">
#                 Cámaras y fotografía
#                </option>
#                <option value="11700">
#                 Casa, jardín y bricolaje
#                </option>
#                <option value="11232">
#                 Cine, DVD y películas
#                </option>
#                <option value="1">
#                 Coleccionismo
#                </option>
#                <option value="1249">
#                 Consolas y videojuegos
#                </option>
#                <option value="888">
#                 Deportes
#                </option>
#                <option value="20710">
#                 Electrodomésticos
#                </option>
#                <option value="1305">
#                 Entradas y eventos
#                </option>
#                <option value="12576">
#                 Equipamiento y maquinaria
#                </option>
#                <option value="14308">
#                 Gastronomía y bebidas
#                </option>
#                <option value="293">
#                 Imagen y sonido
#                </option>
#                <option value="58058">
#                 Informática y tablets
#                </option>
#                <option value="619">
#                 Instrumentos musicales
#                </option>
#                <option value="220">
#                 Juguetes
#                </option>
#                <option value="267">
#                 Libros, revistas y cómics
#                </option>
#                <option value="11116">
#                 Monedas y billetes
#                </option>
#                <option value="131090">
#                 Motor: piezas y accesorios
#                </option>
#                <option value="9800">
#                 Motor: vehículos
#                </option>
#                <option selected="selected" value="15032">
#                 Móviles y telefonía
#                </option>
#                <option value="11233">
#                 Música, CDs y vinilos
#                </option>
#                <option value="99">
#                 Otras categorías
#                </option>
#                <option value="281">
#                 Relojes y joyas
#                </option>
#                <option value="11450">
#                 Ropa, calzado y complementos
#                </option>
#                <option value="260">
#                 Sellos
#                </option>
#                <option value="3252">
#                 Viajes
#                </option>
#               </select>
#              </div>
#             </td>
#             <td class="gh-td gh-sch-btn">
#              <input class="btn btn-prim gh-spr" id="gh-btn" type="submit" value="Buscar"/>
#              <svg aria-hidden="true" class="icon icon--search gh-search-btn__icon" focusable="false" height="22" width="22">
#               <use xlink:href="#icon-search">
#               </use>
#              </svg>
#             </td>
#             <td class="gh-td" id="gh-as-td">
#              <a _sp="m570.l2614" aria-label="Advanced Search" href="https://www.ebay.es/sch/ebayadvsearch" id="gh-as-a" title="Búsqueda avanzada">
#               Avanzada
#              </a>
#             </td>
#            </tr>
#           </tbody>
#          </table>
#         </form>
#        </td>
#        <td class="sticky_placeholder">
#         <ul>
#         </ul>
#        </td>
#       </tr>
#      </tbody>
#     </table>
#     <div aria-label="Cuenta" class="gh-hide-if-nocss" id="gh-top" role="navigation">
#      <ul id="gh-topl">
#       <li class="gh-t" id="gh-eb-u">
#        <noscript class="gh-t gh-spr">
#         ¡Hola! (
#         <a href="https://signin.ebay.es/ws/eBayISAPI.dll?SignIn&amp;_trksid=m570.l3348">
#          Identifícate
#         </a>
#         para pujar o comprar)
#        </noscript>
#        <script>
#         var supressUserGreeting = true; (function(){try{ var sup = !!(supressUserGreeting && typeof window.GHpre !== 'undefined' && !window.GHpre.si); var d=document.cookie,a=((a=d.match(/u1f[^a-zA-Z0-9]([^^]*)[0-9a-z]{8}/))?a[1].replace(/\+/g," "):"").replace(/(.{12}).*/,"$1...");if(/[<>%&'\/]/.test(a)){throw(1)}document.write("<span id=gh-ug"+(!a||/u1p.QEBfX/.test(d)?' class=gh-ug-guest>¡Bienvenido! <a href="https://signin.ebay.es/ws/eBayISAPI.dll?SignIn&sgfl=gh&_trksid=m570.l1524" rel="nofollow" _sp="m570.l1524">Identifícate</a> <span id="gh-ug-flex">o <a href="https://signup.ebay.es/pa/crte?_trksid=m570.l2621" rel="nofollow" _sp="m570.l2621">regístrate</a></span>':' style="margin-right:3px">¡Hola, <b>-User-</b>!'.replace(/-User-/,sup ? '' : decodeURIComponent(escape(a))))+"</span>")}catch(b){document.write("<style>#gh-topl{display:none}</style>")}})();
#        </script>
#       </li>
#       <li class="gh-t gh-divider-l" id="gh-p-1">
#        <a _sp="m570.l3188" class="gh-p" data-sp="m570.l3188" href="https://www.ebay.es/deals">
#         Ofertas de eBay
#        </a>
#       </li>
#       <li class="gh-t gh-divider-l" id="gh-p-3">
#        <a _sp="m570.l1545" data-sp="m570.l1545" href="https://www.ebay.es/help/home">
#         Ayuda
#        </a>
#       </li>
#      </ul>
#      <ul id="gh-eb">
#       <li class="gh-eb-li gh-t-rt gh--link__divider" id="gh-p-2">
#        <a _sp="m570.l1528" class="gh-p" data-sp="m570.l1528" href="https://www.ebay.es/sl/sell">
#         Vender
#        </a>
#       </li>
#       <li class="gh-eb-li gh-margin rt" id="gh-wl-click">
#        <div class="gh-menu gh--link__divider">
#         <a _sp="m570.l47137" class="gh-eb-li-a gh-rvi-menu watchlist-menu" href="https://www.ebay.es/mye/myebay/watchlist" title="Lista de seguimiento">
#          Lista de seguimiento
#          <i class="gh-sprRetina gh-eb-arw gh-rvi-chevron" data-sp="m570.l47137">
#          </i>
#         </a>
#         <a aria-expanded="false" class="gh-acc-exp-a gh-acc-a2 gh-control" data-controltarget="gh-wl-click-o" href="#gh-wl-click" role="button">
#          Ampliar Lista de seguimiento
#         </a>
#         <div aria-label="Lista de seguimiento" class="gh-sublayer gh-flyout__menu" id="gh-wl-click-flyout" role="dialog">
#          <button aria-label="Cerrar diálogo" class="gh_flyout__close" id="gh-wl-click-close">
#           <svg aria-hidden="true" focusable="false" height="17" width="17">
#            <use xlink:href="#icon-close">
#            </use>
#           </svg>
#          </button>
#          <div id="gh-wl-click-body">
#           <div class="gh-loading">
#            <span aria-label="Cargando" class="gh-spinner" role="img">
#            </span>
#            <span class="gh-state">
#             Cargando...
#            </span>
#           </div>
#           <div class="gh-wl-click-gen-error">
#            <span>
#             <a href="https://signin.ebay.es/ws/eBayISAPI.dll?SignIn&amp;sgfl=gh&amp;ru=ru">
#              Identifícate
#             </a>
#             para ver tu información de usuario
#            </span>
#           </div>
#          </div>
#         </div>
#        </div>
#       </li>
#       <li class="gh-eb-li gh-hvr gh-dd rt" data-imp="10" id="gh-eb-My">
#        <div class="gh-menu">
#         <a _sp="m570.l2919" class="gh-eb-li-a gh-rvi-menu" href="https://www.ebay.es/mys/home?source=GBH" title="Mi eBay">
#          Mi eBay
#          <i class="gh-sprRetina gh-eb-arw gh-rvi-chevron" data-sp="m570.l2919">
#          </i>
#         </a>
#         <a aria-expanded="false" class="gh-acc-exp-a gh-acc-a2 gh-control" data-controltarget="gh-eb-My-o" href="#gh-eb-My" role="button">
#          Ampliar Mi eBay
#         </a>
#         <div class="gh-submenu gh-eb-o" id="gh-eb-My-o">
#          <ul id="gh-ul-nav" role="navigation">
#           <li>
#            <a _sp="m570.l1533" class="gh-eb-oa thrd" data-sp="m570.l1533" href="https://www.ebay.es/mye/myebay/summary">
#             Resumen
#            </a>
#           </li>
#           <li>
#            <a _sp="m570.l9225" class="gh-eb-oa thrd" data-sp="m570.l9225" href="https://www.ebay.es/mye/myebay/rvi">
#             Vistos recientemente
#            </a>
#           </li>
#           <li>
#            <a _sp="m570.l1535" class="gh-eb-oa thrd" data-sp="m570.l1535" href="https://www.ebay.es/mye/myebay/bidsoffers">
#             Pujas/ofertas
#            </a>
#           </li>
#           <li>
#            <a _sp="m570.l1534" class="gh-eb-oa thrd" data-sp="m570.l1534" href="https://www.ebay.es/mye/myebay/watchlist">
#             Lista de seguimiento
#            </a>
#           </li>
#           <li>
#            <a _sp="m570.l1536" class="gh-eb-oa thrd" data-sp="m570.l1536" href="https://www.ebay.es/mye/myebay/purchase">
#             Historial de compras
#            </a>
#           </li>
#           <li>
#            <a _sp="m570.l1537" class="gh-eb-oa thrd" data-sp="m570.l1537" href="https://www.ebay.es/mys/home?CurrentPage=MyeBayAllSelling&amp;ssPageName=STRK:ME:LNLK:MESX&amp;source=GBH">
#             En venta
#            </a>
#           </li>
#           <li>
#            <a _sp="m570.l9503" class="gh-eb-oa thrd" data-sp="m570.l9503" href="https://www.ebay.es/myb/SavedSearches">
#             Búsquedas guardadas
#            </a>
#           </li>
#           <li>
#            <a _sp="m570.l9505" class="gh-eb-oa thrd" data-sp="m570.l9505" href="https://www.ebay.es/myb/SavedSellers">
#             Vendedores guardados
#            </a>
#           </li>
#           <li>
#            <a _sp="m570.l143039" class="gh-eb-oa thrd" data-sp="m570.l143039" href="https://www.ebay.es/g/mygarage">
#             Mi garage
#            </a>
#           </li>
#           <li>
#            <a _sp="m570.l1539" class="gh-eb-oa thrd" data-sp="m570.l1539" href="https://mesg.ebay.es/mesgweb/ViewMessages/0">
#             Mensajes
#            </a>
#           </li>
#           <li id="gh-eb-sub-li-cpn">
#           </li>
#          </ul>
#         </div>
#        </div>
#       </li>
#       <li class="gh-eb-li gh-hvr gh-layer rt" id="gh-eb-Alerts">
#        <div class="gh-menu">
#         <button aria-controls="gh-eb-Alerts-o" aria-expanded="false" class="gh-control ghn-b gh-eb-li-a">
#          <i class="gh-sprRetina" id="gh-Alerts-i">
#           Notificación
#          </i>
#         </button>
#         <div class="gh-sublayer">
#          <div class="gh-eb-o" id="gh-eb-Alerts-o" style="display: none;">
#          </div>
#         </div>
#        </div>
#       </li>
#       <li class="gh-eb-li gh-margin rt" id="gh-minicart-hover">
#        <div class="gh-menu">
#         <a _sp="m570.l2633" aria-label="Tu carro de la compra" class="gh-eb-li-a gh-rvi-menu" data-sp="m570.l2633" href="https://cart.payments.ebay.es/sc/view">
#          <svg aria-hidden="true" class="gh-cart-icon" focusable="false">
#           <use xlink:href="#icon-cart-new">
#           </use>
#          </svg>
#         </a>
#         <a aria-expanded="false" class="gh-acc-exp-a gh-acc-a2 gh-control" data-controltarget="gh-minicart-hover-o" href="#gh-minicart-hover" role="button">
#          Ampliar Cesta
#         </a>
#         <div aria-label="Tu carro de la compra" class="gh-sublayer gh-flyout__menu" id="gh-minicart-hover-flyout" role="dialog">
#          <button aria-label="Cerrar diálogo" class="gh_flyout__close" id="gh-minicart-hover-close">
#           <svg aria-hidden="true" focusable="false" height="17" width="17">
#            <use xlink:href="#icon-close">
#            </use>
#           </svg>
#          </button>
#          <div id="gh-minicart-hover-body">
#           <div class="gh-loading">
#            <span aria-label="Cargando" class="gh-spinner" role="img">
#            </span>
#            <span class="gh-state">
#             Cargando...
#            </span>
#           </div>
#           <div class="gh-minicart-hover-gen-error">
#            <span>
#             Se ha producido un error. Ve a la cesta para obtener más información.
#            </span>
#           </div>
#          </div>
#         </div>
#        </div>
#       </li>
#      </ul>
#     </div>
#     <link href="https://www.ebay.es/manifest.json" rel="manifest"/>
#     <div id="gh-ihelp" style="display:none;">
#      {"delay":300}
#     </div>
#     <!--[if lt IE 9]></div><![endif]-->
#    </header>
#    <div class="widgets-placeholder" id="widgets-placeholder">
#    </div>
#    <svg hidden="" style="display: none">
#     <svg height="100%" id="icon-search" viewbox="0 0 20 20" width="100%">
#      <path d="M19.786 18.557l-5.093-5.093a8.1 8.1 0 0 0 1.873-5.21C16.507 3.747 12.82 0 8.254 0 3.688 0 0 3.746 0 8.254c0 4.508 3.688 8.312 8.254 8.312 2.049 0 3.863-.761 5.327-1.932l5.093 5.093a.714.714 0 0 0 .527.234c.176 0 .41-.059.527-.234.351-.351.351-.878.059-1.171l-.001.001zM1.581 8.254a6.67 6.67 0 0 1 6.673-6.673 6.67 6.67 0 0 1 6.673 6.673c0 3.688-2.985 6.732-6.673 6.732s-6.673-2.985-6.673-6.732z">
#      </path>
#     </svg>
#     <symbol id="icon-close" viewbox="1.5 1.5 21 21">
#      <path d="M22.182 3.856c.522-.554.306-1.394-.234-1.938-.54-.543-1.433-.523-1.826-.135C19.73 2.17 11.955 10 11.955 10S4.225 2.154 3.79 1.783c-.438-.371-1.277-.4-1.81.135-.533.537-.628 1.513-.25 1.938.377.424 8.166 8.218 8.166 8.218s-7.85 7.864-8.166 8.219c-.317.354-.34 1.335.25 1.805.59.47 1.24.455 1.81 0 .568-.456 8.166-7.951 8.166-7.951l8.167 7.86c.747.72 1.504.563 1.96.09.456-.471.609-1.268.1-1.804-.508-.537-8.167-8.219-8.167-8.219s7.645-7.665 8.167-8.218z">
#      </path>
#     </symbol>
#     <svg id="gh-icon-cart" viewbox="0 0 40 32">
#      <path d="M35.0390625,6.8515625 C36.4453195,6.8515625 37.4674447,7.20312148 38.1054688,7.90625 C38.7434928,8.60937852 39.0625,9.66405547 39.0625,11.0703125 L39.0625,18.9609375 C39.0625,20.2369855 38.7434928,21.226559 38.1054688,21.9296875 C37.4674447,22.632816 36.4322988,22.984375 35,22.984375 L31.484375,22.984375 C29.3749895,22.984375 27.0898561,22.9778646 24.6289063,22.9648438 C22.1679564,22.9518229 19.9349059,22.9453125 17.9296875,22.9453125 L14.921875,22.9453125 L6.8359375,4.8203125 L0.859375,4.8203125 L0.8203125,0.7578125 L8.90625,0.7578125 L12.9296875,6.8515625 L35.0390625,6.8515625 Z M34.0625,18.9609375 C34.322918,18.9609375 34.5507803,18.8632822 34.7460938,18.6679688 C34.9414072,18.4726553 35.0390625,18.2317723 35.0390625,17.9453125 C35.0390625,17.6588527 34.9414072,17.4179697 34.7460938,17.2226562 C34.5507803,17.0273428 34.322918,16.9296875 34.0625,16.9296875 L17.9296875,16.9296875 C17.6692695,16.9296875 17.4414072,17.0273428 17.2460938,17.2226562 C17.0507803,17.4179697 16.953125,17.6588527 16.953125,17.9453125 C16.953125,18.2317723 17.0507803,18.4726553 17.2460938,18.6679688 C17.4414072,18.8632822 17.6692695,18.9609375 17.9296875,18.9609375 L34.0625,18.9609375 Z M34.0625,12.90625 C34.322918,12.90625 34.5507803,12.8085947 34.7460938,12.6132812 C34.9414072,12.4179678 35.0390625,12.1770848 35.0390625,11.890625 C35.0390625,11.630207 34.9414072,11.3958344 34.7460938,11.1875 C34.5507803,10.9791656 34.322918,10.875 34.0625,10.875 L15.9375,10.875 C15.6510402,10.875 15.4101572,10.9791656 15.2148438,11.1875 C15.0195303,11.3958344 14.921875,11.630207 14.921875,11.890625 C14.921875,12.1770848 15.0195303,12.4179678 15.2148438,12.6132812 C15.4101572,12.8085947 15.6510402,12.90625 15.9375,12.90625 L34.0625,12.90625 Z M34.0234375,24.8984375 C34.8828168,24.8984375 35.6249969,25.1979137 36.25,25.796875 C36.8750031,26.3958363 37.1875,27.1249957 37.1875,27.984375 C37.1875,28.8437543 36.8750031,29.5729137 36.25,30.171875 C35.6249969,30.7708363 34.8828168,31.0703125 34.0234375,31.0703125 C33.1640582,31.0703125 32.4283885,30.7708363 31.8164062,30.171875 C31.204424,29.5729137 30.8984375,28.8437543 30.8984375,27.984375 C30.8984375,27.1249957 31.204424,26.3958363 31.8164062,25.796875 C32.4283885,25.1979137 33.1640582,24.8984375 34.0234375,24.8984375 Z M19.8828125,24.8984375 C20.7421918,24.8984375 21.4778615,25.1979137 22.0898438,25.796875 C22.701826,26.3958363 23.0078125,27.1249957 23.0078125,27.984375 C23.0078125,28.8437543 22.701826,29.5729137 22.0898438,30.171875 C21.4778615,30.7708363 20.7421918,31.0703125 19.8828125,31.0703125 C19.0234332,31.0703125 18.2877635,30.7708363 17.6757812,30.171875 C17.063799,29.5729137 16.7578125,28.8437543 16.7578125,27.984375 C16.7578125,27.1249957 17.063799,26.3958363 17.6757812,25.796875 C18.2877635,25.1979137 19.0234332,24.8984375 19.8828125,24.8984375 Z">
#      </path>
#     </svg>
#     <symbol id="icon-check" viewbox="0 0 30 30">
#      <circle cx="14.5" cy="14.5" fill="#82187c" r="14.5">
#      </circle>
#      <path d="M5.548 15.01l5.773 6.286L21.522 9.824" fill="#82187c" stroke="#ffffff" stroke-width="2">
#      </path>
#     </symbol>
#     <symbol id="icon-cart-new" viewbox="0 0 23 22">
#      <path d="M22 4a.999.999 0 01.97 1.242l-2 8A1 1 0 0120 14H7a1 1 0 01-.97-.758L3.22 2H1a1 1 0 110-2h3a1 1 0 01.97.758L5.78 4H22zm-1.277 2H6.28l1.5 6h11.442l1.5-6zm-4.539 12A2.995 2.995 0 0119 16a2.995 2.995 0 11-2.816 4h-5.368a3 3 0 110-2h5.368zM7 19a1 1 0 102 0 1 1 0 00-2 0zm12 1a1 1 0 110-2 1 1 0 010 2z" fill-rule="evenodd">
#      </path>
#     </symbol>
#     <symbol id="gh-icon-cart-evo" viewbox="0 0 20 20">
#      <path clip-rule="evenodd" d="M2.23628 3.99999H1C0.447715 3.99999 0 3.55228 0 2.99999C0 2.44771 0.447715 1.99999 1 1.99999H2.96947C3.42767 1.98561 3.85407 2.29636 3.96967 2.75462L4.85471 5.99975H17C17.6537 5.99975 18.1411 6.64595 17.9615 7.27447L16.376 12.8239C16.008 14.1118 14.8308 14.9998 13.4914 14.9998H7.5276C6.17475 14.9998 4.98927 14.0943 4.63331 12.7891L2.23628 3.99999ZM6.56284 12.2629L5.40017 7.99975H15.6743L14.4529 12.2745C14.3303 12.7038 13.9379 12.9998 13.4914 12.9998H7.5276C7.07665 12.9998 6.68149 12.6979 6.56284 12.2629Z" fill="#191919" fill-rule="evenodd">
#      </path>
#      <path d="M8 18.5C8 19.3284 7.32843 20 6.5 20C5.67157 20 5 19.3284 5 18.5C5 17.6716 5.67157 17 6.5 17C7.32843 17 8 17.6716 8 18.5Z" fill="#191919">
#      </path>
#      <path d="M14.5 20C15.3284 20 16 19.3284 16 18.5C16 17.6716 15.3284 17 14.5 17C13.6716 17 13 17.6716 13 18.5C13 19.3284 13.6716 20 14.5 20Z" fill="#191919">
#      </path>
#     </symbol>
#     <symbol id="gh-icon-notification-evo" viewbox="0 0 18 20">
#      <path clip-rule="evenodd" d="M5.99993 6.98212C6.00956 4.78121 7.79671 3 9.99989 3C12.2031 3 13.9902 4.78121 13.9999 6.98213C13.9997 6.98808 13.9997 6.99403 13.9997 7V9.66154C13.9997 10.0605 14.1058 10.4523 14.3071 10.7968L15.9593 13.6241C16.0567 13.7908 15.9365 14.0002 15.7434 14.0002L10.0003 14H10H9.99974H9.99957L4.25633 14.0002C4.0633 14.0002 3.94308 13.7908 4.04048 13.6241L5.69271 10.7968C5.894 10.4523 6.00009 10.0605 6.00009 9.66154V7C6.00009 6.99403 6.00003 6.98807 5.99993 6.98212ZM4.00009 7H3.99989C3.99989 3.68629 6.68618 1 9.99989 1C13.3136 1 15.9999 3.68629 15.9999 7H15.9997V9.66154C15.9997 9.70587 16.0115 9.7494 16.0338 9.78768L17.6861 12.615C18.5626 14.115 17.4807 16.0003 15.7434 16.0002L12.9999 16.0001C12.9998 17.6569 11.6567 19 9.99989 19C8.34308 19 6.99996 17.6569 6.99989 16.0001L4.25642 16.0002C2.51907 16.0003 1.43714 14.115 2.3137 12.615L3.96593 9.78768C3.9883 9.7494 4.00009 9.70587 4.00009 9.66154V7ZM8.99989 16L9.99965 16H10.0001L10.9999 16C10.9999 16.5523 10.5522 17 9.99989 17C9.44762 17 8.99991 16.5523 8.99989 16Z" fill="#191919" fill-rule="evenodd">
#      </path>
#     </symbol>
#     <symbol id="gh-icon-search-evo" viewbox="0 0 16 17">
#      <path d="M3 7C3 5.067 4.567 3.5 6.5 3.5C8.433 3.5 10 5.067 10 7C10 8.933 8.433 10.5 6.5 10.5C4.567 10.5 3 8.933 3 7ZM14.76 13.85L14.739 13.84L11.029 10.159L11.004 10.151C11.63 9.259 12 8.174 12 7C12 3.963 9.537 1.5 6.5 1.5C3.463 1.5 1 3.963 1 7C1 10.037 3.463 12.5 6.5 12.5C7.658 12.5 8.731 12.14 9.618 11.528L13.35 15.26C13.746 15.6 14.338 15.576 14.707 15.207C15.076 14.838 15.1 14.246 14.76 13.85Z">
#      </path>
#     </symbol>
#     <symbol id="gh-ac-icon-clear-evo" viewbox="0 0 16 16">
#      <path d="M0 8C0 3.582 3.582 0 8 0C10.122 0 12.1567 0.842667 13.6567 2.34333C15.1573 3.84333 16 5.878 16 8C16 12.418 12.418 16 8 16C3.582 16 0 12.418 0 8ZM11.9789 11.4884C12.0373 11.2462 11.9544 10.9913 11.7654 10.8294L8.91388 7.98215L11.7588 5.1349C11.9842 4.87142 11.969 4.47918 11.7243 4.23361C11.4789 3.98871 11.087 3.97344 10.8237 4.1991L7.97885 7.04634L5.13396 4.19246C4.87401 3.93229 4.45225 3.93229 4.1923 4.19246C3.93235 4.45263 3.93235 4.87474 4.1923 5.1349L7.04381 7.98215L4.19893 10.836C3.97346 11.0995 3.98871 11.4918 4.23341 11.7373C4.47878 11.9822 4.87069 11.9975 5.13396 11.7718L7.97885 8.91796L10.8304 11.7652C10.9922 11.9544 11.2468 12.0373 11.4889 11.9789C11.7316 11.9205 11.9206 11.7314 11.9789 11.4884Z" fill="#707070">
#      </path>
#     </symbol>
#    </svg>
#    <svg hidden="">
#     <symbol id="svg-icon-arrow-down" viewbox="0 0 32 32">
#      <path d="M15.94 25.3L.47 8.06h30.95l-7.74 8.61z">
#      </path>
#     </symbol>
#     <symbol id="svg-icon-arrow-up" viewbox="0 0 32 32">
#      <path d="M16 8.5L1.05 22.43v1.07h29.9v-1.07z">
#      </path>
#     </symbol>
#     <symbol id="svg-icon-arrow-right" viewbox="1.2 2.1 22 21">
#      <path d="M11.7 22.1a1.48 1.48 0 0 1-1.02-.39 1.38 1.38 0 0 1-.4-1c0-.37.14-.71.4-.97l6.5-6.21H2.71c-1.04 0-1.51-.73-1.51-1.4 0-.68.47-1.4 1.5-1.4h14.48c-1.42-1.36-6.02-5.74-6.5-6.22-.3-.3-.44-.64-.44-1a1.37 1.37 0 0 1 .45-.97c.5-.48 1.35-.68 2.03 0 .56.56 9.77 9.33 9.86 9.42l.17.17-.17.16-9.86 9.42c-.26.26-.64.39-1.02.39">
#      </path>
#     </symbol>
#     <symbol id="svg-icon-cart" viewbox="0 0 40 32">
#      <path d="M39.727 7.727c-.39-.624-1.249-1.405-2.966-1.405-1.873-.078-24.273 0-25.6 0L9.21 1.093a1.173 1.173 0 0 0-1.093-.78H1.483C.781.313.312.781.312 1.484S.78 2.655 1.483 2.655h5.854l7.649 20.293c.156.468.624.78 1.093.78h18.419c.702 0 1.249-.39 1.483-1.015.156-.39 1.015-2.732 1.873-5.073.859-2.419 1.795-4.917 2.029-5.698.624-1.717.546-3.2-.156-4.215zm-2.029 3.356c-.312.78-1.171 3.278-2.107 5.698a145.091 145.091 0 0 0-1.639 4.605H16.859L12.02 8.664h24.663c.39 0 .859.078 1.093.39.312.312.234 1.093-.078 2.029zM19.902 29.112a2.888 2.888 0 1 1-5.776 0 2.888 2.888 0 0 1 5.776 0zM36.761 29.112a2.888 2.888 0 1 1-5.776 0 2.888 2.888 0 0 1 5.776 0z">
#      </path>
#     </symbol>
#     <symbol id="svg-icon-check" viewbox="0 0 32 32">
#      <path d="M27.81 4.04l-17 17.16-6.93-6.93-3.3 3.61 10.23 9.94L31.43 7.35 27.8 4.04z">
#      </path>
#     </symbol>
#     <symbol id="svg-icon-arrow-cta" viewbox="0 0 12 12">
#      <g fill="none" fill-rule="evenodd">
#       <path d="M-6-6h24v24H-6z">
#       </path>
#       <path d="M8.76 6.44L5.5 9.72a.6.6 0 0 0 0 .82c.2.2.6.22.82 0L11 5.85 6.3 1.17c-.27-.28-.6-.2-.82 0a.56.56 0 0 0 0 .82l3.28 3.28H1.62c-.4 0-.6.3-.6.58 0 .3.19.59.6.59h7.14z" fill="#151E27" stroke="#151E27" stroke-width=".3">
#       </path>
#      </g>
#     </symbol>
#     <symbol id="svg-icon-fiter-evolution" viewbox="0 0 12 11">
#      <path d="M8 9.33a1 1 0 00-1-1H5a1 1 0 100 2h2a1 1 0 001-1zm-7-7h10a1 1 0 000-2H1a1 1 0 000 2zm9 3a1 1 0 00-1-1H3a1 1 0 000 2h6a1 1 0 001-1z" fill="#0654ba" fill-rule="nonzero">
#      </path>
#     </symbol>
#     <symbol id="svg-icon-sort-evolution" viewbox="0 0 12 15">
#      <path d="M1.71 9c.2 0 .38.06.51.18l3.8 3.32 3.8-3.32a.8.8 0 01.97.03c.26.24.28.6.04.85l-4.3 3.76a.8.8 0 01-1.02 0l-4.3-3.76a.57.57 0 01-.15-.68A.73.73 0 011.7 9zM6.5 1.18l4.3 3.76c.2.18.27.44.15.68a.73.73 0 01-.65.38.78.78 0 01-.51-.18L5.98 2.5l-3.8 3.32a.8.8 0 01-.97-.03.57.57 0 01-.04-.85l4.3-3.76a.8.8 0 011.02 0z" fill-rule="evenodd" stroke-width=".5">
#      </path>
#     </symbol>
#     <symbol id="svg-icon-chevron-down" viewbox="0 0 12 7">
#      <path d="M6 5.31L1.138.205a.65.65 0 0 0-.943 0A.721.721 0 0 0 0 .672v.056c.007.17.072.338.195.467l5.334 5.6c.126.132.29.2.455.205h.032a.652.652 0 0 0 .455-.205l5.334-5.6A.714.714 0 0 0 12 .723V.677a.714.714 0 0 0-.195-.472.65.65 0 0 0-.944 0L6 5.31z">
#      </path>
#     </symbol>
#     <symbol id="svg-icon-chevron-left" viewbox="0 0 32 32">
#      <path d="M25.14 3.84L9.74 19.23l-3.26-3.27L21.88.57l3.26 3.27zM9.74 12.7l15.4 15.4-3.27 3.26-15.39-15.4 3.27-3.26zm0 6.53zm-3.26-3.27z">
#      </path>
#     </symbol>
#     <symbol id="svg-icon-chevron-right" viewbox="0 0 32 32">
#      <path d="M7.06 27.98l15.3-15.28 3.23 3.24L10.3 31.23l-3.24-3.25zm15.3-8.8L7.05 3.9 10.31.65 25.6 15.94l-3.25 3.24zm0-6.48zm3.24 3.24z">
#      </path>
#     </symbol>
#     <symbol id="svg-icon-chevron-up" viewbox="0 0 32 32">
#      <path d="M28.13 25.74l-15.4-15.39L16 7.1l15.4 15.39-3.27 3.26zm-8.86-15.39l-15.4 15.4-3.26-3.27L16 7.08l3.26 3.27zm-6.53 0zM16 7.1z">
#      </path>
#     </symbol>
#     <symbol id="svg-icon-chevron-light-left" viewbox="4 0 32 32">
#      <path d="M28.18 1.33a1.23 1.23 0 0 0-1.72 0L12.4 15.38c-.23.23-.39.54-.39.85s.16.63.39.86l13.58 13.59c.24.23.55.39.86.39s.62-.16.86-.4c.47-.46.47-1.24 0-1.71L14.99 16.24l13.19-13.2c.47-.46.47-1.24 0-1.71z">
#      </path>
#     </symbol>
#     <symbol id="svg-icon-chevron-light-right" viewbox="4 0 32 32">
#      <path d="M12.41 1.33a1.23 1.23 0 0 1 1.72 0l14.05 14.05c.23.23.39.54.39.85s-.16.63-.4.86L14.6 30.68c-.24.23-.55.39-.86.39s-.63-.16-.86-.4a1.23 1.23 0 0 1 0-1.71L25.6 16.24 12.4 3.04a1.23 1.23 0 0 1 0-1.71z">
#      </path>
#     </symbol>
#     <symbol id="svg-icon-confirmation" viewbox="0 0 32 32">
#      <path d="M16.009 32C7.167 32 0 24.832 0 15.991S7.168-.018 16.009-.018c8.842 0 16.009 7.168 16.009 16.009v.02c-.011 8.833-7.174 15.99-16.009 15.99zm0-29.681c-7.561 0-13.69 6.129-13.69 13.69s6.129 13.69 13.69 13.69 13.69-6.129 13.69-13.69-6.129-13.69-13.69-13.69z" fill="#5ba71b">
#      </path>
#      <path d="M14.841 23.448h-.004a.9789.9789 0 0 1-.646-.242l-6.232-5.305a.9847.9847 0 0 1-.347-.751c0-.545.442-.987.987-.987.245 0 .469.089.641.237l5.434 4.637 8.181-10.741c.183-.238.468-.39.788-.39.548 0 .992.444.992.992 0 .228-.077.438-.206.605l-8.81 11.573c-.137.199-.39.358-.682.389h-.116z" fill="#5ba71b">
#      </path>
#     </symbol>
#     <symbol id="svg-icon-close" viewbox="0 0 32 32">
#      <path d="M31.43 2.85L29.04.45l-13.08 13.1L2.87.44.5 2.86l13.08 13.08L.49 29l2.38 2.39 13.09-13.08L29.04 31.4 31.43 29 18.34 15.93z">
#      </path>
#     </symbol>
#     <symbol id="svg-icon-caution-null" viewbox="0 0 32 32">
#      <path d="M29.82 29.07H2.22c-.73 0-1.27-.26-1.54-.73-.26-.47-.2-1.07.16-1.68l13.74-22.9c.37-.61.88-.95 1.43-.95s1.07.34 1.43.95l13.74 22.9c.37.61.43 1.21.16 1.68-.26.47-.8.73-1.52.73zm-13.8-25.6c-.32 0-.62.23-.87.63L1.41 27c-.23.4-.29.76-.15 1.01s.49.4.95.4h27.6c.46 0 .8-.15.95-.4s.08-.61-.15-1L16.87 4.1c-.24-.41-.55-.63-.86-.63z">
#      </path>
#      <path d="M16.01 22c.3 0 .56.11.78.33.21.21.32.47.32.78s-.11.56-.34.77c-.22.22-.48.32-.76.32s-.53-.1-.76-.32c-.22-.21-.33-.47-.33-.77s.1-.57.32-.78c.21-.21.47-.32.77-.32zm1.05-5.69c0 2.29-.47 4.16-1.05 4.16s-1.04-1.87-1.04-4.16.47-4.16 1.04-4.16 1.05 1.87 1.05 4.16z">
#      </path>
#     </symbol>
#     <symbol id="svg-icon-information" viewbox="0 0 32 32">
#      <path d="M15.991 12.986c-.625 0-1.132.507-1.132 1.132v8.737c.074.56.548.987 1.122.987s1.048-.427 1.122-.981l.001-8.743c0-.618-.496-1.121-1.112-1.131zM17.401 9.146c0 .748-.606 1.354-1.354 1.354s-1.354-.606-1.354-1.354c0-.748.606-1.354 1.354-1.354s1.354.606 1.354 1.354z">
#      </path>
#      <path d="M15.991 32C7.149 32-.018 24.832-.018 15.991S7.15-.018 15.991-.018C24.833-.018 32 7.15 32 15.991v.02c-.011 8.833-7.174 15.99-16.009 15.99zm0-29.681c-7.561 0-13.69 6.129-13.69 13.69s6.129 13.69 13.69 13.69 13.69-6.129 13.69-13.69-6.129-13.69-13.69-13.69z">
#      </path>
#     </symbol>
#     <symbol id="svg-icon-mail" viewbox="0 0 36 32">
#      <path d="M35.98 5.776V5.62c0-.078-.078-.078-.078-.156v-.078c0-.078-.078-.078-.156-.078l-.078-.078c-.078 0-.078 0-.156-.078h-.156H5.307 5.073c-.078 0-.078 0-.156.078-.078 0-.078.078-.078.078-.078 0-.078.078-.156.078v.078c0 .078-.078.078-.078.156V26.069c0 .39.312.78.78.78h29.971c.39 0 .781-.312.781-.78V5.854c-.078 0-.078 0-.156-.078zM20.293 16.937L7.493 6.635h25.6l-12.8 10.302zM6.088 25.366V7.493l13.58 10.927s.078.078.156.078c.156.078.312.156.468.156s.312-.078.468-.156L34.497 7.493v17.873H6.087z">
#      </path>
#     </symbol>
#     <symbol id="svg-icon-menu" viewbox="0 0 32 32">
#      <path d="M32.31 7.5H8.27c-.62 0-1.17-.47-1.17-1.18s.55-1.17 1.17-1.17h24.04c.63 0 1.17.55 1.17 1.17s-.54 1.17-1.17 1.17zM32.31 26.85H8.27c-.62 0-1.17-.55-1.17-1.17s.55-1.17 1.17-1.17h24.04c.63 0 1.17.54 1.17 1.17s-.54 1.17-1.17 1.17zM32.31 16.86H8.27c-.62 0-1.17-.55-1.17-1.17s.55-1.17 1.17-1.17h24.04c.63 0 1.17.54 1.17 1.17s-.54 1.17-1.17 1.17z">
#      </path>
#     </symbol>
#     <symbol id="svg-icon-notifications" viewbox="0 0 40 32">
#      <path d="M20.37 32a2.95 2.95 0 0 0 2.97-2.89h-5.86a2.83 2.83 0 0 0 2.9 2.89zM35.75 25.91s-2.9-2.34-4.45-4.14c-1.25-1.48-1.25-3.35-1.25-5.77 0-3.2.08-7.26-3.6-11.24a10.46 10.46 0 0 0-4.67-2.89C21.7 1.1 21 .54 20.2.54s-1.4.55-1.56 1.33a10.07 10.07 0 0 0-4.68 2.89C10.3 8.74 10.3 12.8 10.38 16c0 2.42.08 4.3-1.25 5.77a37.17 37.17 0 0 1-4.45 4.14c-.31.24-.47.7-.31 1.1s.47.62.94.62h29.66c.39 0 .78-.24.93-.63.32-.39.16-.85-.15-1.09zm-15.38-.23H8.04c.86-.78 1.87-1.8 2.65-2.66 1.8-2.02 1.72-4.44 1.72-7.02 0-3.2-.08-6.48 3.12-9.91C17.56 3.82 20.3 3.5 20.3 3.5h.08s2.73.31 4.76 2.58c3.12 3.43 3.12 6.71 3.12 9.91 0 2.58-.07 5 1.72 7.02.78.86 1.8 1.88 2.65 2.66H20.38z">
#      </path>
#     </symbol>
#     <symbol id="svg-icon-priority" viewbox="0 0 32 32">
#      <path d="M16 19c-.63 0-1.14-.51-1.14-1.14V9.13l-.01-.15a1.13 1.13 0 1 1 2.25.15v8.73c0 .62-.5 1.12-1.1 1.13zM17.4 22.86a1.35 1.35 0 1 1-2.7 0 1.35 1.35 0 0 1 2.7 0z" fill="#dd1e31">
#      </path>
#      <path d="M16 32a16 16 0 1 1 16-16V16a16 16 0 0 1-16 16zm0-29.68a13.69 13.69 0 1 0-.01 27.38 13.69 13.69 0 0 0 0-27.38z" fill="#dd1e31">
#      </path>
#     </symbol>
#     <symbol id="svg-icon-profile" viewbox="0 0 32 32">
#      <path d="M13.64 1.8h4.72c4.65 0 5.3 5.36 5.3 5.36l-.01 6.98c0 .42-2.92 8.3-2.92 8.3l9.43 4.73s-1.69 2.94-3.54 2.94l-21.24.01c-1.8 0-3.54-2.95-3.54-2.95l9.47-4.78s-2.97-7.6-2.97-8.25l-.03-7.03s.9-5.32 5.33-5.32z">
#      </path>
#     </symbol>
#     <symbol id="svg-icon-search" viewbox="4 0 32 32">
#      <path d="M33.33 30.2l-6.8-6.79a10.8 10.8 0 0 0 2.5-6.94c-.07-6.01-4.99-11-11.08-11s-11 4.99-11 11 4.91 11.08 11 11.08a11.3 11.3 0 0 0 7.1-2.57l6.8 6.79c.23.23.46.3.7.3s.54-.07.7-.3c.47-.47.47-1.18.08-1.57zM9.05 16.47a8.9 8.9 0 1 1 17.8 0 8.96 8.96 0 0 1-8.9 8.97 8.91 8.91 0 0 1-8.9-8.97z">
#      </path>
#     </symbol>
#     <symbol id="svg-icon-settings" viewbox="0 0 32 32">
#      <path d="M29.386 18.233h-1.337c-.611 0-1.264.479-1.448 1.063l-.768 1.87c-.289.54-.169 1.341.261 1.773l.953.949a1.119 1.119 0 0 1 0 1.578l-1.581 1.577a1.118 1.118 0 0 1-1.576 0l-.947-.95c-.435-.431-1.233-.55-1.773-.257l-1.87.768c-.585.181-1.064.832-1.064 1.445v1.337c0 .611-.503 1.113-1.116 1.113h-2.232a1.119 1.119 0 0 1-1.116-1.113v-1.337c0-.613-.477-1.264-1.066-1.445l-1.87-.768c-.537-.293-1.336-.175-1.767.257l-.953.95a1.117 1.117 0 0 1-1.575 0l-1.582-1.577a1.12 1.12 0 0 1 0-1.578l.95-.949c.434-.431.552-1.233.261-1.773l-.77-1.87c-.179-.584-.827-1.063-1.444-1.065h-1.34A1.12 1.12 0 0 1 1.5 17.114v-2.232c0-.613.503-1.114 1.116-1.114l1.339.002c.616 0 1.264-.481 1.448-1.066l.766-1.87c.293-.541.174-1.337-.261-1.771l-.949-.95a1.119 1.119 0 0 1 0-1.578l1.579-1.577a1.117 1.117 0 0 1 1.575 0l.953.948c.434.434 1.229.553 1.771.261l1.867-.767c.588-.183 1.066-.835 1.066-1.448V2.615a1.12 1.12 0 0 1 1.116-1.117h2.232a1.12 1.12 0 0 1 1.116 1.117v1.337c0 .613.479 1.265 1.064 1.448l1.864.767c.544.292 1.343.172 1.775-.261l.951-.948a1.118 1.118 0 0 1 1.576 0l1.581 1.577a1.12 1.12 0 0 1 0 1.579l-.953.95c-.43.434-.55 1.23-.261 1.771l.768 1.867c.184.587.835 1.067 1.448 1.067h1.337c.616 0 1.114.502 1.114 1.114v2.235c0 .614-.497 1.116-1.113 1.116zm-13.383-7.409a5.176 5.176 0 1 0 0 10.352 5.176 5.176 0 1 0 0-10.352z">
#      </path>
#     </symbol>
#     <symbol id="svg-icon-star" viewbox="0 0 32 32">
#      <path d="M16 .85l4.61 9.98 10.53 1.66-7.57 7.76 1.84 10.9L16 25.98l-9.42 5.17 1.85-10.9-7.57-7.76 10.53-1.66 4.6-9.98z">
#      </path>
#     </symbol>
#     <symbol id="svg-icon-trash" viewbox="0 0 28 32">
#      <path d="M19.36 21.7c.46 0 .83-.33.89-.77v-7.26a.89.89 0 1 0-1.78 0v7.25c.06.45.43.79.88.79zM14.03 21.7c.46 0 .83-.33.89-.77v-7.26a.89.89 0 1 0-1.78 0v7.25c.05.45.43.79.88.79zM8.7 21.7c.45 0 .83-.33.88-.77v-7.26a.89.89 0 1 0-1.78 0v7.25c.06.45.43.79.89.79z">
#      </path>
#      <path d="M27.66 5.33h-6.2c0-1.77-.48-5.33-3.56-5.33h-7.38C7.47 0 6.97 3.56 6.97 5.33H.8a.89.89 0 1 0 0 1.78h1.67v19.15c0 2.18 2.06 5.74 4.25 5.74h14.93c2.19 0 3.86-3.56 3.86-5.74V7.1h2.11a.89.89 0 0 0 .04-1.78zM10.52 1.78h7.4c1.56 0 1.96 1.78 1.96 3.55H8.57c.02-1.77.4-3.55 1.96-3.55zM23.8 26.26c0 1.31-.76 3.96-2.08 3.96h-15c-1.32 0-2.45-2.65-2.45-3.96V7.1h19.55v19.15z">
#      </path>
#     </symbol>
#     <symbol id="svg-icon-view-detail" viewbox="0 0 32 32">
#      <path d="M30.5 19.19a.8.8 0 0 1-.8.8H2.2a.8.8 0 0 1-.8-.8V1.86c0-.44.36-.8.8-.8h27.5c.45 0 .8.36.8.8V19.2zM30.6 30.14a.8.8 0 0 1-.8.8H2.32a.8.8 0 0 1-.8-.8v-5.8c0-.44.36-.8.8-.8H29.8c.44 0 .8.36.8.8v5.8z">
#      </path>
#     </symbol>
#     <symbol id="svg-icon-view-grid" viewbox="0 0 32 32">
#      <path d="M14.06 13.27a.8.8 0 0 1-.8.8H2.23a.8.8 0 0 1-.8-.8V2.23c0-.44.37-.8.8-.8h11.05c.43 0 .8.36.8.8v11.04zM14.06 29.77a.8.8 0 0 1-.8.8H2.23a.8.8 0 0 1-.8-.8V18.73c0-.43.37-.8.8-.8h11.05c.43 0 .8.37.8.8v11.04zM30.57 13.27a.8.8 0 0 1-.8.8H18.73a.8.8 0 0 1-.8-.8V2.23c0-.44.37-.8.8-.8h11.04c.44 0 .8.36.8.8v11.04zM30.57 29.77a.8.8 0 0 1-.8.8H18.73a.8.8 0 0 1-.8-.8V18.73c0-.43.37-.8.8-.8h11.04c.44 0 .8.37.8.8v11.04z">
#      </path>
#     </symbol>
#     <symbol id="svg-icon-view-list" viewbox="0 0 32 32">
#      <path d="M8.2 7.86a.8.8 0 0 1-.8.8H1.6a.8.8 0 0 1-.8-.8v-5.8c0-.44.37-.8.8-.8h5.8c.44 0 .8.36.8.8v5.8zM31.2 7.86a.8.8 0 0 1-.8.8H12.26a.8.8 0 0 1-.8-.8v-5.8c0-.44.36-.8.8-.8H30.4c.43 0 .8.36.8.8v5.8zM8.2 18.9a.8.8 0 0 1-.8.8H1.6a.8.8 0 0 1-.8-.8v-5.8c0-.44.37-.8.8-.8h5.8c.44 0 .8.36.8.8v5.8zM31.2 18.9a.8.8 0 0 1-.8.8H12.26a.8.8 0 0 1-.8-.8v-5.8c0-.44.36-.8.8-.8H30.4c.43 0 .8.36.8.8v5.8zM8.2 29.94a.8.8 0 0 1-.8.8H1.6a.8.8 0 0 1-.8-.8v-5.8c0-.44.37-.8.8-.8h5.8c.44 0 .8.36.8.8v5.8zM31.2 29.94a.8.8 0 0 1-.8.8H12.26a.8.8 0 0 1-.8-.8v-5.8c0-.44.36-.8.8-.8H30.4c.43 0 .8.36.8.8v5.8z">
#      </path>
#     </symbol>
#     <symbol id="svg-icon-window" viewbox="0 0 36 32">
#      <path d="M.66 7.58h20.86c.37 0 .67.3.67.67v.95c0 .37-.3.67-.67.67H.66A.66.66 0 0 1 0 9.2v-.95c0-.37.3-.67.66-.67z">
#      </path>
#      <path d="M2.28 7.58V31.9H0V7.58h2.28zM26.97 17.96v13.26c0 .4-.33.73-.74.73h-.93a.74.74 0 0 1-.74-.73V17.96c0-.4.33-.73.74-.73h.93c.41 0 .74.33.74.73z">
#      </path>
#      <path d="M0 29.72h26.95V32H0v-2.28zM34.36.2h2.55v22.1h-2.55V.2z">
#      </path>
#      <path d="M36.9 0v2.55H14.8V0h22.1z">
#      </path>
#      <path d="M35.1-.02l1.8 1.8-19.03 19.04-1.8-1.8L35.1-.02z">
#      </path>
#     </symbol>
#     <symbol id="svg-icon-filters" viewbox="0 0 14 10">
#      <path d="M2.09 4.34h9.8c.26 0 .61.3.61.66 0 .37-.35.66-.62.66h-9.8c-.27 0-.58-.3-.58-.66 0-.37.31-.66.59-.66zm1.76 3.8h6.4c.2 0 .55.3.55.66 0 .37-.36.66-.55.66h-6.4c-.18 0-.55-.3-.55-.66 0-.37.37-.66.55-.66zm9.52-6.31H.63A.65.65 0 0 1 0 1.16C0 .8.28.5.63.5h12.74c.35 0 .63.3.63.66 0 .37-.28.67-.63.67z">
#      </path>
#     </symbol>
#     <symbol id="svg-icon-etrs-badge">
#      <path d="M9.336 16.984h-.993v-3.079l-.993-.993-.993.993v3.08h-.993a1.986 1.986 0 0 0-1.987 1.986v.993h7.946v-.993a1.986 1.986 0 0 0-1.987-1.987m1.192-8.343l1.39 5.264-4.568-3.774-4.569 3.774 1.39-5.164L0 5.264l5.364-.298L7.35 0l1.986 4.966 5.364.298-4.172 3.377">
#      </path>
#     </symbol>
#     <symbol id="svg-icon-rating-star" viewbox="0 0 16 16">
#      <path d="M8 0l2.4 5.28 5.6.8-4 4.16.96 5.76L8 13.28 3.04 16 4 10.24 0 6.08l5.6-.8z" fill="#f18e00">
#      </path>
#     </symbol>
#     <symbol id="svg-icon-rating-emptystar" viewbox="0 0 16 16">
#      <path d="M8 0l2.4 5.28 5.6.8-4 4.16.96 5.76L8 13.28 3.04 16 4 10.24 0 6.08l5.6-.8z" fill="#cccccc">
#      </path>
#     </symbol>
#     <symbol id="svg-icon-rating-halfstar" viewbox="0 0 16 16">
#      <path d="M8 13.28L3.04 16 4 10.24 0 6.08l5.6-.8L8 0z" fill="#f18e00">
#      </path>
#      <path d="M8 0l2.4 5.28 5.6.8-4 4.16.96 5.76L8 13.28z" fill="#cccccc">
#      </path>
#     </symbol>
#     <symbol id="svg-ebay-moneyback-guarantee" viewbox="0 0 20 24">
# ...
#   </script>
#   <script>
#    window.SFE && window.SFE.LazyLoading && window.SFE.LazyLoading.initialize(300);
#   </script>
#   <script>
#    !function(){"use strict";const e="data-defer-load",t=4;let r,n,i,o,a=0,d=0;function s(){let e=[],r=document.querySelectorAll(".s-item__image-wrapper img[data-defertimer]");for(let n=0;n<r.length&&n<t;n++)e.push(parseInt(r[n].getAttribute("data-defertimer")));return parseInt((e=>{e.sort((function(e,t){return e-t}));const t=Math.floor(e.length/2);return e.length%2?e[t]:(e[t-1]+e[t])/2})(e))}function l(){o=performance.now(),r=document.querySelectorAll("img["+e+"]")||[],d=r.length;let l=[];for(a=0;a<d;a++)n=r[a],i=n.getAttribute(e),null!==i&&(n.removeAttribute("onload"),n.setAttribute("src",i),n.removeAttribute(e),n.addEventListener("load",(e=>{let t=e.currentTarget;if(t){let e=t.getAttribute("style");t.setAttribute("style",`${e};width:auto`),80===t.width&&80===t.height&&window.SRP&&window.SRP.metrics&&window.SRP.metrics.incrementCounter("imageEmptyError")}})),a<t&&l.push(new Promise((e=>{n.addEventListener("load",(t=>{let r=t.currentTarget;r&&r.setAttribute("data-defertimer",parseInt(performance.now()-o)),e()}))}))));Promise.all(l).then((()=>{let e=new CustomEvent("site-speed-ebay.metricsData",{detail:{srp_deffered_atf:s()}});document.dispatchEvent(e)}))}addEventListener("load",l,!1),addEventListener("pageshow",(e=>{e.persisted&&l()}),!1)}();
#   </script>
#   <script src="https://ir.ebaystatic.com/rs/c/jquery-3.5.1.min.js">
#   </script>
#   <script src="https://ir.ebaystatic.com/rs/v/pab3fhsgku1p3hmalnaevuutkey.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    (function($){ if(typeof(GHFlyout) === 'function') { new GHFlyout("/gh/watchlist?modules=WATCH_LIST", "gh-wl-click", ""); } })(GH && GH.jQ); (function($){ if(typeof(GHFlyout) === 'function') { new GHFlyout("/gh/cart?modules=MINI_CART", "", "gh-minicart-hover"); } })(GH && GH.jQ); if(typeof GH!="undefined"&&GH){GH.urls={ autocomplete_js:0,fnet_js:"https://c.paypal.com/da/r/efbv3.js",ie8_js:"https://ir.ebaystatic.com/f/rbezfuzpu20wfd2kvejeb5adxyg.js",scandal_js:"https://ir.ebaystatic.com/cr/v/c1/ScandalJS-1.2.0-v4.min.js",widget_delivery_platform:"https://ir.ebaystatic.com/cr/v/c1/globalheader_widget_platform__v2-b70676194b.js",auto_tracking_widget:"https://ir.ebaystatic.com/cr/v/c01/45177f26-6a9c-414a-9e3e-b82519ececb6.min.js",web_resource_tracker:"https://ir.ebaystatic.com/rs/v/mjgerh5fmy51nnbwjoml1g1juqs.js",behavior_js_collection:"https://ir.ebaystatic.com/cr/v/c01/aW5ob3VzZWpzMTcwNjU2NzE0ODEwMg==-1.0.0.min.js" }; GH.GHSW={ raptor:0,sandbox:0,emp:0,ac1:0,ac2:0,ac3:0,ac4:0,ac5:0,ac6:0,hideMobile:0,langSwitch:0,pool:0,ALERT_POPUPOFF:0,NEWALERT_POPUPOFF:0,newprofile:0,desktop_new_profile_service:"true",UNLOAD_Firefox:0,UNLOAD_Chrome:0,UNLOAD_IE:0,UNLOAD_Safari:0,ENABLE_HTTPS:"true",SEARCH_PROM:"true",MINICART:0,STICKY_HEADER:0 }; } if(typeof GH!="undefined" && GH){GH_config={"lng":"es-ES","geoLang":"[]","suppressGeoUserUpdateInfo":"false","siteId":"186","xhrBaseUrl":"https://www.ebay.es","env":"production","risk_behavior_collection_interval":"{\"default\":15000,\"2507978\":5000,\"2500857\":5000}",sin:0,pageId:2334524,selectedCatId:'15032',fn:"",id:""};GH.init();}
#   </script>
#   <script src="https://ir.ebaystatic.com/cr/v/c1/ebay-cookies/1.js">
#   </script>
#   <script type="text/javascript">
#    (function(scope) {var trackingInfo = {"X_EBAY_C_CORRELATION_SESSION":"si=04a23cc518f0ab4a7cfe4dbbffedb879,c=1,operationId=2351460,trk-gflgs=wA**"};scope.trkCorrelationSessionInfo={};scope.trkCorrelationSessionInfo.getTrackingInfo=function(){return trackingInfo;};scope.trkCorrelationSessionInfo.getTrackingCorrelationSessionInfo=function(){return trackingInfo.X_EBAY_C_CORRELATION_SESSION};})(window)
#   </script>
#   <script type="text/javascript">
#    if(typeof raptor !== "undefined" && raptor.require){var Uri=raptor.require("ebay/legacy/utils/Uri");$uri=function(href){return new Uri(href);};window.raptor.extend(window.raptor, require("ebay/legacy/adaptor-utils"));}
#   </script>
#   <script id="taasHeaderRes" src="https://ir.ebaystatic.com/cr/v/c01/10341xh50yz21mhhydueu4m5wad.js" type="text/javascript">
#   </script>
#   <script id="taasContent" type="text/javascript">
#    try {new window.TaaSTrackingCore({"psi":"Aoj0LnIQ*","rover":{"imp":"/roverimp/0/0/9","clk":"/roverclk/0/0/9","uri":"https://rover.ebay.es"},"pid":"p2351460"});
# var _plsubtInp={"eventFamily":"DFLT","samplingRate":100, "pageLoadTime": new Date().getTime(), "pageId":2351460, "app":"Testapp", "disableImp":true};var _plsUBTTQ=[];var TaaSIdMapTrackerObj = new TaaSIdMapTracker();TaaSIdMapTrackerObj.roverService("https://rover.ebay.es/idmap/0?footer");} catch (err) { console && console.log && console.log(err); }
#   </script>
#   <script id="taasFooterRes" src="https://ir.ebaystatic.com/cr/v/c01/050424x45ab470b86468939d672.js" type="text/javascript">
#   </script>
#   <script>
#    /* ssgST: excluded from sampling */
#   </script>
#   <script>
#    if (window && window.SRP) {
#         window.SRP.plStrategyIndex = 10;
#     }
#   </script>
#   <script>
#    'use strict';
# (function(){var r=".srp-river-main li.s-item";var a;var i=false;if(window.MutationObserver){var e=function(e){e.forEach(function(e){if(e.type==="attributes"&&e.attributeName==="style"){document.querySelectorAll("iframe").forEach(function(e){if(e.src.indexOf("pbjikboenpfhbbejgkoklgkhjpfogcam")>-1||e.src.indexOf("amazon")>-1){e.parentNode.removeChild(e);document.getElementsByTagName("html")[0].style.marginTop=0;$(document).trigger("rover",{ex1:46118})}})}})};var n=function(e){return e===null||getComputedStyle(e).display==="none"};var t=function(){var e=window.SRP&&window.SRP.metrics&&window.SRP.metrics["static"];var t=e.riverItemCount;var r=document.querySelectorAll(".srp-river-results .s-item");var n=Array.prototype.slice.call(r);var a=n.some(function(e){if(e.offsetParent===null){if(e.hasChildNodes()&&!e.childNodes[0].classList.contains("s-item__hd")){return true}}});return a||r.length<t};var o=function(){var n=false;return function(e){var t;e=e||false;if(!e){window.localStorage.setItem("SRP.PLBTimestamp",new Date)}i=true;if(!n){t=new XMLHttpRequest;t.open("POST","./update",true);t.setRequestHeader("srt","01000900000050befdc98f729ce70a4e3fc6b00cad3dc5028bbf0dc386ff3e27be6b437c8c7fc0afbc71ab0272414da3676f5edda8f38519251b5d2e2456ab9fd03795845af9bcd70700d222aa0c8cd41958ac14108f57");var r={t:"plb",v:e?"0":"1",details:{strat:window.SRP.plStrategyIndex}};t.send(JSON.stringify(r));n=true;a&&a.disconnect()}}}();var s=function(e){var t=document.querySelector(r);e.forEach(function(e){if(n(t)){o()}})};var u=new MutationObserver(e);u.observe(document.getElementsByTagName("html")[0],{attributes:true});var l=document.querySelector(r);var c=document.querySelector("#mainContent")===null;if(!c){if(n(l)){o()}else{a=new MutationObserver(s);a.observe(l,{attributes:true,childList:true,subtree:true})}}window.addEventListener("load",function(){if(t()){o()}setTimeout(function(){var e;var t=window.localStorage;try{e=new Date(t.getItem("SRP.PLBTimestamp"))}catch(a){}if(t.getItem("SRP.PLBTimestamp")&&e){var r=new Date;var n=r-e;if(!i&&n>1e4){t.removeItem("SRP.PLBTimestamp");o(true)}}},3e3)})}})()
#   </script>
#   <!--M#s0-63-->
#   <div aria-labelledby="s0-63-0-dialog-dialog-title" aria-modal="true" class="lightbox-dialog s-hero-dialog lightbox-dialog--mask-fade" hidden="" role="dialog">
#    <div class="lightbox-dialog__window lightbox-dialog__window--animate">
#     <!--F#7-->
#     <button aria-label="Maximize Lightbox Dialog" class="lightbox-dialog__handle" type="button">
#     </button>
#     <!--F/-->
#     <div class="lightbox-dialog__header">
#      <!--F#16-->
#      <h2 class="lightbox-dialog__title" id="s0-63-0-dialog-dialog-title">
#      </h2>
#      <!--F/-->
#      <!--F#17-->
#      <button aria-label="Close dialog" class="icon-btn lightbox-dialog__close" type="button">
#       <svg aria-hidden="true" class="icon icon--close-16" focusable="false">
#        <defs>
#         <symbol id="icon-close-16" viewbox="0 0 16 16">
#          <path d="M2.293 2.293a1 1 0 0 1 1.414 0L8 6.586l4.293-4.293a1 1 0 1 1 1.414 1.414L9.414 8l4.293 4.293a1 1 0 0 1-1.414 1.414L8 9.414l-4.293 4.293a1 1 0 0 1-1.414-1.414L6.586 8 2.293 3.707a1 1 0 0 1 0-1.414Z">
#          </path>
#         </symbol>
#        </defs>
#        <use href="#icon-close-16">
#        </use>
#       </svg>
#      </button>
#      <!--F/-->
#     </div>
#     <div class="lightbox-dialog__main">
#      <!--F#11-->
#      <!--F#3-->
#      <div>
#      </div>
#      <div hidden="">
#       <div class="inline-notice inline-notice--attention">
#        <span class="inline-notice__header" id="s0-63-0-dialog-11-3-2-0-status">
#         <svg aria-hidden="true" class="icon icon--attention-filled-16" focusable="false">
#          <defs>
#           <symbol id="icon-attention-filled-16" viewbox="0 0 16 16">
#            <path d="M8 0a8 8 0 1 0 0 16A8 8 0 0 0 8 0Zm0 12a1 1 0 1 1 0-2 1 1 0 0 1 0 2Zm1-4a1 1 0 1 1-2 0V5a1 1 0 0 1 2 0v3Z">
#            </path>
#           </symbol>
#          </defs>
#          <use href="#icon-attention-filled-16">
#          </use>
#         </svg>
#        </span>
#        <span class="inline-notice__main">
#         <!--F#9-->
#         <p>
#         </p>
#         <!--F/-->
#        </span>
#       </div>
#      </div>
#      <!--F/-->
#      <!--F/-->
#     </div>
#    </div>
#   </div>
#   <!--M/-->
#   <!--M#s0-64-->
#   <noscript>
#   </noscript>
#   <!--M/-->
#   <!--M#s0-65-->
#   <script>
#    const __rendered = `${Date.now()}`;
#   </script>
#   <!--M/-->
#   <script>
#    $MC=(window.$MC||[]).concat({"o":{"l":1,"w":[["s0-60-0-2",0,{"model":{"keyword":"celulares","categoryId":"15032","refineCategories":[{"key":"Móviles y telefonía","value":"15032","selected":"selected"}],"searchFormFields":[{"name":"LH_TitleDesc","value":0},{"name":"_odkw","value":"celulares"},{"name":"_osacat","value":"15032"}]}},{"w":{}}],["s0-60-0-12-4",1,{"model":{"_type":"SearchIncludeDescExperienceModel","checkBox":{"_type":"TextualSelection","paramKey":"LH_TitleDesc","paramValue":true,"label":{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"Incluir descripción"}]},"uxComponentHint":"CHECKBOX"}}},{"f":1,"s":{"checked":false}}],["s0-60-0-12-8-0-1-2",2,{"model":{"_type":"SearchRefinementsModule","group":[{"_type":"Group","fieldId":"category","paramKey":"_sacat","label":{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"Categoría"}]},"selectionType":"SINGLE","expandInline":true,"entries":[{"_type":"Group","paramValue":"0","label":{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"Todos"}]},"action":{"_type":"Action","type":"NAV","name":"SEARCH","params":{"_from":"R40","_oac":"1","_nkw":"celulares"},"trackingList":[{"eventFamily":"LST","eventAction":"ACTN","actionKind":"NAVSRC","actionKinds":["NAVSRC"],"operationId":"2351460","flushImmediately":false,"eventProperty":{"moduledtl":"mi%3A4118%7Ciid%3A1%7Cselected%3A0%7Cglobal%3A1%7CaspectURLParam%3A_sacat%7Cli%3A8173%7Cluid%3A21%7C","pageci":"14f3b9ae-0077-11ef-b17c-66249c990f80","parentrq":"04a23cb318f0ab4a7cfe9862fffb6d2e"}},{"actionKind":"NAV","operationId":"2351460","flushImmediately":false,"eventProperty":{"sid":"p2351460.m4118.l9012"}}],"URL":"https://www.ebay.es/sch/i.html?_from=R40&_nkw=celulares&_oac=1"},"defaultChoice":true,"expandInline":true,"entries":[{"_type":"Group","selected":true,"paramValue":"15032","label":{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"Móviles y telefonía"}],"accessibilityText":"Categoría seleccionada"},"expandInline":true,"entries":[{"_type":"TextualSelection","paramValue":"9394","label":{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"Accesorios para móviles"}]},"action":{"_type":"Action","type":"NAV","name":"SEARCH","params":{"_from":"R40","_nkw":"celulares","_sacat":"9394"},"trackingList":[{"eventFamily":"LST","eventAction":"ACTN","actionKind":"NAVSRC","actionKinds":["NAVSRC"],"operationId":"2351460","flushImmediately":false,"eventProperty":{"moduledtl":"mi%3A4118%7Ciid%3A1%7Cselected%3A0%7Cglobal%3A1%7CaspectURLParam%3A_sacat%7Cli%3A8173%7Cluid%3A1%7C","pageci":"14f3b9ae-0077-11ef-b17c-66249c990f80","parentrq":"04a23cb318f0ab4a7cfe9862fffb6d2e"}},{"actionKind":"NAV","actionKinds":["NAV"],"operationId":"2351460","flushImmediately":false,"eventProperty":{"sid":"p2351460.m4118.l9012"}}],"URL":"https://www.ebay.es/sch/9394/i.html?_from=R40&_nkw=celulares"}},{"_type":"TextualSelection","paramValue":"9355","label":{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"Móviles y smartphones"}]},"action":{"_type":"Action","type":"NAV","name":"SEARCH","params":{"_from":"R40","_nkw":"celulares","_sacat":"9355"},"trackingList":[{"eventFamily":"LST","eventAction":"ACTN","actionKind":"NAVSRC","actionKinds":["NAVSRC"],"operationId":"2351460","flushImmediately":false,"eventProperty":{"moduledtl":"mi%3A4118%7Ciid%3A1%7Cselected%3A0%7Cglobal%3A1%7CaspectURLParam%3A_sacat%7Cli%3A8173%7Cluid%3A2%7C","pageci":"14f3b9ae-0077-11ef-b17c-66249c990f80","parentrq":"04a23cb318f0ab4a7cfe9862fffb6d2e"}},{"actionKind":"NAV","actionKinds":["NAV"],"operationId":"2351460","flushImmediately":false,"eventProperty":{"sid":"p2351460.m4118.l9012"}}],"URL":"https://www.ebay.es/sch/9355/i.html?_from=R40&_nkw=celulares"}},{"_type":"TextualSelection","paramValue":"43304","label":{"_type":"TextualDisplay","textSpans":[{"_type":"TextSpan","text":"Teléfonos móviles: recambios"}]},"action":{"_type":"Action","type":"NAV","name":"SEARCH","params":{"_from":"R40","_nkw":"celulares","_sac ...
#   </script>
#   <script src="https://ir.ebaystatic.com/rs/c/inception-jBL8999Y.js">
#   </script>
#   <script src="https://ir.ebaystatic.com/rs/c/search-page-large-m7dhFsgy.js">
#   </script>
#   <script>
#    $_mod.ready();
#   </script>
#  </body>
# </html>
# <!-- RcmdId srpnweb,RlogId t6pwvit%60d59%3Fjqpvtwmrce1(0aigu*w%60ut351%3E-18f04a23cb2-0x1003 -->
# <!-- SiteId: 186, Environment: production, AppName: srpnweb, PageId: 2334524 -->
# <script type="text/javascript">
#  (function(scope){var CosHeaders={"X_EBAY_C_TRACKING":"guid=04a23cc518f0ab4a7cfe4dbbffedb879,pageid=2334524,cobrandId=0","X_EBAY_C_ENDUSERCTX":"clientId=urn%3Aebay-marketplace-consumerid%3A13051638-8fe9-4380-8d03-c2b176530b4a,ip=90.104.111.199,userAgentAccept=*%2F*,userAgentAcceptEncoding=identity,userAgent=python-requests%2F2.26.0,uri=%2Fsch%2F15032%2Fi.html,applicationURL=https%3A%2F%2Fwww.ebay.es%2Fsch%2F15032%2Fi.html%3F_from%3DR40%26_nkw%3Dcelulares,xff=90.104.111.199%2C%202.21.132.69%2C2.16.142.14%2C10.191.76.108,isPiggybacked=false,expectSecureURL=true,physicalLocation=country%3DFR%2Czip%3D44560,contextualLocation=country%3DUS,origClientId=urn%3Aebay-marketplace-consumerid%3A13051638-8fe9-4380-8d03-c2b176530b4a"};scope.cosHeadersInfo={getCosHeaders:function(){return CosHeaders;},getTrackingHeaders:function(){return CosHeaders.X_EBAY_C_TRACKING;},getEndUserContext:function(){return CosHeaders.X_EBAY_C_ENDUSERCTX;}};})(window)
# </script>

# %% [markdown]
# Lo primero que vamos a hacer es extraer el nombre de todos los teléfonos móviles que tenemos en la página web.

# %%
# sacamos los nombres de los moviles
lista_nombre_movil = sopa_moviles.find_all("div", {"class": "s-item__title"})

# mostramos los resultados del método ".find_all()". Como dijimos al inicio este método nos va a devolver una lista
# Si lo exploramos un poco veremos que tenemos una lista de elemento y que tiene muchas cosas, pero si nos fijamos bien tenemos todos los nombres de los teléfonos que tenemos en la página web
print("El resultado del método '.find_all()' es: \n",   lista_nombre_movil)

# es el momento de sacar la información útil del método que hemos usado previamente. Para eso lo primero que vamos a hacer es crearnos una lista donde iremos almacenado los resultados que queremos
nombres_productos = []

# dado que es una lista lo que vamos a hacer es iterar por la lista para poder acceder a cada uno de los elementos
for i in lista_nombre_movil:
    # utilizamos el método ".getText()" para sacar el texto de cada uno de los elementos y lo apendeamos a la lista que hemos creado previamente. 
    nombres_productos.append(i.getText())

print("\n--------------------------\n")

print("Los resultados de extraer el texto de cada uno de los elementos es:\n", nombres_productos)
# Out:
# El resultado del método '.find_all()' es:
#  [<div class="s-item__title"><span aria-level="3" role="heading"><!--F#f_0-->Shop on eBay<!--F/--></span></div>, <div class="s-item__title"><span aria-level="3" role="heading"><!--F#f_0-->Smartphone 2024 OUKITEL WP32 Exterior Android 13 12GB+128GB/1TB Exterior Práctico NFC<!--F/--></span></div>, <div class="s-item__title"><span aria-level="3" role="heading"><!--F#f_0-->(Desbloqueado) Teléfono Celular Android Infinix Note 40 Pro 8 GB + 256 GB VERDE Doble SIM<!--F/--></span></div>, <div class="s-item__title"><span aria-level="3" role="heading"><!--F#f_0-->DOOGEE S40/S40Pro 4G Red Exterior Smartphone 2/4GB+16/64GB Android 10 Móvil<!--F/--></span></div>, <div class="s-item__title"><span aria-level="3" role="heading"><!--F#f_0-->OUKITEL C35 Smartphone sin contrato 24 GB+256 GB Android 13 móvil 5150mAh<!--F/--></span></div>, <div class="s-item__title"><span aria-level="3" role="heading"><!--F#f_0-->Colección de móviles Nokia 3310 3110 5110 6110 6210<!--F/--></span></div>, <div class="s-item__title"><span aria-level="3" role="heading"><!--F#f_0-->Smartphone Sonim XP8 XP8800 64GB Verizon GSM Desbloqueado Resistente Doble SIM Muy Bueno<!--F/--></span></div>, <div class="s-item__title"><span aria-level="3" role="heading"><!--F#f_0--><span class="LIGHT_HIGHLIGHT">Anuncio nuevo</span><!--F/--><!--F#f_0-->Smartphone UnihertzJellyPro4G - 2GB RAM, 16GB ROM - Android 8.1 - Azul - Modelo JP<!--F/--></span></div>, <div class="s-item__title"><span aria-level="3" role="heading"><!--F#f_0-->Celulares 2021 desbloqueado para 4,4,2 doble SIM baratos súper teléfono inteligente<!--F/--></span></div>, <div class="s-item__title"><span aria-level="3" role="heading"><!--F#f_0--><span class="LIGHT_HIGHLIGHT">Anuncio nuevo</span><!--F/--><!--F#f_0-->Smartphone Pinephone Pine64 64 Desbloqueado 3GB RAM, 32GB eMMC Linux<!--F/--></span></div>, <div class="s-item__title"><span aria-level="3" role="heading"><!--F#f_0-->TOTALMENTE NUEVO SAMSUNG GT-S5611 TELÉFONO GRATUITO SIM - BLUETOOTH - CÁMARA DE 5 MP - 3G - RADIO<!--F/--></span></div>, <div class="s-item__title"><span aria-level="3" role="heading"><!--F#f_0-->DOOGEE X97 6,0 pulgadas 4G Smartphone 3 GB + 16 GB barato Android 12 móvil sin contrato<!--F/--></span></div>, <div class="s-item__title"><span aria-level="3" role="heading"><!--F#f_0-->Teléfono celular I14pro desbloqueado 6,1 pulgadas 4 GB RAM 32 GB ROM<!--F/--></span></div>, <div class="s-item__title"><span aria-level="3" role="heading"><!--F#f_0-->Nuevo teléfono celular i15 Pro Max 7,3" Android 16 GB + 1 TB 5G desbloqueado globalmente<!--F/--></span></div>, <div class="s-item__title"><span aria-level="3" role="heading"><!--F#f_0-->10000mAh DOOGEE S88 Plus 8 GB + 128 GB Android Outdoor Smartphone sin contrato móvil<!--F/--></span></div>, <div class="s-item__title"><span aria-level="3" role="heading"><!--F#f_0-->Teléfono inteligente OUKITEL C35 24 GB + 256 GB Android 13 práctico 6,56 pulgadas 5150mAh 4G doble SIM<!--F/--></span></div>, <div class="s-item__title"><span aria-level="3" role="heading"><!--F#f_0-->Smartphone DOOGEE S40/S40Pro Doble 4G para exteriores 2/4GB+16/64GB Android 10 Práctico NFC<!--F/--></span></div>, <div class="s-item__title"><span aria-level="3" role="heading"><!--F#f_0--><span class="LIGHT_HIGHLIGHT">Anuncio nuevo</span><!--F/--><!--F#f_0-->Smartphone Samsung Galaxy A13 Azul (2022) SM-A135U1/DS - Usado Para Piezas Como Está<!--F/--></span></div>, <div class="s-item__title"><span aria-level="3" role="heading"><!--F#f_0--><span class="LIGHT_HIGHLIGHT">Anuncio nuevo</span><!--F/--><!--F#f_0-->Celulares Motorola i335 Nextel resistentes en caja abierta coleccionables<!--F/--></span></div>, <div class="s-item__title"><span aria-level="3" role="heading"><!--F#f_0-->DOOGEE X95 2 GB + 16 GB Smartphone sin contrato barato DUAL 4G SIM móvil 4350mAh<!--F/--></span></div>, <div class="s-item__title"><span aria-level="3" role="heading"><!--F#f_0-->Teléfono celular resistente Global OUKITEL WP36 10600mAh 16 GB + 128 GB ocho núcleos 13 MP NFC IP68 ...
#
# --------------------------
#
# Los resultados de extraer el texto de cada uno de los elementos es:
#  ['Shop on eBay', 'Smartphone 2024 OUKITEL WP32 Exterior Android 13 12GB+128GB/1TB Exterior Práctico NFC', '(Desbloqueado) Teléfono Celular Android Infinix Note 40 Pro 8 GB + 256 GB VERDE Doble SIM', 'DOOGEE S40/S40Pro 4G Red Exterior Smartphone 2/4GB+16/64GB Android 10 Móvil', 'OUKITEL C35 Smartphone sin contrato 24 GB+256 GB Android 13 móvil 5150mAh', 'Colección de móviles Nokia 3310 3110 5110 6110 6210', 'Smartphone Sonim XP8 XP8800 64GB Verizon GSM Desbloqueado Resistente Doble SIM Muy Bueno', 'Anuncio nuevoSmartphone UnihertzJellyPro4G - 2GB RAM, 16GB ROM - Android 8.1 - Azul - Modelo JP', 'Celulares 2021 desbloqueado para 4,4,2 doble SIM baratos súper teléfono inteligente', 'Anuncio nuevoSmartphone Pinephone Pine64 64 Desbloqueado 3GB RAM, 32GB eMMC Linux', 'TOTALMENTE NUEVO SAMSUNG GT-S5611 TELÉFONO GRATUITO SIM - BLUETOOTH - CÁMARA DE 5 MP - 3G - RADIO', 'DOOGEE X97 6,0 pulgadas 4G Smartphone 3 GB + 16 GB barato Android 12 móvil sin contrato', 'Teléfono celular I14pro desbloqueado 6,1 pulgadas 4 GB RAM 32 GB ROM', 'Nuevo teléfono celular i15 Pro Max 7,3" Android 16 GB + 1 TB 5G desbloqueado globalmente', '10000mAh DOOGEE S88 Plus 8 GB + 128 GB Android Outdoor Smartphone sin contrato móvil', 'Teléfono inteligente OUKITEL C35 24 GB + 256 GB Android 13 práctico 6,56 pulgadas 5150mAh 4G doble SIM', 'Smartphone DOOGEE S40/S40Pro Doble 4G para exteriores 2/4GB+16/64GB Android 10 Práctico NFC', 'Anuncio nuevoSmartphone Samsung Galaxy A13 Azul (2022) SM-A135U1/DS - Usado Para Piezas Como Está', 'Anuncio nuevoCelulares Motorola i335 Nextel resistentes en caja abierta coleccionables', 'DOOGEE X95 2 GB + 16 GB Smartphone sin contrato barato DUAL 4G SIM móvil 4350mAh', 'Teléfono celular resistente Global OUKITEL WP36 10600mAh 16 GB + 128 GB ocho núcleos 13 MP NFC IP68', 'Anuncio nuevoNUEVO Realme Note 50 4GB+128GB AZUL Versión Global Teléfono celular Android con doble SIM', 'Anuncio nuevoSmartphone Samsung Galaxy A8 Desbloqueado Android Gris Funciona Buen Estado', 'Anuncio nuevoNUEVO Realme Note 50 4GB+128GB NEGRO Versión Global Teléfono celular Android con doble SIM', 'Anuncio nuevoNokia C22 64GB Dual-SIM Charcoal Black, nuevo solo sin embalaje', 'DOOGEE S88 Pro Outdoor Smartphone 6 GB + 128 GB 10000mAh móvil Android sin contrato', 'Smartphone 2024 OUKITEL WP19 Pro Outdoor Práctico 22000mAh 24GB+256GB Android 13 ', '(Lote de 5) Teléfono celular inalámbrico SCHOK Volt SV55 Assurance negro 16 g', 'Anuncio nuevoSmartphone TCL 30 XE 5g Triple Cámara 64GB GSM Desbloqueado en Todo el Mundo', 'Móvil OUKITEL WP32 sin contrato 12 GB + 128 GB 5,93" Android 13 NFC/OTG/GPS/Face ID', 'Smartphone robusto DOOGEE S88-PLUS 6,3 pulgadas 8GB + 128GB 10000mAh Android 10 móvil', 'UMIDIGI BISON 2/BISON 2 PRO 128 GB 256 GB Smartphone móvil Android contrato móvil', 'DOOGEE S40 Pro Outdoor Smartphone sin contrato, 4 GB + 64 GB doble SIM 4G IP68 móvil', 'Anuncio nuevoSmartphone Samsung Galaxy A6 (2018) SM-A600FN Negro - Usado Para Piezas Tal cual', 'Anuncio nuevoNuevo Smartphone 2024 Desbloqueado i15 Pro Max 7.3" 4G 5G Android Doble SIM Teléfonos Celulares', 'Anuncio nuevoTeléfono Celular Nothing Phone 2(a) 5G NEGRO 12GB+256GB Doble SIM Desbloqueado Android', ' Teléfono Móvil Desbloqueado Original NOKIA N95 8 GB 3G 5 MP Wifi GPS 2,8"" Pantalla GSM', 'Anuncio nuevoTeléfono celular Nokia 3560 muy raro sin tarjeta SIM encendido', 'Anuncio nuevoTeléfono celular 11.0 desbloqueado de 5,72 pulgadas 2 GB 16 GB teléfonos inteligentes octa núcleos con doble', 'UMIDIGI A13S 32 GB 64 GB Smartphone Dual SIM Android móvil sin contrato', 'Smartphone Sonim XP10 XP9900 5G AT&T GSM 🙂 Desbloqueado Resistente Android 128GB 50MP', 'Nuevo móvil sin contrato Android Smartphone barato 4G doble SIM cuatro núcleos 16 GB 2024', 'Anuncio nuevoTeléfono Celular Jethro SC330 Negro/Plateado 3G Senior Abatible', 'Anuncio nuevoLote de 18 Celulares -Mixto- LG, Samsung, iPhone, Motorola **LEER** SOLO PARA REPUESTOS', 'Nokia N95 - bronce (desbloqueado) teléfono inteligente', 'Anuncio nuevoTe ...

# %% [markdown]
# Seguimos extrayendo más información, ahora es el momento de sacar los precios.

# %%
# sacamos los precios usando el método ".find_all()"
lista_precios_moviles = sopa_moviles.find_all("span", {"class": "s-item__price"})
print("El resultado del método '.find_all()' es: \n",   lista_precios_moviles)

# creamos una lista vacía donde almacenaremos todos los precios que hemos extraído de la página web
precios_productos = []

# de la misma forma que con los nombres de productos, vamos a iterar por la lista para sacar todos los precios
for i in lista_precios_moviles:
    # usando el método ".getText()" sacamos el precio
    precios_productos.append(i.getText())

print("\n--------------------------\n")

print("Los resultados de extraer el texto de cada uno de los elementos es:\n", precios_productos)
# Out:
# El resultado del método '.find_all()' es:
#  [<span class="s-item__price"><!--F#f_0--><!--F#f_0-->$20.00<!--F/--><!--F/--></span>, <span class="s-item__price"><!--F#f_0--><!--F#f_0-->131,08 EUR<!--F/--><!--F/--></span>, <span class="s-item__price"><!--F#f_0--><!--F#f_0--><span class="ITALIC">399,25 EUR</span><!--F/--><!--F/--></span>, <span class="s-item__price"><!--F#f_0--><!--F#f_0-->79,66 EUR<!--F/--><!--F/--></span>, <span class="s-item__price"><!--F#f_0--><!--F#f_0-->151,25 EUR<!--F/--><!--F/--></span>, <span class="s-item__price"><!--F#f_0--><!--F#f_0-->25,50 EUR<!--F/--><!--F/--></span>, <span class="s-item__price"><!--F#f_0--><!--F#f_0--><span class="ITALIC">101,21 EUR</span><!--F/--><!--F/--></span>, <span class="s-item__price"><!--F#f_0--><!--F#f_0--><span class="ITALIC">151,81 EUR</span><!--F/--><!--F/--></span>, <span class="s-item__price"><!--F#f_0--><!--F#f_0--><span class="ITALIC">53,32 EUR</span><!--F/--><!--F#f_0--><span class="DEFAULT ITALIC"> a </span><!--F/--><!--F#f_0--><span class="ITALIC">54,69 EUR</span><!--F/--><!--F/--></span>, <span class="s-item__price"><!--F#f_0--><!--F#f_0--><span class="ITALIC">112,46 EUR</span><!--F/--><!--F/--></span>, <span class="s-item__price"><!--F#f_0--><!--F#f_0--><span class="ITALIC">73,40 EUR</span><!--F/--><!--F/--></span>, <span class="s-item__price"><!--F#f_0--><!--F#f_0-->49,92 EUR<!--F/--><!--F/--></span>, <span class="s-item__price"><!--F#f_0--><!--F#f_0--><span class="ITALIC">58,49 EUR</span><!--F/--><!--F#f_0--><span class="DEFAULT ITALIC"> a </span><!--F/--><!--F#f_0--><span class="ITALIC">59,14 EUR</span><!--F/--><!--F/--></span>, <span class="s-item__price"><!--F#f_0--><!--F#f_0--><span class="ITALIC">156,26 EUR</span><!--F/--><!--F#f_0--><span class="DEFAULT ITALIC"> a </span><!--F/--><!--F#f_0--><span class="ITALIC">179,94 EUR</span><!--F/--><!--F/--></span>, <span class="s-item__price"><!--F#f_0--><!--F#f_0-->140,17 EUR<!--F/--><!--F/--></span>, <span class="s-item__price"><!--F#f_0--><!--F#f_0-->151,25 EUR<!--F/--><!--F/--></span>, <span class="s-item__price"><!--F#f_0--><!--F#f_0-->79,66 EUR<!--F/--><!--F/--></span>, <span class="s-item__price"><!--F#f_0--><!--F#f_0--><span class="ITALIC">37,49 EUR</span><!--F/--><!--F/--></span>, <span class="s-item__price"><!--F#f_0--><!--F#f_0--><span class="ITALIC">39,35 EUR</span><!--F/--><!--F/--></span>, <span class="s-item__price"><!--F#f_0--><!--F#f_0-->49,41 EUR<!--F/--><!--F/--></span>, <span class="s-item__price"><!--F#f_0--><!--F#f_0--><span class="ITALIC">189,82 EUR</span><!--F/--><!--F/--></span>, <span class="s-item__price"><!--F#f_0--><!--F#f_0--><span class="ITALIC">183,32 EUR</span><!--F/--><!--F/--></span>, <span class="s-item__price"><!--F#f_0--><!--F#f_0--><span class="ITALIC">58,48 EUR</span><!--F/--><!--F/--></span>, <span class="s-item__price"><!--F#f_0--><!--F#f_0--><span class="ITALIC">183,32 EUR</span><!--F/--><!--F/--></span>, <span class="s-item__price"><!--F#f_0--><!--F#f_0-->59,95 EUR<!--F/--><!--F/--></span>, <span class="s-item__price"><!--F#f_0--><!--F#f_0-->126,15 EUR<!--F/--><!--F/--></span>, <span class="s-item__price"><!--F#f_0--><!--F#f_0-->292,43 EUR<!--F/--><!--F/--></span>, <span class="s-item__price"><!--F#f_0--><!--F#f_0--><span class="ITALIC">123,70 EUR</span><!--F/--><!--F/--></span>, <span class="s-item__price"><!--F#f_0--><!--F#f_0--><span class="ITALIC">133,83 EUR</span><!--F/--><!--F/--></span>, <span class="s-item__price"><!--F#f_0--><!--F#f_0-->131,08 EUR<!--F/--><!--F/--></span>, <span class="s-item__price"><!--F#f_0--><!--F#f_0-->127,05 EUR<!--F/--><!--F/--></span>, <span class="s-item__price"><!--F#f_0--><!--F#f_0-->196,34 EUR<!--F/--><!--F#f_0--><span class="DEFAULT"> a </span><!--F/--><!--F#f_0-->272,26 EUR<!--F/--><!--F/--></span>, <span class="s-item__price"><!--F#f_0--><!--F#f_0-->79,66 EUR<!--F/--><!--F/--></span>, <span class="s-item__price"><!--F#f_0--><!--F#f_0--><span class="ITALIC">16,87 EUR</span><!--F/--><!--F/--></span>, <span class="s-item__price"><!--F#f_0--><!--F#f_0--><span class="ITALIC">13 ...
#
# --------------------------
#
# Los resultados de extraer el texto de cada uno de los elementos es:
#  ['$20.00', '131,08 EUR', '399,25 EUR', '79,66 EUR', '151,25 EUR', '25,50 EUR', '101,21 EUR', '151,81 EUR', '53,32 EUR a 54,69 EUR', '112,46 EUR', '73,40 EUR', '49,92 EUR', '58,49 EUR a 59,14 EUR', '156,26 EUR a 179,94 EUR', '140,17 EUR', '151,25 EUR', '79,66 EUR', '37,49 EUR', '39,35 EUR', '49,41 EUR', '189,82 EUR', '183,32 EUR', '58,48 EUR', '183,32 EUR', '59,95 EUR', '126,15 EUR', '292,43 EUR', '123,70 EUR', '133,83 EUR', '131,08 EUR', '127,05 EUR', '196,34 EUR a 272,26 EUR', '79,66 EUR', '16,87 EUR', '134,95 EUR a 191,18 EUR', '593,81 EUR', '58,98 EUR', '22,48 EUR', '54,77 EUR', '100,43 EUR a 100,83 EUR', '415,56 EUR', '45,60 EUR a 65,66 EUR', '44,97 EUR', '31,45 EUR', '46,11 EUR', '593,81 EUR', '99,71 EUR', '94,09 EUR', '22,48 EUR', '36,55 EUR', '72,88 EUR', '16,87 EUR', '65,55 EUR', '99,82 EUR a 110,91 EUR', '157,44 EUR', '44,93 EUR', '56,22 EUR', '23,61 EUR', '29,00 EUR', '45,94 EUR a 50,98 EUR', '53,55 EUR', '41,94 EUR', '53,99 EUR', '33,73 EUR', '56,22 EUR', '23,61 EUR', '17,81 EUR', '94,47 EUR a 246,30 EUR', '44,99 EUR', '69,58 EUR', '44,97 EUR', '9,36 EUR', '57,35 EUR a 59,36 EUR', '76,48 EUR', '98,73 EUR', '563,70 EUR', '140,17 EUR']

# %% [markdown]
# Si nos fijamos ya tenemos los precios de todos los teléfonos móviles, pero vemos que estos datos están en formato *string* y en realidad nos interesa que estén en formato de número por lo que tendremos que:
#
# - Eliminar la palabra "EUR"
#
# - Reemplazar las "," por ".", ya que en Python los números decimales deben ir con "."
#
# - eliminar caracteres espaciales que no me sirvan!
#
# Pongamonos manos a la obra, para eso lo vamos a hacer con una *list comprehension* para recordarlas.

# %%
# creamos una list comprehension para tener los datos en el formato correcto
precios_productos = [float(precio.split()[0].replace(".", "").replace(",", ".").replace("$","")) for precio in precios_productos]
print("Los resultados después de limpiar la información contenida en la lista 'precios_productos' es:\n", precios_productos)
# Out:
# Los resultados después de limpiar la información contenida en la lista 'precios_productos' es:
#  [2000.0, 131.08, 399.25, 79.66, 151.25, 25.5, 101.21, 151.81, 53.32, 112.46, 73.4, 49.92, 58.49, 156.26, 140.17, 151.25, 79.66, 37.49, 39.35, 49.41, 189.82, 183.32, 58.48, 183.32, 59.95, 126.15, 292.43, 123.7, 133.83, 131.08, 127.05, 196.34, 79.66, 16.87, 134.95, 593.81, 58.98, 22.48, 54.77, 100.43, 415.56, 45.6, 44.97, 31.45, 46.11, 593.81, 99.71, 94.09, 22.48, 36.55, 72.88, 16.87, 65.55, 99.82, 157.44, 44.93, 56.22, 23.61, 29.0, 45.94, 53.55, 41.94, 53.99, 33.73, 56.22, 23.61, 17.81, 94.47, 44.99, 69.58, 44.97, 9.36, 57.35, 76.48, 98.73, 563.7, 140.17]

# %%
# Es el turno de sacar el tipo de envío que tiene los productos 
lista_envio_moviles = sopa_moviles.find_all("span", {"class": "s-item__shipping s-item__logisticsCost"})
print("Los resultados de extraer el texto de cada uno de los elementos es:\n", lista_envio_moviles)


# igual que en todos los pasos anteriores, iteramos por la lista. Pero en este caso lo vamos a hacer usando una list comprehension

tipo_envio = [i.getText() for i in lista_envio_moviles]

print("\n--------------------------\n")

print("Los resultados de extraer el texto de cada uno de los elementos es:\n", tipo_envio)
# Out:
# Los resultados de extraer el texto de cada uno de los elementos es:
#  [<span class="s-item__shipping s-item__logisticsCost"><!--F#f_0-->Envío no especificado<!--F/--></span>, <span class="s-item__shipping s-item__logisticsCost"><!--F#f_0-->Envío internacional gratis<!--F/--></span>, <span class="s-item__shipping s-item__logisticsCost"><!--F#f_0-->Envío no especificado<!--F/--></span>, <span class="s-item__shipping s-item__logisticsCost"><!--F#f_0-->Envío no especificado<!--F/--></span>, <span class="s-item__shipping s-item__logisticsCost"><!--F#f_0-->+ 14,00 EUR de envío<!--F/--></span>, <span class="s-item__shipping s-item__logisticsCost"><!--F#f_0--><span class="ITALIC">+ 23,09 EUR de envío</span><!--F/--></span>, <span class="s-item__shipping s-item__logisticsCost"><!--F#f_0-->Envío internacional gratis<!--F/--></span>, <span class="s-item__shipping s-item__logisticsCost"><!--F#f_0-->Envío internacional gratis<!--F/--></span>, <span class="s-item__shipping s-item__logisticsCost"><!--F#f_0--><span class="ITALIC">+ 23,43 EUR de envío</span><!--F/--></span>, <span class="s-item__shipping s-item__logisticsCost"><!--F#f_0--><span class="ITALIC">+ 13,91 EUR de envío estimado</span><!--F/--></span>, <span class="s-item__shipping s-item__logisticsCost"><!--F#f_0-->Envío no especificado<!--F/--></span>, <span class="s-item__shipping s-item__logisticsCost"><!--F#f_0-->Envío internacional gratis<!--F/--></span>, <span class="s-item__shipping s-item__logisticsCost"><!--F#f_0-->Envío internacional gratis<!--F/--></span>, <span class="s-item__shipping s-item__logisticsCost"><!--F#f_0-->+ 10,07 EUR de envío<!--F/--></span>, <span class="s-item__shipping s-item__logisticsCost"><!--F#f_0-->Envío no especificado<!--F/--></span>, <span class="s-item__shipping s-item__logisticsCost"><!--F#f_0-->Envío no especificado<!--F/--></span>, <span class="s-item__shipping s-item__logisticsCost"><!--F#f_0--><span class="ITALIC">+ 11,25 EUR de envío</span><!--F/--></span>, <span class="s-item__shipping s-item__logisticsCost"><!--F#f_0--><span class="ITALIC">+ 21,27 EUR de envío</span><!--F/--></span>, <span class="s-item__shipping s-item__logisticsCost"><!--F#f_0-->Envío no especificado<!--F/--></span>, <span class="s-item__shipping s-item__logisticsCost"><!--F#f_0-->Envío internacional gratis<!--F/--></span>, <span class="s-item__shipping s-item__logisticsCost"><!--F#f_0-->Envío internacional gratis<!--F/--></span>, <span class="s-item__shipping s-item__logisticsCost"><!--F#f_0--><span class="ITALIC">+ 21,83 EUR de envío</span><!--F/--></span>, <span class="s-item__shipping s-item__logisticsCost"><!--F#f_0-->Envío internacional gratis<!--F/--></span>, <span class="s-item__shipping s-item__logisticsCost"><!--F#f_0-->+ 5,40 EUR de envío<!--F/--></span>, <span class="s-item__shipping s-item__logisticsCost"><!--F#f_0-->Envío no especificado<!--F/--></span>, <span class="s-item__shipping s-item__logisticsCost"><!--F#f_0-->Envío no especificado<!--F/--></span>, <span class="s-item__shipping s-item__logisticsCost"><!--F#f_0--><span class="ITALIC">+ 23,75 EUR de envío</span><!--F/--></span>, <span class="s-item__shipping s-item__logisticsCost"><!--F#f_0--><span class="ITALIC">+ 24,06 EUR de envío</span><!--F/--></span>, <span class="s-item__shipping s-item__logisticsCost"><!--F#f_0-->+ 9,98 EUR de envío<!--F/--></span>, <span class="s-item__shipping s-item__logisticsCost"><!--F#f_0-->Envío no especificado<!--F/--></span>, <span class="s-item__shipping s-item__logisticsCost"><!--F#f_0-->Envío internacional gratis<!--F/--></span>, <span class="s-item__shipping s-item__logisticsCost"><!--F#f_0-->Envío no especificado<!--F/--></span>, <span class="s-item__shipping s-item__logisticsCost"><!--F#f_0--><span class="ITALIC">+ 14,06 EUR de envío</span><!--F/--></span>, <span class="s-item__shipping s-item__logisticsCost"><!--F#f_0-->Envío internacional gratis<!--F/--></span>, <span class="s-item__shipping s-item__logisticsCost"><!--F#f_0-->Envío internacional gratis<!--F/--></span>, <span class="s-item__shipping s-item__logisticsCost"><!-- ...
#
# --------------------------
#
# Los resultados de extraer el texto de cada uno de los elementos es:
#  ['Envío no especificado', 'Envío internacional gratis', 'Envío no especificado', 'Envío no especificado', '+\xa014,00 EUR de envío', '+\xa023,09 EUR de envío', 'Envío internacional gratis', 'Envío internacional gratis', '+\xa023,43 EUR de envío', '+ 13,91 EUR de envío estimado', 'Envío no especificado', 'Envío internacional gratis', 'Envío internacional gratis', '+\xa010,07 EUR de envío', 'Envío no especificado', 'Envío no especificado', '+\xa011,25 EUR de envío', '+\xa021,27 EUR de envío', 'Envío no especificado', 'Envío internacional gratis', 'Envío internacional gratis', '+\xa021,83 EUR de envío', 'Envío internacional gratis', '+\xa05,40 EUR de envío', 'Envío no especificado', 'Envío no especificado', '+\xa023,75 EUR de envío', '+\xa024,06 EUR de envío', '+\xa09,98 EUR de envío', 'Envío no especificado', 'Envío internacional gratis', 'Envío no especificado', '+\xa014,06 EUR de envío', 'Envío internacional gratis', 'Envío internacional gratis', 'Envío internacional gratis', '+\xa023,02 EUR de envío', '+\xa02,78 EUR de envío', 'Envío internacional gratis', '+\xa032,37 EUR de envío', '+\xa013,10 EUR de envío', '+\xa018,07 EUR de envío', '+\xa072,92 EUR de envío', 'Envío internacional gratis', 'Envío internacional gratis', 'Envío internacional gratis', '+\xa03,37 EUR de envío', '+\xa023,02 EUR de envío', '+\xa029,23 EUR de envío', '+\xa027,91 EUR de envío', 'Envío no especificado', 'Envío internacional gratis', '+\xa021,39 EUR de envío', '+\xa021,44 EUR de envío', '+\xa021,76 EUR de envío', '+\xa0169,11 EUR de envío', '+\xa015,00 EUR de envío', '+\xa013,10 EUR de envío', '+\xa010,07 EUR de envío', 'Envío internacional gratis', '+\xa02,78 EUR de envío', '+\xa063,30 EUR de envío', '+\xa018,41 EUR de envío', '+\xa014,85 EUR de envío', '+\xa024,97 EUR de envío', '+\xa07,87 EUR de envío', '+\xa027,58 EUR de envío', '+\xa010,07 EUR de envío', '+\xa018,07 EUR de envío', '+\xa048,83 EUR de envío', '+\xa013,10 EUR de envío', 'Envío internacional gratis', 'Envío internacional gratis', 'Envío no especificado', '+\xa010,07 EUR de envío']

# %%
# seguimos la misma lógica para sacar la url de la imagen del producto.
lista_imagenes_moviles = sopa_moviles.find_all("div", {"class": "s-item__image-wrapper image-treatment"})
print("El resultado del método '.find_all()' es: \n",   lista_imagenes_moviles)

imagenes_productos = []
# iteramos por la lista para extraer todas las imagenes
for indice, imagen in enumerate(lista_imagenes_moviles):
    imagenes_productos.append(imagen.find_all("img")[0]["src"])


print("\n--------------------------\n")

print("Los resultados de extraer el texto de cada uno de los elementos es:\n", imagenes_productos)

# %%
# vamos a crearnos una función donde almacenemos todo este código y lo podamos hacer todo del tirón, sin necesidad de tener que estar repitiendo código todo el rato. 
def sacar_moviles_ebay(url):
    
    """
    Extrae información de teléfonos móviles en venta desde una página web de eBay.

    Parameters:
        url (str): La URL de la página web de eBay que contiene la información de los teléfonos móviles.

    Returns:
        dict: Un diccionario con la información de los teléfonos móviles, que incluye nombres, precios,
              tipos de envío e imágenes.
    """
    
    res_moviles_ebay = requests.get(url_moviles)

    # vemos si todo ha ido bien
    print("La respuesta de la petición es:", res_moviles_ebay.status_code)
    
    sopa_moviles_ebay = BeautifulSoup(res_moviles_ebay.content, 'html.parser')
    
    # sacamos los nombres de los teléfonos móviles
    lista_nombre_autos = sopa_moviles.find_all("div", {"class": "s-item__title"})

    # sacamos los precios de los teléfonos móviles
    lista_precios_moviles = sopa_moviles.find_all("span", {"class": "s-item__price"})
    
    # sacamos el tipo de envío de los teléfonos móviles
    lista_envio_moviles = sopa_moviles.find_all("span", {"class": "s-item__shipping s-item__logisticsCost"})
    
    # sacamos las url de las imagenes de los móviles
    lista_imagenes_moviles = sopa_moviles.find_all("div", {"class": "s-item__image-wrapper image-treatment"})

    # vamos a juntar todas las listas que han sido tratadas de la misma forma, es decir, todas menos la última (en esta recordad que usamos el método enumerate())
    
    lista_elementos = [lista_nombre_autos, lista_precios_moviles, lista_envio_moviles]
    keys = ["nombre", "precio", "tipo_envio"]
    
    diccionario = {"nombre": [], "precio": [], "tipo_envio": [], "imagen":[]}
    
    for key, lista in zip(diccionario.keys(), lista_elementos):
        textos = [i.getText() for i in lista]
        
        if key == "precio":
            textos = [float(precio.split()[0].replace(".", "").replace(",", ".").replace("$","")) for precio in textos]

        diccionario[key] = textos
    
    # solo nos falta sacar la información de las imagenes, que recordemos lo habíamos sacado usando el método enumerate()
    imagenes_productos_ebay = []
    # iteramos por la lista para extraer todas las imagenes
    for indice, imagen in enumerate(lista_imagenes_moviles):
        imagenes_productos_ebay.append(imagen.find_all("img")[0]["src"])
    
    diccionario["imagen"] = imagenes_productos_ebay
    return diccionario

# %%
datos_ebay = sacar_moviles_ebay(url_moviles)
print("el resultado de nuestra función es:", datos_ebay)
# Out:
# La respuesta de la petición es: 200
# el resultado de nuestra función es: {'nombre': ['Shop on eBay', 'Smartphone 2024 OUKITEL WP32 Exterior Android 13 12GB+128GB/1TB Exterior Práctico NFC', '(Desbloqueado) Teléfono Celular Android Infinix Note 40 Pro 8 GB + 256 GB VERDE Doble SIM', 'DOOGEE S40/S40Pro 4G Red Exterior Smartphone 2/4GB+16/64GB Android 10 Móvil', 'OUKITEL C35 Smartphone sin contrato 24 GB+256 GB Android 13 móvil 5150mAh', 'Colección de móviles Nokia 3310 3110 5110 6110 6210', 'Smartphone Sonim XP8 XP8800 64GB Verizon GSM Desbloqueado Resistente Doble SIM Muy Bueno', 'Anuncio nuevoSmartphone UnihertzJellyPro4G - 2GB RAM, 16GB ROM - Android 8.1 - Azul - Modelo JP', 'Celulares 2021 desbloqueado para 4,4,2 doble SIM baratos súper teléfono inteligente', 'Anuncio nuevoSmartphone Pinephone Pine64 64 Desbloqueado 3GB RAM, 32GB eMMC Linux', 'TOTALMENTE NUEVO SAMSUNG GT-S5611 TELÉFONO GRATUITO SIM - BLUETOOTH - CÁMARA DE 5 MP - 3G - RADIO', 'DOOGEE X97 6,0 pulgadas 4G Smartphone 3 GB + 16 GB barato Android 12 móvil sin contrato', 'Teléfono celular I14pro desbloqueado 6,1 pulgadas 4 GB RAM 32 GB ROM', 'Nuevo teléfono celular i15 Pro Max 7,3" Android 16 GB + 1 TB 5G desbloqueado globalmente', '10000mAh DOOGEE S88 Plus 8 GB + 128 GB Android Outdoor Smartphone sin contrato móvil', 'Teléfono inteligente OUKITEL C35 24 GB + 256 GB Android 13 práctico 6,56 pulgadas 5150mAh 4G doble SIM', 'Smartphone DOOGEE S40/S40Pro Doble 4G para exteriores 2/4GB+16/64GB Android 10 Práctico NFC', 'Anuncio nuevoSmartphone Samsung Galaxy A13 Azul (2022) SM-A135U1/DS - Usado Para Piezas Como Está', 'Anuncio nuevoCelulares Motorola i335 Nextel resistentes en caja abierta coleccionables', 'DOOGEE X95 2 GB + 16 GB Smartphone sin contrato barato DUAL 4G SIM móvil 4350mAh', 'Teléfono celular resistente Global OUKITEL WP36 10600mAh 16 GB + 128 GB ocho núcleos 13 MP NFC IP68', 'Anuncio nuevoNUEVO Realme Note 50 4GB+128GB AZUL Versión Global Teléfono celular Android con doble SIM', 'Anuncio nuevoSmartphone Samsung Galaxy A8 Desbloqueado Android Gris Funciona Buen Estado', 'Anuncio nuevoNUEVO Realme Note 50 4GB+128GB NEGRO Versión Global Teléfono celular Android con doble SIM', 'Anuncio nuevoNokia C22 64GB Dual-SIM Charcoal Black, nuevo solo sin embalaje', 'DOOGEE S88 Pro Outdoor Smartphone 6 GB + 128 GB 10000mAh móvil Android sin contrato', 'Smartphone 2024 OUKITEL WP19 Pro Outdoor Práctico 22000mAh 24GB+256GB Android 13 ', '(Lote de 5) Teléfono celular inalámbrico SCHOK Volt SV55 Assurance negro 16 g', 'Anuncio nuevoSmartphone TCL 30 XE 5g Triple Cámara 64GB GSM Desbloqueado en Todo el Mundo', 'Móvil OUKITEL WP32 sin contrato 12 GB + 128 GB 5,93" Android 13 NFC/OTG/GPS/Face ID', 'Smartphone robusto DOOGEE S88-PLUS 6,3 pulgadas 8GB + 128GB 10000mAh Android 10 móvil', 'UMIDIGI BISON 2/BISON 2 PRO 128 GB 256 GB Smartphone móvil Android contrato móvil', 'DOOGEE S40 Pro Outdoor Smartphone sin contrato, 4 GB + 64 GB doble SIM 4G IP68 móvil', 'Anuncio nuevoSmartphone Samsung Galaxy A6 (2018) SM-A600FN Negro - Usado Para Piezas Tal cual', 'Anuncio nuevoNuevo Smartphone 2024 Desbloqueado i15 Pro Max 7.3" 4G 5G Android Doble SIM Teléfonos Celulares', 'Anuncio nuevoTeléfono Celular Nothing Phone 2(a) 5G NEGRO 12GB+256GB Doble SIM Desbloqueado Android', ' Teléfono Móvil Desbloqueado Original NOKIA N95 8 GB 3G 5 MP Wifi GPS 2,8"" Pantalla GSM', 'Anuncio nuevoTeléfono celular Nokia 3560 muy raro sin tarjeta SIM encendido', 'Anuncio nuevoTeléfono celular 11.0 desbloqueado de 5,72 pulgadas 2 GB 16 GB teléfonos inteligentes octa núcleos con doble', 'UMIDIGI A13S 32 GB 64 GB Smartphone Dual SIM Android móvil sin contrato', 'Smartphone Sonim XP10 XP9900 5G AT&T GSM 🙂 Desbloqueado Resistente Android 128GB 50MP', 'Nuevo móvil sin contrato Android Smartphone barato 4G doble SIM cuatro núcleos 16 GB 2024', 'Anuncio nuevoTeléfono Celular Jethro SC330 Negro/Plateado 3G Senior Abatible', 'Anuncio nuevoLote de 18 Celulares -Mixto- LG, Samsung, iPhone, Motorola **LEER** SOLO PARA REPUESTOS', 'Nokia N95 - bronce (desbloq ...

# %%
datos_ebay
# Out:
# {'nombre': ['Shop on eBay',
#   'Smartphone 2024 OUKITEL WP32 Exterior Android 13 12GB+128GB/1TB Exterior Práctico NFC',
#   '(Desbloqueado) Teléfono Celular Android Infinix Note 40 Pro 8 GB + 256 GB VERDE Doble SIM',
#   'DOOGEE S40/S40Pro 4G Red Exterior Smartphone 2/4GB+16/64GB Android 10 Móvil',
#   'OUKITEL C35 Smartphone sin contrato 24 GB+256 GB Android 13 móvil 5150mAh',
#   'Colección de móviles Nokia 3310 3110 5110 6110 6210',
#   'Smartphone Sonim XP8 XP8800 64GB Verizon GSM Desbloqueado Resistente Doble SIM Muy Bueno',
#   'Anuncio nuevoSmartphone UnihertzJellyPro4G - 2GB RAM, 16GB ROM - Android 8.1 - Azul - Modelo JP',
#   'Celulares 2021 desbloqueado para 4,4,2 doble SIM baratos súper teléfono inteligente',
#   'Anuncio nuevoSmartphone Pinephone Pine64 64 Desbloqueado 3GB RAM, 32GB eMMC Linux',
#   'TOTALMENTE NUEVO SAMSUNG GT-S5611 TELÉFONO GRATUITO SIM - BLUETOOTH - CÁMARA DE 5 MP - 3G - RADIO',
#   'DOOGEE X97 6,0 pulgadas 4G Smartphone 3 GB + 16 GB barato Android 12 móvil sin contrato',
#   'Teléfono celular I14pro desbloqueado 6,1 pulgadas 4 GB RAM 32 GB ROM',
#   'Nuevo teléfono celular i15 Pro Max 7,3" Android 16 GB + 1 TB 5G desbloqueado globalmente',
#   '10000mAh DOOGEE S88 Plus 8 GB + 128 GB Android Outdoor Smartphone sin contrato móvil',
#   'Teléfono inteligente OUKITEL C35 24 GB + 256 GB Android 13 práctico 6,56 pulgadas 5150mAh 4G doble SIM',
#   'Smartphone DOOGEE S40/S40Pro Doble 4G para exteriores 2/4GB+16/64GB Android 10 Práctico NFC',
#   'Anuncio nuevoSmartphone Samsung Galaxy A13 Azul (2022) SM-A135U1/DS - Usado Para Piezas Como Está',
#   'Anuncio nuevoCelulares Motorola i335 Nextel resistentes en caja abierta coleccionables',
#   'DOOGEE X95 2 GB + 16 GB Smartphone sin contrato barato DUAL 4G SIM móvil 4350mAh',
#   'Teléfono celular resistente Global OUKITEL WP36 10600mAh 16 GB + 128 GB ocho núcleos 13 MP NFC IP68',
#   'Anuncio nuevoNUEVO Realme Note 50 4GB+128GB AZUL Versión Global Teléfono celular Android con doble SIM',
#   'Anuncio nuevoSmartphone Samsung Galaxy A8 Desbloqueado Android Gris Funciona Buen Estado',
#   'Anuncio nuevoNUEVO Realme Note 50 4GB+128GB NEGRO Versión Global Teléfono celular Android con doble SIM',
#   'Anuncio nuevoNokia C22 64GB Dual-SIM Charcoal Black, nuevo solo sin embalaje',
#   'DOOGEE S88 Pro Outdoor Smartphone 6 GB + 128 GB 10000mAh móvil Android sin contrato',
#   'Smartphone 2024 OUKITEL WP19 Pro Outdoor Práctico 22000mAh 24GB+256GB Android 13 ',
#   '(Lote de 5) Teléfono celular inalámbrico SCHOK Volt SV55 Assurance negro 16 g',
#   'Anuncio nuevoSmartphone TCL 30 XE 5g Triple Cámara 64GB GSM Desbloqueado en Todo el Mundo',
#   'Móvil OUKITEL WP32 sin contrato 12 GB + 128 GB 5,93" Android 13 NFC/OTG/GPS/Face ID',
#   'Smartphone robusto DOOGEE S88-PLUS 6,3 pulgadas 8GB + 128GB 10000mAh Android 10 móvil',
#   'UMIDIGI BISON 2/BISON 2 PRO 128 GB 256 GB Smartphone móvil Android contrato móvil',
#   'DOOGEE S40 Pro Outdoor Smartphone sin contrato, 4 GB + 64 GB doble SIM 4G IP68 móvil',
#   'Anuncio nuevoSmartphone Samsung Galaxy A6 (2018) SM-A600FN Negro - Usado Para Piezas Tal cual',
#   'Anuncio nuevoNuevo Smartphone 2024 Desbloqueado i15 Pro Max 7.3" 4G 5G Android Doble SIM Teléfonos Celulares',
#   'Anuncio nuevoTeléfono Celular Nothing Phone 2(a) 5G NEGRO 12GB+256GB Doble SIM Desbloqueado Android',
#   ' Teléfono Móvil Desbloqueado Original NOKIA N95 8 GB 3G 5 MP Wifi GPS 2,8"" Pantalla GSM',
#   'Anuncio nuevoTeléfono celular Nokia 3560 muy raro sin tarjeta SIM encendido',
#   'Anuncio nuevoTeléfono celular 11.0 desbloqueado de 5,72 pulgadas 2 GB 16 GB teléfonos inteligentes octa núcleos con doble',
#   'UMIDIGI A13S 32 GB 64 GB Smartphone Dual SIM Android móvil sin contrato',
#   'Smartphone Sonim XP10 XP9900 5G AT&T GSM 🙂 Desbloqueado Resistente Android 128GB 50MP',
#   'Nuevo móvil sin contrato Android Smartphone barato 4G doble SIM cuatro núcleos 16 GB 2024',
#   'Anuncio nuevoTeléfono Celular Jethro SC330 Negro/Plateado 3G Senior Abatible',
#   'Anuncio nuevoLote de 18 Celulares -Mixto- LG, Samsung, iPhone, Motorola **LEER** SOLO PARA REPUESTOS',
#   'Nokia N95 - bronce (desbloqueado) teléfono inteligente',
#   'Anuncio nuevoTeléfono Celular Nothing Phone 2(a) 5G MILK 12GB+256GB Doble SIM Desbloqueado Android',
#   'Anuncio nuevoTeléfono Motorola Moto G7 Plus Doble SIM Android 4/6GB RAM 64/128GB ROM 6.2"',
#   'Teléfono celular clásico Nokia 6300 4G LTE 3 colores desbloqueado doble SIM KaiOS nuevo sellado',
#   'Anuncio nuevoNokia 3560 muy raro - para coleccionistas - sin tarjeta SIM encendido teléfono celular',
#   'Teléfono Celular Inteligente Apple iPhone 12 5G Negro *AGRIETADO -- SOLO PARA REPUESTOS/SALVAMENTO',
#   'Anuncio nuevoTeléfono celular abatible Motorola RAZR V3m',
#   'Smartphone DOOGEE X96PRO 6.52" 4 GB + 64 GB Android 11 5400mAh móvil sin contrato',
#   'Smartphone UMIDIGI Power 5 6.53" 4GB +128GB Android11 móvil sin contrato 6150mAh',
#   'Smartphone BLU G91s 128GB (Desbloqueado) 2022 Android 4G - Verde Oliva',
#   'Anuncio nuevoSmartphone Apple iPhone 5s A1533 - Teléfono Desbloqueado 16GB Gris espacial',
#   'Anuncio nuevoSmartphone Propel 5G 64GB Android 13 Plateado',
#   'Teléfono inteligente Samsung Galaxy Express I437 - 8 GB - negro - (AT&T) - *FUNCIONAL*',
#   'Olympia BECCO Plus negro - móvil con botones grandes para personas mayores (sin bloqueo de SIM) ',
#   'XGODY NUEVO Android 16 GB móvil sin contrato Dual SIM Smartphone Quad Core GPS 2024',
#   'DOOGEE X97 4G Smartphone sin contrato Barato 3+16GB (SD 256GB) Android 12 móvil',
#   'Teléfono celular Samsung C3520 Bluetooth MP3 FM radio GSM abatible desbloqueado',
#   '(Negro) Teléfonos celulares resistentes desbloqueados 5.0 pulgadas 2.4G WIFI resistente',
#   'Anuncio nuevoTeléfono celular Alcatel QuickFlip 4045C AT&T bloqueado 4G',
#   'Teléfono celular Nokia 225 4G - TA-1282 - negro (desbloqueado) LTE GSM desbloqueado globalmente',
#   'Anuncio nuevoSmartphone LG Aristo 3 Plus X220MB (Metro Desbloqueado) - 16GB Negro - ROTO #1276',
#   'Anuncio nuevoApple iPhone 5S - A1533 - 16 GB - Plateado - Desbloqueado (0418B)',
#   'Apple iPhone 2G 1a Generación Desbloqueado 4GB 8GB 16GB Raro iOS 1.0',
#   'Anuncio nuevoTeléfono Celular TCL30Z T602DL (Negro 32GB) Tracfone Inalámbrico NUEVO OpenBox ',
#   'DOOGEE X97Pro 4G Smartphone 4GB + 64GB Android 12 4200mAh móvil sin contrato NFC',
#   'Anuncio nuevoSmartphone LG Nexus 5X - 16GB - Blanco Android 8.1.0',
#   'Anuncio nuevo"Nuevo en caja" Teléfono Celular Blu G33 6,2"" Pantalla HD 4G LTE Desbloqueado de Fábrica GSM',
#   '2024 NUEVO 5,5"" Móvil Android sin contrato Dual SIM Smartphone Quad Core 3390mAh',
#   'Muy Nuevo Teléfono Móvil Motorola v8088 v8088+ Desbloqueado 2G GMS 100% Funcionando',
#   '[Casi Como Nuevo] KYOCERA 902KC DIGNO 3 ANDROID TELÉFONO PLEGABLE NEGRO Teléfono móvil DESBLOQUEADO',
#   'Cámara termográfica DOOGEE V31 GT Dual 5G Outdoor Smartphone 20 GB+256 GB sin contrato',
#   'DOOGEE S88 Pro 6,3" 10000mAh 6+128 GB robusto smartphone sin contrato móvil NFC'],
#  'precio': [2000.0,
#   131.08,
#   399.25,
#   79.66,
#   151.25,
#   25.5,
#   101.21,
#   151.81,
#   53.32,
#   112.46,
#   73.4,
#   49.92,
#   58.49,
#   156.26,
#   140.17,
#   151.25,
#   79.66,
#   37.49,
#   39.35,
#   49.41,
#   189.82,
#   183.32,
#   58.48,
#   183.32,
#   59.95,
#   126.15,
#   292.43,
#   123.7,
#   133.83,
#   131.08,
#   127.05,
#   196.34,
#   79.66,
#   16.87,
#   134.95,
#   593.81,
#   58.98,
#   22.48,
#   54.77,
#   100.43,
#   415.56,
#   45.6,
#   44.97,
#   31.45,
#   46.11,
#   593.81,
#   99.71,
#   94.09,
#   22.48,
#   36.55,
#   72.88,
#   16.87,
#   65.55,
#   99.82,
#   157.44,
#   44.93,
#   56.22,
#   23.61,
#   29.0,
#   45.94,
#   53.55,
#   41.94,
#   53.99,
#   33.73,
#   56.22,
#   23.61,
#   17.81,
#   94.47,
#   44.99,
#   69.58,
#   44.97,
#   9.36,
#   57.35,
#   76.48,
#   98.73,
#   563.7,
#   140.17],
#  'tipo_envio': ['Envío no especificado',
#   'Envío internacional gratis',
#   'Envío no especificado',
#   'Envío no especificado',
#   '+\xa014,00 EUR de envío',
#   '+\xa023,09 EUR de envío',
#   'Envío internacional gratis',
#   'Envío internacional gratis',
#   '+\xa023,43 EUR de envío',
#   '+ 13,91 EUR de envío estimado',
#   'Envío no especificado',
#   'Envío internacional gratis',
#   'Envío internacional gratis',
#   '+\xa010,07 EUR de envío',
#   'Envío no especificado',
#   'Envío no especificado',
#   '+\xa011,25 EUR de envío',
#   '+\xa021,27 EUR de envío',
#   'Envío no especificado',
#   'Envío internacional gratis',
#   'Envío internacional gratis',
#   '+\xa021,83 EUR de envío',
#   'Envío internacional gratis',
#   '+\xa05,40 EUR de envío',
#   'Envío no especificado',
#   'Envío no especificado',
#   '+\xa023,75 EUR de envío',
#   '+\xa024,06 EUR de envío',
#   '+\xa09,98 EUR de envío',
#   'Envío no especificado',
#   'Envío internacional gratis',
#   'Envío no especificado',
#   '+\xa014,06 EUR de envío',
#   'Envío internacional gratis',
#   'Envío internacional gratis',
#   'Envío internacional gratis',
#   '+\xa023,02 EUR de envío',
#   '+\xa02,78 EUR de envío',
#   'Envío internacional gratis',
#   '+\xa032,37 EUR de envío',
#   '+\xa013,10 EUR de envío',
#   '+\xa018,07 EUR de envío',
#   '+\xa072,92 EUR de envío',
#   'Envío internacional gratis',
#   'Envío internacional gratis',
#   'Envío internacional gratis',
#   '+\xa03,37 EUR de envío',
#   '+\xa023,02 EUR de envío',
#   '+\xa029,23 EUR de envío',
#   '+\xa027,91 EUR de envío',
#   'Envío no especificado',
#   'Envío internacional gratis',
#   '+\xa021,39 EUR de envío',
#   '+\xa021,44 EUR de envío',
#   '+\xa021,76 EUR de envío',
#   '+\xa0169,11 EUR de envío',
#   '+\xa015,00 EUR de envío',
#   '+\xa013,10 EUR de envío',
#   '+\xa010,07 EUR de envío',
#   'Envío internacional gratis',
#   '+\xa02,78 EUR de envío',
#   '+\xa063,30 EUR de envío',
#   '+\xa018,41 EUR de envío',
#   '+\xa014,85 EUR de envío',
#   '+\xa024,97 EUR de envío',
#   '+\xa07,87 EUR de envío',
#   '+\xa027,58 EUR de envío',
#   '+\xa010,07 EUR de envío',
#   '+\xa018,07 EUR de envío',
#   '+\xa048,83 EUR de envío',
#   '+\xa013,10 EUR de envío',
#   'Envío internacional gratis',
#   'Envío internacional gratis',
#   'Envío no especificado',
#   '+\xa010,07 EUR de envío'],
#  'imagen': ['https://ir.ebaystatic.com/rs/v/fxxj3ttftm5ltcqnto1o4baovyl.png',
#   'https://i.ebayimg.com/thumbs/images/g/EYsAAOSwbehlpOg8/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/c~cAAOSw3fVmARto/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/EggAAOSwCmVl5ZlN/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/O~0AAOSwCz9lC61y/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/LDoAAOSwfO1mDXxJ/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/hksAAOSwprtlG1QM/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/MPoAAOSwjqlmJgSZ/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/xNYAAOSw8Idl5zUW/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/1RwAAOSwOR1mJYsk/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/a1gAAOSw1ntlMA7D/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/sRQAAOSwtfpmBOd-/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/XdIAAOSwOCdlrCpT/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/IUoAAOSwl2Bl7s4b/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/W8cAAOSw6dVl6W93/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/ZRMAAOSw-OxlRg6-/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/tAoAAOSwZzBl3aLP/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/xbsAAOSw16ZmJEKY/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/gxUAAOSwOv1mJYtM/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/KvIAAOSwfXJljoxs/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/~HMAAOSw831mEm6V/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/i9EAAOSwMWhmJe5E/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/Z3YAAOSwitll~c05/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/gC4AAOSwiHRmJe0e/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/QR4AAOSw1WtmJbTT/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/54MAAOSw9iVli~rW/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/IqUAAOSwyOFlpPR-/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/J1wAAOSwvkBlgvnr/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/OxoAAOSwstFmJbaN/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/jxoAAOSwSsRl8qzF/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/I1QAAOSwboJl6ESC/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/i1EAAOSwb0xi8ik8/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/VFgAAOSwBmtlYySZ/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/0i0AAOSw7JBmJA1s/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/bQAAAOSwnuhlQ2ek/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/lXsAAOSw~XBmJgS6/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/zeEAAOSwFg9fHX0D/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/KbUAAOSwYHhlUn9H/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/u9oAAOSwGW1mJImh/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/fGAAAOSwHc1iRBmT/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/fW8AAOSwOY1l197t/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/fW0AAOSwHH1mIInl/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/4UoAAOSwLiZmJcRn/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/UZwAAOSwLvhmJYxd/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/VuEAAOSwhcRiafyg/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/YAQAAOSwcudmJgW8/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/l5QAAOSwxTxkxeZj/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/rOEAAOSwg1JmAmVJ/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/FCoAAOSwUWtkt~lI/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/TGYAAOSwmr1l18Hn/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/NSEAAOSwZfFkETEX/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/PBoAAOSwKpBmBQ0g/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/MssAAOSw9EVg6Daw/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/INYAAOSw2dRmBEmT/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/r1IAAOSwU-dmJgEi/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/MVcAAOSwqb5mJXR8/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/OxQAAOSw6shlgOzI/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/bTkAAOSwehxl~ZZR/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/WOUAAOSwmwxmAXW~/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/VRUAAOSwyQNmGPZN/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/OvgAAOSwkjpjggsV/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/HMQAAOSwnnBmGYjn/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/DxkAAOSw8dhjnNXz/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/obkAAOSwFVlkcoMs/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/GMkAAOSwwcxmJZpg/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/pZAAAOSwilxmJAG5/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/ZXkAAOSwFO1lEq3y/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/mBcAAOSwql5le5gF/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/qVAAAOSwZwFmGPa~/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/jJ8AAOSwrj5mJXL5/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/POMAAOSwQP1mDxwW/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/a8IAAOSwyYdmBaXs/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/cRsAAOSwxC5kkT6O/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/VeEAAOSwVJVl7s~6/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/u6YAAOSwWxFlnl1P/s-l300.jpg',
#   'https://i.ebayimg.com/thumbs/images/g/nwMAAOSwcL1lYx02/s-l300.jpg']}

# %%
datos_ebay["precio"]
# Out:
# [2000.0,
#  131.08,
#  399.25,
#  79.66,
#  151.25,
#  25.5,
#  101.21,
#  151.81,
#  53.32,
#  112.46,
#  73.4,
#  49.92,
#  58.49,
#  156.26,
#  140.17,
#  151.25,
#  79.66,
#  37.49,
#  39.35,
#  49.41,
#  189.82,
#  183.32,
#  58.48,
#  183.32,
#  59.95,
#  126.15,
#  292.43,
#  123.7,
#  133.83,
#  131.08,
#  127.05,
#  196.34,
#  79.66,
#  16.87,
#  134.95,
#  593.81,
#  58.98,
#  22.48,
#  54.77,
#  100.43,
#  415.56,
#  45.6,
#  44.97,
#  31.45,
#  46.11,
#  593.81,
#  99.71,
#  94.09,
#  22.48,
#  36.55,
#  72.88,
#  16.87,
#  65.55,
#  99.82,
#  157.44,
#  44.93,
#  56.22,
#  23.61,
#  29.0,
#  45.94,
#  53.55,
#  41.94,
#  53.99,
#  33.73,
#  56.22,
#  23.61,
#  17.81,
#  94.47,
#  44.99,
#  69.58,
#  44.97,
#  9.36,
#  57.35,
#  76.48,
#  98.73,
#  563.7,
#  140.17]

# %% [markdown]
# Esto lo hemos hecho solo para una página, pero si nos fijamos en la página web hay muchas más páginas y veamos en que se difererian las unas de las otras:

# %%
# Inicializamos un bucle que recorrerá 3 páginas de resultados en eBay
for pagina in range(3):
    # Construimos la URL de la página actual con el número de página
    url_moviles_todos = f"https://www.ebay.es/sch/15032/i.html?_from=R40&_nkw=celulares&_pgn{pagina}"
    
    # Llamamos a la función 'sacar_moviles_ebay' para extraer información de los móviles en la página actual
    todos_resultados_moviles = sacar_moviles_ebay(url_moviles_todos)

# Al final del bucle, 'todos_resultados_moviles' contendrá la información de la última página procesada.
# Out:
# La respuesta de la petición es: 200
# La respuesta de la petición es: 200
# La respuesta de la petición es: 200

# %% [markdown]
# ## Pandas
#
# **Pandas** es una de las librerías más populares de Python utilizada en el análisis de datos y la manipulación de estructuras de datos. Proporciona estructuras de datos y herramientas de manipulación de alto rendimiento, diseñadas específicamente para facilitar el trabajo con datos estructurados o tabulares.
#
# La estructura de datos principal en **Pandas** se llama *DataFrame*, que es esencialmente una tabla de datos bidimensional con columnas etiquetadas y filas indexadas (como un Excel con el que puede que si estés más familiarizada). Los *DataFrames* en Pandas permiten almacenar y manipular datos de manera eficiente, ofreciendo una amplia gama de funciones para filtrar, seleccionar, agregar y transformar datos.
#
# La librería Pandas proporciona numerosas funciones y métodos para realizar operaciones comunes de análisis de datos, como la limpieza y preparación de datos, la agregación y resumen de datos, el filtrado y selección de datos, la manipulación de fechas y mucho más. También permite leer y escribir datos en varios formatos, como archivos CSV, Excel, SQL, entre otros.
#
# Como analistas de datos utilizaremos Pandas por varias razones. Algunas de las más importantes son:
#
# 1. **Manipulación y limpieza de datos**:  ofrece una amplia gama de funciones y métodos que facilitan la manipulación y limpieza de datos. Permite cargar datos desde diferentes fuentes, como archivos CSV, Excel, SQL, etc., y ofrece herramientas para filtrar y seleccionar datos, eliminar valores nulos, cambiar el formato de datos, etc. Estas capacidades son esenciales para preparar y transformar los datos antes de realizar el análisis.
#
# 2. **Análisis exploratorio de datos**: proporciona herramientas eficientes para realizar un análisis exploratorio de datos. Permite realizar operaciones estadísticas básicas, calcular medidas de resumen, explorar correlaciones entre variables y crear visualizaciones para comprender mejor los datos. Esto ayuda a los analistas de datos a obtener información rápida sobre la distribución de los datos, las tendencias y las relaciones entre las variables.
#
# 3. **Indexación y selección de datos**: facilita la indexación y selección de datos en un DataFrame. Permite acceder a columnas y filas específicas, filtrar datos según condiciones específicas y realizar operaciones avanzadas de indexación y selección. Estas capacidades son cruciales para extraer los datos relevantes necesarios para un análisis específico.
#
# 4. **Combinación y agregación de datos**: Los analistas de datos a menudo necesitan combinar y agregar datos de diferentes fuentes. Pandas ofrece funcionalidades para fusionar, unir y concatenar DataFrames, lo que permite combinar datos de diferentes tablas y realizar operaciones de agregación, como sumarización de datos, agrupación y cálculo de estadísticas descriptivas.

# %%
# convertir el diccionario en DataFrame
# usar el método pd.DataFrame(), que es uno de los métodos que más usaremos más a menudo durante estas lecciones
# esta tabla la almacenaremos en una variable llamada "df"

df = pd.DataFrame(todos_resultados_moviles)

# utilizaremos el método .head() para mostrar las 5 primeras filas del dataframe generado en el paso anterior
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1433/200047153.py in <module>
#       3 # esta tabla la almacenaremos en una variable llamada "df"
#       4
# ----> 5 df = pd.DataFrame(todos_resultados_moviles)
#       6
#       7 # utilizaremos el método .head() para mostrar las 5 primeras filas del dataframe generado en el paso anterior
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     462         # TODO: can we get rid of the dt64tz special case above?
#     463
# --> 464     return arrays_to_mgr(
#     465         arrays, data_names, index, columns, dtype=dtype, typ=typ, consolidate=copy
#     466     )
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity, typ, consolidate)
#     117         # figure out the index, if necessary
#     118         if index is None:
# --> 119             index = _extract_index(arrays)
#     120         else:
#     121             index = ensure_index(index)
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py in _extract_index(data)
#     633             lengths = list(set(raw_lengths))
#     634             if len(lengths) > 1:
# --> 635                 raise ValueError("All arrays must be of the same length")
#     636
#     637             if have_dicts:
#
# ValueError: All arrays must be of the same length

# %%
# veamos como esta compuesto nuestro diccionario

todos_resultados_moviles.keys()
# Out:
# dict_keys(['nombre', 'precio', 'tipo_envio', 'imagen'])

# %%
# cantidad de elementos que tiene cada una de mis claves???

print(f"variable nombre: {len(todos_resultados_moviles['nombre'])}")
print(f"variable precio: {len(todos_resultados_moviles['precio'])}")
print(f"variable tipo_envio: {len(todos_resultados_moviles['tipo_envio'])}")
print(f"variable imagen: {len(todos_resultados_moviles['imagen'])}")
# Out:
# variable nombre: 76
# variable precio: 77
# variable tipo_envio: 75
# variable imagen: 76

# %%
# Encuentra la longitud mínima entre todas las listas

val_min = min(len(values) for values in todos_resultados_moviles.values())

# Limita cada lista para que tenga la longitud mínima
todos_resultados_moviles = {key: values[:val_min] for key, values in todos_resultados_moviles.items()}

# Convierte el diccionario en un DataFrame de pandas como haciamos antes
df = pd.DataFrame(todos_resultados_moviles)

df
# Out:
#                                                nombre   precio  \
# 0                                        Shop on eBay  2000.00
# 1   Smartphone 2024 OUKITEL WP32 Exterior Android ...   131.08
# 2   (Desbloqueado) Teléfono Celular Android Infini...   399.25
# 3   DOOGEE S40/S40Pro 4G Red Exterior Smartphone 2...    79.66
# 4   OUKITEL C35 Smartphone sin contrato 24 GB+256 ...   151.25
# ..                                                ...      ...
# 70  Anuncio nuevo"Nuevo en caja" Teléfono Celular ...    44.97
# 71  2024 NUEVO 5,5"" Móvil Android sin contrato Du...     9.36
# 72  Muy Nuevo Teléfono Móvil Motorola v8088 v8088+...    57.35
# 73  [Casi Como Nuevo] KYOCERA 902KC DIGNO 3 ANDROI...    76.48
# 74  Cámara termográfica DOOGEE V31 GT Dual 5G Outd...    98.73
#
#                     tipo_envio  \
# 0        Envío no especificado
# 1   Envío internacional gratis
# 2        Envío no especificado
# 3        Envío no especificado
# 4         + 14,00 EUR de envío
# ..                         ...
# 70        + 13,10 EUR de envío
# 71  Envío internacional gratis
# 72  Envío internacional gratis
# 73       Envío no especificado
# 74        + 10,07 EUR de envío
#
#                                                imagen
# 0   https://ir.ebaystatic.com/rs/v/fxxj3ttftm5ltcq...
# 1   https://i.ebayimg.com/thumbs/images/g/EYsAAOSw...
# 2   https://i.ebayimg.com/thumbs/images/g/c~cAAOSw...
# 3   https://i.ebayimg.com/thumbs/images/g/EggAAOSw...
# 4   https://i.ebayimg.com/thumbs/images/g/O~0AAOSw...
# ..                                                ...
# 70  https://i.ebayimg.com/thumbs/images/g/POMAAOSw...
# 71  https://i.ebayimg.com/thumbs/images/g/a8IAAOSw...
# 72  https://i.ebayimg.com/thumbs/images/g/cRsAAOSw...
# 73  https://i.ebayimg.com/thumbs/images/g/VeEAAOSw...
# 74  https://i.ebayimg.com/thumbs/images/g/u6YAAOSw...
#
# [75 rows x 4 columns]

# %%
# Elimina el primer registro del DataFrame

df = df.drop(df.index[0])
df
# Out:
#                                                nombre  precio  \
# 1   Smartphone 2024 OUKITEL WP32 Exterior Android ...  131.08
# 2   (Desbloqueado) Teléfono Celular Android Infini...  399.25
# 3   DOOGEE S40/S40Pro 4G Red Exterior Smartphone 2...   79.66
# 4   OUKITEL C35 Smartphone sin contrato 24 GB+256 ...  151.25
# 5   Colección de móviles Nokia 3310 3110 5110 6110...   25.50
# ..                                                ...     ...
# 70  Anuncio nuevo"Nuevo en caja" Teléfono Celular ...   44.97
# 71  2024 NUEVO 5,5"" Móvil Android sin contrato Du...    9.36
# 72  Muy Nuevo Teléfono Móvil Motorola v8088 v8088+...   57.35
# 73  [Casi Como Nuevo] KYOCERA 902KC DIGNO 3 ANDROI...   76.48
# 74  Cámara termográfica DOOGEE V31 GT Dual 5G Outd...   98.73
#
#                     tipo_envio  \
# 1   Envío internacional gratis
# 2        Envío no especificado
# 3        Envío no especificado
# 4         + 14,00 EUR de envío
# 5         + 23,09 EUR de envío
# ..                         ...
# 70        + 13,10 EUR de envío
# 71  Envío internacional gratis
# 72  Envío internacional gratis
# 73       Envío no especificado
# 74        + 10,07 EUR de envío
#
#                                                imagen
# 1   https://i.ebayimg.com/thumbs/images/g/EYsAAOSw...
# 2   https://i.ebayimg.com/thumbs/images/g/c~cAAOSw...
# 3   https://i.ebayimg.com/thumbs/images/g/EggAAOSw...
# 4   https://i.ebayimg.com/thumbs/images/g/O~0AAOSw...
# 5   https://i.ebayimg.com/thumbs/images/g/LDoAAOSw...
# ..                                                ...
# 70  https://i.ebayimg.com/thumbs/images/g/POMAAOSw...
# 71  https://i.ebayimg.com/thumbs/images/g/a8IAAOSw...
# 72  https://i.ebayimg.com/thumbs/images/g/cRsAAOSw...
# 73  https://i.ebayimg.com/thumbs/images/g/VeEAAOSw...
# 74  https://i.ebayimg.com/thumbs/images/g/u6YAAOSw...
#
# [74 rows x 4 columns]

# %%
# si queremos sacar las últimas filas del dataframe usaremos el método .tail()
df.tail(3)
# Out:
#                                                nombre  precio  \
# 72  Muy Nuevo Teléfono Móvil Motorola v8088 v8088+...   57.35
# 73  [Casi Como Nuevo] KYOCERA 902KC DIGNO 3 ANDROI...   76.48
# 74  Cámara termográfica DOOGEE V31 GT Dual 5G Outd...   98.73
#
#                     tipo_envio  \
# 72  Envío internacional gratis
# 73       Envío no especificado
# 74        + 10,07 EUR de envío
#
#                                                imagen
# 72  https://i.ebayimg.com/thumbs/images/g/cRsAAOSw...
# 73  https://i.ebayimg.com/thumbs/images/g/VeEAAOSw...
# 74  https://i.ebayimg.com/thumbs/images/g/u6YAAOSw...

# %%
# si queremos sacar las primeras filas del dataframe usaremos el método .head()
df.head(15)
# Out:
#                                                nombre  precio  \
# 1   Smartphone 2024 OUKITEL WP32 Exterior Android ...  131.08
# 2   (Desbloqueado) Teléfono Celular Android Infini...  399.25
# 3   DOOGEE S40/S40Pro 4G Red Exterior Smartphone 2...   79.66
# 4   OUKITEL C35 Smartphone sin contrato 24 GB+256 ...  151.25
# 5   Colección de móviles Nokia 3310 3110 5110 6110...   25.50
# 6   Smartphone Sonim XP8 XP8800 64GB Verizon GSM D...  101.21
# 7   Anuncio nuevoSmartphone UnihertzJellyPro4G - 2...  151.81
# 8   Celulares 2021 desbloqueado para 4,4,2 doble S...   53.32
# 9   Anuncio nuevoSmartphone Pinephone Pine64 64 De...  112.46
# 10  TOTALMENTE NUEVO SAMSUNG GT-S5611 TELÉFONO GRA...   73.40
# 11  DOOGEE X97 6,0 pulgadas 4G Smartphone 3 GB + 1...   49.92
# 12  Teléfono celular I14pro desbloqueado 6,1 pulga...   58.49
# 13  Nuevo teléfono celular i15 Pro Max 7,3" Androi...  156.26
# 14  10000mAh DOOGEE S88 Plus 8 GB + 128 GB Android...  140.17
# 15  Teléfono inteligente OUKITEL C35 24 GB + 256 G...  151.25
#
#                        tipo_envio  \
# 1      Envío internacional gratis
# 2           Envío no especificado
# 3           Envío no especificado
# 4            + 14,00 EUR de envío
# 5            + 23,09 EUR de envío
# 6      Envío internacional gratis
# 7      Envío internacional gratis
# 8            + 23,43 EUR de envío
# 9   + 13,91 EUR de envío estimado
# 10          Envío no especificado
# 11     Envío internacional gratis
# 12     Envío internacional gratis
# 13           + 10,07 EUR de envío
# 14          Envío no especificado
# 15          Envío no especificado
#
#                                                imagen
# 1   https://i.ebayimg.com/thumbs/images/g/EYsAAOSw...
# 2   https://i.ebayimg.com/thumbs/images/g/c~cAAOSw...
# 3   https://i.ebayimg.com/thumbs/images/g/EggAAOSw...
# 4   https://i.ebayimg.com/thumbs/images/g/O~0AAOSw...
# 5   https://i.ebayimg.com/thumbs/images/g/LDoAAOSw...
# 6   https://i.ebayimg.com/thumbs/images/g/hksAAOSw...
# 7   https://i.ebayimg.com/thumbs/images/g/MPoAAOSw...
# 8   https://i.ebayimg.com/thumbs/images/g/xNYAAOSw...
# 9   https://i.ebayimg.com/thumbs/images/g/1RwAAOSw...
# 10  https://i.ebayimg.com/thumbs/images/g/a1gAAOSw...
# 11  https://i.ebayimg.com/thumbs/images/g/sRQAAOSw...
# 12  https://i.ebayimg.com/thumbs/images/g/XdIAAOSw...
# 13  https://i.ebayimg.com/thumbs/images/g/IUoAAOSw...
# 14  https://i.ebayimg.com/thumbs/images/g/W8cAAOSw...
# 15  https://i.ebayimg.com/thumbs/images/g/ZRMAAOSw...

# %%
# ¿cuántas filas y columnas tenemos en el dataframe? usaremos el método .shape
# fijaos que este método nos devuelve una tupla con dos elementos. 
# el PRIMERO de los elementos hace referencia al número de FILAS
# el SEGUNDO de los elementos hace referencia al número de COLUMNAS
df.shape
# Out:
# (74, 4)

# %%
# ¿cuáles son los tipos de datos que tenemos en cada columna?
# para eso usaremos el método .dtypes
# 📌 NOTA: en Pandas los strings son mostrados como tipo "object"
df.dtypes
# Out:
# nombre         object
# precio        float64
# tipo_envio     object
# imagen         object
# dtype: object

# %%
# en Pandas tenemos un método que aglutina toda la información que hemos visto hasta ahora, 
# ese método es el ".info()"
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 74 entries, 1 to 74
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   nombre      74 non-null     object
#  1   precio      74 non-null     float64
#  2   tipo_envio  74 non-null     object
#  3   imagen      74 non-null     object
# dtypes: float64(1), object(3)
# memory usage: 2.9+ KB

# %%
# Pandas también nos permiten extraer los principales estadísticos de nuestro conjunto de datos. 
# usaremos el método ".describe()"
# es importante destacar que por defecto este método nos va a devolver los principales estadísticos de las variables de tipo numérico
df.describe().T
# Out:
#         count        mean         std   min     25%     50%       75%     max
# precio   74.0  104.428784  111.373832  9.36  44.975  67.565  130.0725  593.81

# %%
df.describe()
# Out:
#            precio
# count   74.000000
# mean   104.428784
# std    111.373832
# min      9.360000
# 25%     44.975000
# 50%     67.565000
# 75%    130.072500
# max    593.810000

# %%
# si quisieramos saber cuales son los principales estadísticos de las variables categóricas tendremos que incluir un parámetro en el método ".describe()"
# este parámetro es el "include"
df.describe(include = "object").T
# Out:
#            count unique                                                top  \
# nombre        74     74  Smartphone 2024 OUKITEL WP32 Exterior Android ...
# tipo_envio    74     36                         Envío internacional gratis
# imagen        74     74  https://i.ebayimg.com/thumbs/images/g/EYsAAOSw...
#
#            freq
# nombre        1
# tipo_envio   20
# imagen        1

# %%
# nos puede interesar saber si tenemos valores nulos en nuestro conjunto de datos. 
# para eso tendremos que usar el método ".isnull()" 
df.isnull().sum()
# Out:
# nombre        0
# precio        0
# tipo_envio    0
# imagen        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.duplicated(subset = "precio").sum()
# Out:
# 11

# %% [markdown]
# # Sacando datos de una tabla
#
# En ocasiones, como analistas de datos, nos puede interesar obtener información específica de una tabla que se encuentra en una página web. La extracción de datos de una tabla en una página web implica un proceso un poco diferente en comparación con la extracción de información de texto plano. Como en el ejemplo anterio, utilizaremos la biblioteca Pandas en combinación con otras bibliotecas como `requests` y `BeautifulSoup` para lograr esto.
#
# El escenario particular que abordaremos es la extracción de datos del histórico de los precios del IBEX-35. El IBEX-35 es un índice bursátil compuesto por las 35 empresas con mayor capitalización en la Bolsa de Madrid. Estos datos históricos de precios nos brindan información valiosa para el análisis y seguimiento de los mercados financieros.
#
#
# Algunas de las preguntas que podríamos contestar con estos datos son:
#
# 1. **¿Cuál ha sido la tendencia general del IBEX-35 en un período de tiempo específico?** Podemos analizar los precios de cierre del IBEX-35 a lo largo del tiempo y determinar si ha habido una tendencia alcista, bajista o lateral. Podemos identificar períodos de crecimiento sostenido, caídas significativas o momentos de estabilidad.
#
# 2. **¿Cuáles han sido los máximos y mínimos históricos del IBEX-35?** Podemos identificar los puntos más altos y más bajos alcanzados por el índice a lo largo de su historia. Esto puede ser útil para evaluar el rendimiento general y la volatilidad del mercado.
#
# 3. **¿Cuáles han sido los cambios porcentuales diarios o mensuales del IBEX-35?** Podemos calcular los cambios porcentuales diarios o mensuales en el valor del índice para identificar períodos de alta volatilidad o estabilidad. Esto puede proporcionar información sobre la magnitud y la frecuencia de los movimientos del mercado.
#
# 4. **¿Cuáles son los patrones estacionales o cíclicos en el comportamiento del IBEX-35?** Podemos analizar los datos históricos para identificar patrones estacionales o cíclicos en el rendimiento del índice. Por ejemplo, podríamos examinar si hay tendencias específicas asociadas con ciertos meses del año o días de la semana.
#
# Estas son solo algunas preguntas que podríamos responder utilizando los datos históricos del IBEX-35. Dependiendo de los objetivos de análisis y las necesidades específicas, podremos formular preguntas adicionales y realizar análisis más detallados para comprender mejor el comportamiento y las tendencias del mercado.

# %%
# al igual que en el ejemplo anterior lo primero que haremos será definir la url de la página de la vamos a sacar datos
url_bolsa = "https://www.bolsamania.com/indice/IBEX-35/historico-precios"

# hacemos la request a la página de la que queremos sacar la info
res_bolsa = requests.get(url_bolsa)

# vemos si todo ha ido bien
print("La respuesta de la petición es:", res_bolsa.status_code)
# Out:
# La respuesta de la petición es: 200

# %%
# creamos el objeto BeautifulSoup para poder acceder al contenido solicitado
sopa_bolsa = BeautifulSoup(res_bolsa.content, 'html.parser')

# recordemos que el método .prettify nos permite mostrar de una forma más amigable los resultados obtenidos de la sopa
print(sopa_bolsa.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="es" xml:lang="es">
#  <head>
#   <title>
#    Precios históricos de IBEX 35  - Bolsamania.com
#   </title>
#   <link href="https://www.bolsamania.com/rss/generarRss2.php" rel="alternate" title="RSS de bolsamania" type="application/rss+xml"/>
#   <meta content="Precios históricos de IBEX 35  - Bolsamania.com" name="title"/>
#   <meta content="Precios históricos de IBEX 35" name="description"/>
#   <meta content="bolsa,portal,financiero,cotizaciones,madrid,actualidad,bursatil,noticias,cartera,recomendaciones,mercado,continuo,ibex,divisas,finanzas,mercados, IBEX 35,fsSector:fs_" name="keywords"/>
#   <meta content="vQvvK3aWyocxI4jZrUYY1wlUpVGsOTMHg2qPFieRTUA" name="google-site-verification"/>
#   <meta content="1436008526699345" property="fb:pages"/>
#   <meta content="6wdyrqwezubh8d1ltqd7vnmi6tyusa" name="facebook-domain-verification"/>
#   <meta content="Madrid, Spain" name="locality"/>
#   <meta content="Web Financial Group, S.A." name="author"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type">
#    <meta content="es-es" http-equiv="language"/>
#    <script type="text/javascript">
#     var rfrsh = setTimeout(function() { window.location = location.href; }, eval(180 * 1000));
#    </script>
#    <noscript>
#     <meta content="180" http-equiv="refresh"/>
#    </noscript>
#    <meta content="app-id=1251409805" name="apple-itunes-app"/>
#    <meta content="app-id=com.web.financialgroup.webfg" name="google-play-app"/>
#    <meta content="ads" name="wfg"/>
#    <script>
#     (function(){
#         window.$vortex=window.$vortex||[];
#         $vortex.push(function(){
#             var vortexConfig=[
#                 {
#                   type:"cmp",
#                   enabled:false
#                 },
#                 {
#                     type:"adserver",
#                     setup:"full",
#                     adUnit:"ES_BOLSAMANIA/HOME/INDICE/HISTORICO_PRECIOS"
#                 },
#                 {
#                     type:"page",
#                     keywords:["bolsa","portal","financiero","cotizaciones","madrid","actualidad","bursatil","noticias","cartera","recomendaciones","mercado","continuo","ibex","divisas","finanzas","mercados","_ibex_35","fs_"],
#                     taxonomies:["1","1-1","1-1-12","1-1-7"],
#                     entities:["ibex_35"]
#                 },
#                 {
#                     type:"adSlots",
#                     positions:"skin,sky,ldb,mpu,itx"
#                 }
#             ];
#             $vortex.setConf(vortexConfig);
#         });
#         var vortex_script=document.createElement('script');
#         vortex_script.setAttribute("async","async");
#         vortex_script.setAttribute("src","https://vm.s3wfg.com/js/vortexloader.js?v=20240422");
#         (document.body||document.head).appendChild(vortex_script);
#
#         document.addEventListener('DOMContentLoaded', function(){
#             var closable=document.getElementsByClassName('__adclose');
#             for (var i = 0; i < closable.length; i++) {
#                 closable[i].onclick = function(){
#                     var ad_parent = this.closest('.ads-parent');
#                     ad_parent.removeChild(ad_parent.childNodes[0]);
#                 }
#             }
#         }, false);
#     })();
#    </script>
#    <link href="//rsrc.s3wfg.com/web/faviconBMSv2.ico" rel="Shortcut Icon"/>
#    <link href="//rsrc.s3wfg.com/web/img/icons/iconnApp_small.jpg" rel="apple-touch-icon"/>
#    <link href="//rsrc.s3wfg.com/web/img/icons/iconnApp_small.jpg" rel="android-touch-icon"/>
#    <!--
# <script type="text/javascript">
# var css_bundle = document.createElement('link');
# css_bundle.rel = 'stylesheet';
# css_bundle.href = '';
# css_bundle.type = 'text/css';
# var godefer = document.getElementsByTagName('link')[0];
# godefer.parentNode.insertBefore(css_bundle, godefer);
# </script>
# <noscript>
#   <link rel="stylesheet" type="text/css" href="" />
# </noscript>
# -->
#    <link href="https://rsrc.s3wfg.com/web/webpack/build/css/bolsamania.bundle.css?v=b50e5164ed85a3fcb00358c96e0a0059_20240422" media="all" rel="stylesheet" type="text/css"/>
#    <!-- Google Tag Manager -->
#    <script>
#     (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#             new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-NGNRZVQ9');
#    </script>
#    <!-- End Google Tag Manager -->
#    <!--[if lt IE 10]>
#     <script type="text/javascript" src="http://cdnjs.cloudflare.com/ajax/libs/jquery-ajaxtransport-xdomainrequest/1.0.3/jquery.xdomainrequest.min.js"></script>
# <![endif]-->
#    <script async="" src="https://cdn.gravitec.net/storage/2b08c84d123b20fdb770c2ac73dd8e37/client.js">
#    </script>
#    <!--Flipboard button-->
#    <script async="" src="//cdn.flipboard.com/web/buttons/js/flbuttons.min.js" type="text/javascript">
#    </script>
#    <!--[if lt IE 8]><script src="http://html5shiv.googlecode.com/svn/trunk/html5.js"></script><![endif]-->
#    <!--[if lt IE 9]>
# 	<script type="text/javascript">
# 		document.createElement("nav");
# 		document.createElement("header");
# 		document.createElement("footer");
# 		document.createElement("section");
# 		document.createElement("article");
# 		document.createElement("aside");
# 		document.createElement("hgroup");
# 		document.createElement('video');
# 		document.createElement('audio');
# 		document.createElement('track');
# 	</script>
# <![endif]-->
#    <script>
#     var WFG = WFG || {
#         'LS': {
#             'loadTableConf': function() {},
#             'addLsTable': function() {},
#             'removeLsTable': function() {},
#             'checkLsEngine': function() {},
#             'loadItemConf': function() {}
#         },
#         'testServer': {
#             'init': function() {}
#         }
#     };
#
#     var _site = '';
#     var _domain = 'https://www.bolsamania.com/';
#    </script>
#    <!-- Custom tags -->
#    <meta content="https://www.bolsamania.com/indice/IBEX-35/historico-precios" name="canonical"/>
#    <link as="html" crossorigin="use-credentials" href="https://www.bolsamania.com/scroll_2/indice/IBEX-35/historico-precios" rel="prefetch"/>
#    <link as="html" crossorigin="use-credentials" href="https://www.bolsamania.com/scroll_3/indice/IBEX-35/warrants" rel="prefetch"/>
#    <link as="html" crossorigin="use-credentials" href="https://www.bolsamania.com/scroll_4/indice/IBEX-35/ficha" rel="prefetch"/>
#    <link as="html" crossorigin="use-credentials" href="https://www.bolsamania.com/scroll_5/indice/IBEX-35/noticias" rel="prefetch"/>
#    <meta content="Mon, 22 Apr 2024 10:10:31 +0200" name="last-modified"/>
#    <script defer="" type="module">
#     import { start } from 'https://adgage.adkaora.space/vortexmedia/generic/prod/adk-init.js'
#    </script>
#    <!-- End Custom tags -->
#   </meta>
#  </head>
#  <body class="section_fact_sheet_v2" id="section_mediav1.0|bolsamania_fact_sheet_v2_38d974fc78818d0797deab2892acf957_es_s">
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NGNRZVQ9" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <!-- Begin google-analytics Tag BMS-->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-Y9XKHVSX71">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#     function gtag(){dataLayer.push(arguments);}
#     gtag('js', new Date());
#
#     gtag('config', 'G-Y9XKHVSX71');
#   </script>
#   <!-- End google-analytics Tag BMS-->
#   <!-- Begin Bing Tag BMS-->
#   <script>
#    (function(w,d,t,r,u){var f,n,i;w[u]=w[u]||[],f=function(){var o={ti:"5564975"};o.q=w[u],w[u]=new UET(o),w[u].push("pageLoad")},n=d.createElement(t),n.src=r,n.async=1,n.onload=n.onreadystatechange=function(){var s=this.readyState;s&&s!=="loaded"&&s!=="complete"||(f(),n.onload=n.onreadystatechange=null)},i=d.getElementsByTagName(t)[0],i.parentNode.insertBefore(n,i)})(window,document,"script","//bat.bing.com/bat.js","uetq");
#   </script>
#   <noscript>
#    <img alt="tag bing" height="0" src="//bat.bing.com/action/0?ti=5564975&amp;Ver=2" style="display:none; visibility: hidden;" width="0"/>
#   </noscript>
#   <!-- End Bing Tag BMS-->
#   <ins vtx-conf="{}" vtx-position="skin">
#   </ins>
#   <div class="adk-slot interstitial">
#    <div id="adk_interstitial0">
#    </div>
#    <div id="adk_interstitial">
#    </div>
#   </div>
#   <div id="bmsapp">
#    <div class="clearfix ads-parent">
#     <div class="banner">
#      <ins vtx-conf='{"onDemand":true,"label":"leftTower","minWidth":"1700","top":"50px","relative":".container"}' vtx-position="sky">
#      </ins>
#     </div>
#    </div>
#    <div class="clearfix ads-parent">
#     <div class="banner">
#      <ins vtx-conf='{"onDemand":true,"label":"rightTower","minWidth":"1700","top":"50px","relative":".container"}' vtx-position="sky">
#      </ins>
#     </div>
#    </div>
#    <div class="cabecera-rail">
#     <div class="container max-width-md">
#      <div class="header-banner">
#       <div class="clearfix ads-parent">
#        <div class="fixed-height-banner">
#         <ins vtx-conf="{}" vtx-position="ldb">
#         </ins>
#        </div>
#       </div>
#      </div>
#     </div>
#     <header class="main-header" ref="mainHeader">
#      <div class="container max-width-md">
#       <div class="flex items-center justify-between">
#        <div class="menu-display">
#         <div class="menuNavButton hamburger hamburger--elastic" v-on:click="showHideMenus('bolsamania')">
#          <div class="hamburger-box">
#           <div class="hamburger-inner">
#           </div>
#          </div>
#         </div>
#         <a class="small-logo" href="https://www.bolsamania.com/">
#          <img alt="Bolsamania.com" class="logo" src="//rsrc.s3wfg.com/web/img/logos/svg/small-logo-bm.svg" style="width: 100px"/>
#         </a>
#        </div>
#        <div class="center-box">
#         <a class="main-logo" href="https://www.bolsamania.com/">
#          <strong class="is-hidden">
#           Bolsamania
#          </strong>
#          <span class="logoBM">
#           <img alt="Bolsamania.com" class="logo" src="//rsrc.s3wfg.com/web/img/logos/svg/bolsamania-mainlogo.svg"/>
#          </span>
#         </a>
#         <time class="date-home display@lg">
#          22 abr, 2024                        |
#                         Actualizado a las                        10:08
#         </time>
#        </div>
#        <div class="flex flex-column button-group">
#         <a aria-label="modal buscar" class="btn btn-header display@sm search-btn" data-params='{"modal":true}' data-target="#headerModal" data-toggle="modal" data-uri="/busqueda.html" href="#" role="button" v-on:click="loadModal">
#          <i class="icon">
#           <svg height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#            <path d="M10,18c1.846,0,3.543-0.635,4.897-1.688l4.396,4.396l1.414-1.414l-4.396-4.396C17.365,13.543,18,11.846,18,10 c0-4.411-3.589-8-8-8s-8,3.589-8,8S5.589,18,10,18z M10,4c3.309,0,6,2.691,6,6s-2.691,6-6,6s-6-2.691-6-6S6.691,4,10,4z">
#            </path>
#           </svg>
#          </i>
#          <span>
#           Buscar
#          </span>
#         </a>
#         <template v-if="menus.user">
#          <div class="user-menu">
#           <span class="btn btn-header user-menu-btn margin-top-xs" v-expand-user-menu="">
#            <i class="icon">
#             <svg height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M7.5 6.5C7.5 8.981 9.519 11 12 11s4.5-2.019 4.5-4.5S14.481 2 12 2 7.5 4.019 7.5 6.5zM20 21h1v-1c0-3.859-3.141-7-7-7h-4c-3.86 0-7 3.141-7 7v1h1 1 14H20z">
#              </path>
#             </svg>
#            </i>
#            <span>
#             Mi perfil
#            </span>
#           </span>
#           <div class="hide" v-fold-user-menu="">
#            <ul aria-labelledby="dropdownMenuUser" class="dropdown-menu">
#             <div class="user-whois">
#              <i v-bind:class="'user-profile-pic user-' + menus.user.letter">
#              </i>
#              <h3>
#               {{ menus.user.data_crypt.username }}
#              </h3>
#             </div>
#             <template v-for="item in menus.user.menu">
#              <li v-if="item.link">
#               <a v-bind:href="item.link">
#                <i class="icon" v-bind:class="item.icon">
#                </i>
#                {{item.text}}
#               </a>
#              </li>
#              <li v-bind:class="item.icon" v-bind:role="item.text" v-else="">
#              </li>
#             </template>
#            </ul>
#           </div>
#          </div>
#         </template>
#         <template v-else="">
#          <a aria-label="modal login" class="btn btn-header user-menu-btn margin-top-xs" data-params='{"modal":true}' data-target="#headerModal" data-toggle="modal" data-uri="/login.html" href="#" role="button" v-on:click="loadModal">
#           <i class="icon">
#            <svg height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#             <path d="M10.998 16L15.998 12 10.998 8 10.998 11 1.998 11 1.998 13 10.998 13z">
#             </path>
#             <path d="M12.999,2.999c-2.405,0-4.665,0.937-6.364,2.637L8.049,7.05c1.322-1.322,3.08-2.051,4.95-2.051s3.628,0.729,4.95,2.051 S20,10.13,20,12s-0.729,3.628-2.051,4.95s-3.08,2.051-4.95,2.051s-3.628-0.729-4.95-2.051l-1.414,1.414 c1.699,1.7,3.959,2.637,6.364,2.637s4.665-0.937,6.364-2.637C21.063,16.665,22,14.405,22,12s-0.937-4.665-2.637-6.364 C17.664,3.936,15.404,2.999,12.999,2.999z">
#             </path>
#            </svg>
#           </i>
#           <span>
#            Acceder
#           </span>
#          </a>
#         </template>
#        </div>
#       </div>
#       <div class="main-section-header">
#        <div class="mask">
#         <div>
#          <nav class="main-quick-navbar flex items-center justify-between">
#           <ul>
#            <li>
#             <a href="https://www.bolsamania.com/bolsa-cotizaciones/home.html">
#              Cotizaciones
#             </a>
#            </li>
#            <li>
#             <a href="https://www.bolsamania.com/ultimas/index.html">
#              Noticias
#             </a>
#            </li>
#            <li>
#             <a href="https://www.bolsamania.com/analisis-de-bolsa.html">
#              Análisis
#             </a>
#            </li>
#            <li>
#             <a href="https://www.bolsamania.com/criptodivisas/index.html">
#              Criptodivisas
#             </a>
#            </li>
#            <li>
#             <a href="https://www.bolsamania.com/mi-cartera">
#              Mi Cartera
#              <sup style="color:#000;font-size: 0.7em;">
#               Nuevo
#              </sup>
#             </a>
#            </li>
#           </ul>
#           <ul>
#            <li>
#             <a href="https://www.bolsamania.com/tiempo-real.html">
#              Tiempo Real
#             </a>
#            </li>
#            <li>
#             <a href="https://www.bolsamania.com/trader_watch.html">
#              Trader Watch
#             </a>
#            </li>
#           </ul>
#          </nav>
#          <div class="card card-market margin-left-xs ibex-quick-rewiew">
#           <div>
#            <div class="flex justify-between">
#             <h2 class="card-name">
#              <a href="https://www.bolsamania.com/indice/IBEX-35" target="_self" title="IBEX 35">
#               IBEX 35
#              </a>
#             </h2>
#            </div>
#            <div class="">
#             <ul class="flex justify-between">
#              <li class="card-list">
#               10.786,700
#              </li>
#              <li class="card-list">
#               <span class="greenarrowleft">
#                0,53%
#               </span>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#          <div class="is-hidden" v-ls-conf="[]">
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </header>
#    </div>
#    <nav class="main-header-navbar">
#     <ul class="follow-us">
#      <li>
#       <a aria-label="button ir a bolsamania twitter" href="https://twitter.com/bolsamania" rel="noopener" role="button" target="_blank">
#        <svg height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#         <title>
#          Ir a Twitter de Bolsamania
#         </title>
#         <path d="M19.633,7.997c0.013,0.175,0.013,0.349,0.013,0.523c0,5.325-4.053,11.461-11.46,11.461c-2.282,0-4.402-0.661-6.186-1.809	c0.324,0.037,0.636,0.05,0.973,0.05c1.883,0,3.616-0.636,5.001-1.721c-1.771-0.037-3.255-1.197-3.767-2.793	c0.249,0.037,0.499,0.062,0.761,0.062c0.361,0,0.724-0.05,1.061-0.137c-1.847-0.374-3.23-1.995-3.23-3.953v-0.05	c0.537,0.299,1.16,0.486,1.82,0.511C3.534,9.419,2.823,8.184,2.823,6.787c0-0.748,0.199-1.434,0.548-2.032	c1.983,2.443,4.964,4.04,8.306,4.215c-0.062-0.3-0.1-0.611-0.1-0.923c0-2.22,1.796-4.028,4.028-4.028	c1.16,0,2.207,0.486,2.943,1.272c0.91-0.175,1.782-0.512,2.556-0.973c-0.299,0.935-0.936,1.721-1.771,2.22	c0.811-0.088,1.597-0.312,2.319-0.624C21.104,6.712,20.419,7.423,19.633,7.997z">
#         </path>
#        </svg>
#       </a>
#      </li>
#      <li>
#       <a aria-label="button ir a bolsamania facebook" href="https://www.facebook.com/Bolsamania" rel="noopener" role="button" target="_blank">
#        <svg height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#         <title>
#          Ir a Facebook de Bolsamania
#         </title>
#         <path d="M13.397,20.997v-8.196h2.765l0.411-3.209h-3.176V7.548c0-0.926,0.258-1.56,1.587-1.56h1.684V3.127	C15.849,3.039,15.025,2.997,14.201,3c-2.444,0-4.122,1.492-4.122,4.231v2.355H7.332v3.209h2.753v8.202H13.397z">
#         </path>
#        </svg>
#       </a>
#      </li>
#      <li>
#       <a aria-label="button ir a bolsamania flipboard" href="https://flipboard.com/@Bolsamania?utm_campaign=tools&amp;utm_medium=follow&amp;action=follow&amp;utm_source=www.bolsamania.com" rel="noopener" role="button" target="_blank">
#        <svg aria-hidden="true" height="24" viewbox="0 0 448 512" width="24">
#         <title>
#          Ir a Flipboard de Bolsamania
#         </title>
#         <path d="M0 32v448h448V32H0zm358.4 179.2h-89.6v89.6h-89.6v89.6H89.6V121.6h268.8v89.6z">
#         </path>
#        </svg>
#       </a>
#      </li>
#      <li>
#       <a aria-label="button ir a bolsamania youtube" href="https://www.youtube.com/user/bolsamaniaTV" rel="noopener" role="button" target="_blank">
#        <svg height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#         <title>
#          Ir a Bolsamania TV
#         </title>
#         <path d="M21.593,7.203c-0.23-0.858-0.905-1.535-1.762-1.766C18.265,5.007,12,5,12,5S5.736,4.993,4.169,5.404	c-0.84,0.229-1.534,0.921-1.766,1.778c-0.413,1.566-0.417,4.814-0.417,4.814s-0.004,3.264,0.406,4.814	c0.23,0.857,0.905,1.534,1.763,1.765c1.582,0.43,7.83,0.437,7.83,0.437s6.265,0.007,7.831-0.403c0.856-0.23,1.534-0.906,1.767-1.763	C21.997,15.281,22,12.034,22,12.034S22.02,8.769,21.593,7.203z M9.996,15.005l0.005-6l5.207,3.005L9.996,15.005z">
#         </path>
#        </svg>
#       </a>
#      </li>
#     </ul>
#     <div class="hamburger hamburger--elastic is-active" v-on:click="showHideMenus('bolsamania')">
#      <div class="hamburger-box">
#       <div class="hamburger-inner">
#       </div>
#      </div>
#     </div>
#     <a aria-label="modal buscar" class="btn btn-header visible-xs search-btn" data-params='{"modal":true}' data-target="#headerModal" data-toggle="modal" data-uri="/busqueda.html" href="#" role="button" v-on:click="loadModal">
#      <i class="icon">
#       <svg height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#        <title>
#         Buscar
#        </title>
#        <path d="M10,18c1.846,0,3.543-0.635,4.897-1.688l4.396,4.396l1.414-1.414l-4.396-4.396C17.365,13.543,18,11.846,18,10 c0-4.411-3.589-8-8-8s-8,3.589-8,8S5.589,18,10,18z M10,4c3.309,0,6,2.691,6,6s-2.691,6-6,6s-6-2.691-6-6S6.691,4,10,4z">
#        </path>
#       </svg>
#      </i>
#      <span>
#       Buscar
#      </span>
#     </a>
#     <template v-if="menus.show">
#      <div class="clearfix ads-parent">
#       <div class="banner">
#        <div class="publicidad">
#         Publicidad
#        </div>
#        <ins v-ads-display-async="" vtx-conf='{"reservePosition":"menu","bannedSizes":["300x600"],"onDemand":true,"refreshable":false,"label":"enmenu","disableArf":true}' vtx-position="mpu">
#        </ins>
#       </div>
#      </div>
#     </template>
#     <ul>
#      <li class="submenu" v-bind:class="{active: menus.subMenuIsActive}">
#       <a href="https://www.bolsamania.com/bolsa-cotizaciones/home.html" v-on:click="toggleSubMenu">
#        Cotizaciones
#       </a>
#       <ul class="main-submenu">
#        <li>
#         <a href="https://www.bolsamania.com/bolsa-cotizaciones/home.html">
#          Portada De Cotizaciones
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/bolsa-cotizaciones/indices.html">
#          Índices
#         </a>
#        </li>
#        <li class="adirecto">
#         <a href="https://www.bolsamania.com/indice/IBEX-35">
#          Ibex 35
#         </a>
#        </li>
#        <li class="adirecto">
#         <a href="https://www.bolsamania.com/mercado/MERCADO-CONTINUO">
#          Mercado Continuo
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/divisa">
#          Divisas
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/bolsa-cotizaciones/materias-primas.html">
#          Materias Primas
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/criptodivisas/index.html">
#          Criptodivisas
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/derivados-warrants.html">
#          Warrants
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/bolsa-cotizaciones/renta-fija.html">
#          Renta Fija
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/bolsa-cotizaciones/etfs.html">
#          ETF
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/prima-riesgo/">
#          Prima De Riesgo
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/tiempo-real.html">
#          Tiempo Real
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/favoritos">
#          Favoritos
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li v-bind:class="{active: menus.subMenuIsActive}">
#       <a href="https://www.bolsamania.com/mi-cartera" v-on:click="toggleSubMenu">
#        Mi Cartera
#        <sup style="color:#000;font-size: 0.7em;">
#         Nuevo
#        </sup>
#       </a>
#      </li>
#      <li class="submenu" v-bind:class="{active: menus.subMenuIsActive}">
#       <a href="https://www.bolsamania.com/ultimas/index.html" v-on:click="toggleSubMenu">
#        Noticias
#       </a>
#       <ul class="main-submenu">
#        <li>
#         <a href="https://www.bolsamania.com/ultimas/index.html">
#          Últimas
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/pulsos/index.html">
#          Pulsos
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/mercados/index.html">
#          Mercados
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/noticias/ultima-hora">
#          Última Hora
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/empresas/index.html">
#          Empresas
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/economia/index.html">
#          Economía
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/finanzas-personales/index.html">
#          Finanzas Personales
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/declaracion-impuestos-renta/">
#          Impuestos Y Fiscalidad
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/politica/index.html">
#          Política
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/internacional/index.html">
#          Internacional
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/tecnologia/index.html">
#          Tecnología
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/deportes/index.html">
#          Deportes
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/promocionado/ultimas">
#          Promocionadas
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li class="submenu" v-bind:class="{active: menus.subMenuIsActive}">
#       <a href="https://www.bolsamania.com/analisis-de-bolsa.html" v-on:click="toggleSubMenu">
#        Análisis
#       </a>
#       <ul class="main-submenu">
#        <li>
#         <a href="https://www.bolsamania.com/analisis-de-bolsa.html">
#          Portada De Análisis
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/analisis-tecnico/index.html">
#          Análisis Técnico
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/analisis-fundamental/index.html">
#          Análisis Fundamental
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/expertos/index.html">
#          Expertos
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/analisis-de-bolsa/ratingsEspana.html">
#          Cambios De Recomendación
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/analistas.html">
#          Analistas
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li v-bind:class="{active: menus.subMenuIsActive}">
#       <a href="https://www.bolsamania.com/fundsnews" v-on:click="toggleSubMenu">
#        Fundsnews
#       </a>
#      </li>
#      <li class="submenu" v-bind:class="{active: menus.subMenuIsActive}">
#       <a href="https://www.bolsamania.com/finanzas-personales/index.html" v-on:click="toggleSubMenu">
#        F. Personales
#       </a>
#       <ul class="main-submenu">
#        <li>
#         <a href="https://www.bolsamania.com/finanzas-personales/index.html">
#          Portada
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/declaracion-impuestos-renta/">
#          Impuestos Y Fiscalidad
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/entidades-de-credito.html">
#          Oficinas Bancarias
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/buscartrabajo">
#          Buscar Trabajo
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/mejorescreditos">
#          Mejores Créditos
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/mejoresprestamos">
#          Mejores Préstamos
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li class="submenu" v-bind:class="{active: menus.subMenuIsActive}">
#       <a href="https://www.bolsamania.com/herramientas-de-bolsa.html" v-on:click="toggleSubMenu">
#        Herramientas
#       </a>
#       <ul class="main-submenu">
#        <li>
#         <a href="https://www.bolsamania.com/herramientas-de-bolsa.html">
#          Portada De Herramientas
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/trader_watch.html">
#          Trader Watch
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/formacion-de-bolsa.html">
#          Formación De Bolsa
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/fiscalidad.html">
#          Fiscalidad
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/cartera">
#          Cartera
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bolsamania.com/favoritos">
#          Favoritos
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li v-bind:class="{active: menus.subMenuIsActive}">
#       <a href="https://www.bolsamania.com/agenda" v-on:click="toggleSubMenu">
#        Agenda
#       </a>
#      </li>
#      <li v-bind:class="{active: menus.subMenuIsActive}">
#       <a href="https://www.bolsamania.com/tv.html" v-on:click="toggleSubMenu">
#        TV
#       </a>
#      </li>
#      <li v-bind:class="{active: menus.subMenuIsActive}">
#       <a href="https://www.bolsamania.com/trader_watch.html" v-on:click="toggleSubMenu">
#        Trader Watch
#       </a>
#      </li>
#      <li v-bind:class="{active: menus.subMenuIsActive}">
#       <a href="https://www.bolsamania.com/tiempo-real.html" v-on:click="toggleSubMenu">
#        Tiempo Real
#       </a>
#      </li>
#     </ul>
#    </nav>
#    <div class="modal fade" id="headerModal" no-reload="" ref="vueModalHeader" role="dialog">
#    </div>
#    <div class="container max-width-md">
#     <nav class="breadcrumb" ref="breadcrumb">
#      <ol itemscope="" itemtype="https://schema.org/BreadcrumbList">
#       <li itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
#        <a href="https://www.bolsamania.com/" itemprop="item">
#         <span itemprop="name">
#          Portada
#         </span>
#        </a>
#        <meta content="1" itemprop="position"/>
#       </li>
#       <li itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
#        <a href="https://www.bolsamania.com/bolsa-cotizaciones/home.html" itemprop="item" v-expand-breadcrumb="629">
#         <span it="3" itemprop="name">
#          Cotizaciones
#         </span>
#        </a>
#        <meta content="2" itemprop="position"/>
#        <span class="down" ref="drop" v-expand-breadcrumb="629">
#        </span>
#       </li>
#       <li itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
#        <a href="https://www.bolsamania.com/bolsa-cotizaciones/indices.html" itemprop="item" v-expand-breadcrumb="3">
#         <span it="17" itemprop="name">
#          Índices
#         </span>
#        </a>
#        <meta content="3" itemprop="position"/>
#        <span class="down" ref="drop" v-expand-breadcrumb="3">
#        </span>
#       </li>
#       <li itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
#        <a href="https://www.bolsamania.com/indice/IBEX-35" itemprop="item" v-expand-breadcrumb="17">
#         <span it="77" itemprop="name">
#          España
#         </span>
#        </a>
#        <meta content="4" itemprop="position"/>
#        <span class="down" ref="drop" v-expand-breadcrumb="17">
#        </span>
#       </li>
#       <li class="active" itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
#        <a href="https://www.bolsamania.com/indice/IBEX-35" itemprop="item" v-expand-breadcrumb="77">
#         <span it="88" itemprop="name">
#          Ibex 35
#         </span>
#        </a>
#        <meta content="5" itemprop="position"/>
#        <span class="down" ref="drop" v-expand-breadcrumb="77">
#        </span>
#       </li>
#      </ol>
#     </nav>
#     <div class="breadcrumb-child">
#      <div class="hide" id="bread-child-629">
#       <ul>
#        <li class="active" it="3">
#         <a class="" href="https://www.bolsamania.com/bolsa-cotizaciones/home.html">
#          Cotizaciones
#         </a>
#        </li>
#        <li it="4">
#         <a class="" href="https://www.bolsamania.com/ultimas/index.html">
#          Noticias
#         </a>
#        </li>
#        <li it="5">
#         <a class="" href="https://www.bolsamania.com/analisis-de-bolsa.html">
#          Análisis
#         </a>
#        </li>
#        <li it="665">
#         <a class="" href="https://www.bolsamania.com/criptodivisas/index.html">
#          Criptodivisas
#         </a>
#        </li>
#        <li it="541">
#         <a class="" href="https://www.bolsamania.com/fundsnews">
#          Fundsnews
#         </a>
#        </li>
#        <li it="666">
#         <a class="" href="https://www.bolsamania.com/tiempo-real.html">
#          Tiempo Real
#         </a>
#        </li>
#        <li it="47">
#         <a class="" href="https://www.bolsamania.com/trader_watch.html">
#          Trader Watch
#         </a>
#        </li>
#        <li it="793">
#         <a class="" href="https://www.bolsamania.com/mi-cartera">
#          Mi cartera
#          <sup style="color:#000;font-size: 0.7em;">
#           nuevo
#          </sup>
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="hide" id="bread-child-3">
#       <ul>
#        <li it="15">
#         <a class="" href="https://www.bolsamania.com/bolsa-cotizaciones/home.html">
#          Portada de Cotizaciones
#         </a>
#        </li>
#        <li class="active" it="17">
#         <a class="" href="https://www.bolsamania.com/bolsa-cotizaciones/indices.html">
#          Índices
#         </a>
#        </li>
#        <li it="684">
#         <a class="adirecto" href="https://www.bolsamania.com/indice/IBEX-35">
#          Ibex 35
#         </a>
#        </li>
#        <li it="685">
#         <a class="adirecto" href="https://www.bolsamania.com/mercado/MERCADO-CONTINUO">
#          Mercado Continuo
#         </a>
#        </li>
#        <li it="18">
#         <a class="" href="https://www.bolsamania.com/divisa">
#          Divisas
#         </a>
#        </li>
#        <li it="21">
#         <a class="" href="https://www.bolsamania.com/bolsa-cotizaciones/materias-primas.html">
#          Materias Primas
#         </a>
#        </li>
#        <li it="523">
#         <a class="" href="https://www.bolsamania.com/criptodivisas/index.html">
#          Criptodivisas
#         </a>
#        </li>
#        <li it="8">
#         <a class="" href="https://www.bolsamania.com/derivados-warrants.html">
#          Warrants
#         </a>
#        </li>
#        <li it="19">
#         <a class="" href="https://www.bolsamania.com/bolsa-cotizaciones/renta-fija.html">
#          Renta Fija
#         </a>
#        </li>
#        <li it="20">
#         <a class="" href="https://www.bolsamania.com/bolsa-cotizaciones/etfs.html">
#          ETF
#         </a>
#        </li>
#        <li it="22">
#         <a class="" href="https://www.bolsamania.com/prima-riesgo/">
#          Prima de Riesgo
#         </a>
#        </li>
#        <li it="13">
#         <a class="" href="https://www.bolsamania.com/tiempo-real.html">
#          Tiempo Real
#         </a>
#        </li>
#        <li it="535">
#         <a class="" href="https://www.bolsamania.com/favoritos">
#          Favoritos
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="hide" id="bread-child-17">
#       <ul>
#        <li it="638">
#         <a class="" href="https://www.bolsamania.com/bolsa-cotizaciones/indices.html">
#          Portada Índices
#         </a>
#        </li>
#        <li class="active" it="77">
#         <a class="" href="https://www.bolsamania.com/indice/IBEX-35">
#          España
#         </a>
#        </li>
#        <li it="78">
#         <a class="" href="https://www.bolsamania.com/indice/DOW-JONES">
#          EEUU
#         </a>
#        </li>
#        <li it="79">
#         <a class="" href="https://www.bolsamania.com/indice/DAX">
#          Alemania
#         </a>
#        </li>
#        <li it="81">
#         <a class="" href="https://www.bolsamania.com/indice/CAC-40">
#          Francia
#         </a>
#        </li>
#        <li it="82">
#         <a class="" href="https://www.bolsamania.com/indice/PSI-20">
#          Portugal
#         </a>
#        </li>
#        <li it="83">
#         <a class="" href="https://www.bolsamania.com/indice/EURONEXT-BEL-20">
#          Bélgica
#         </a>
#        </li>
#        <li it="84">
#         <a class="" href="https://www.bolsamania.com/indice/AEX">
#          Holanda
#         </a>
#        </li>
#        <li it="85">
#         <a class="" href="https://www.bolsamania.com/indice/SMI">
#          Suiza
#         </a>
#        </li>
#        <li it="86">
#         <a class="" href="https://www.bolsamania.com/indice/HANG-SENG">
#          Asia
#         </a>
#        </li>
#        <li it="87">
#         <a class="" href="https://www.bolsamania.com/indice/STOXX600">
#          Índices Globales
#         </a>
#        </li>
#        <li it="124">
#         <a class="" href="https://www.bolsamania.com/indice/IPC">
#          Latam
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="show" id="bread-child-77">
#       <ul>
#        <li class="active" it="88">
#         <a class="" href="https://www.bolsamania.com/indice/IBEX-35">
#          Ibex 35
#         </a>
#        </li>
#        <li it="89">
#         <a class="" href="https://www.bolsamania.com/mercado/MERCADO-CONTINUO">
#          MERCADO CONTINUO
#         </a>
#        </li>
#        <li it="90">
#         <a class="" href="https://www.bolsamania.com/indice/LATIBEX">
#          Latibex All
#         </a>
#        </li>
#        <li it="91">
#         <a class="" href="https://www.bolsamania.com/indice/LATIBEX-BRASIL">
#          Latibex Brasil
#         </a>
#        </li>
#        <li it="92">
#         <a class="" href="https://www.bolsamania.com/mercado/MERCADO-ALTERNATIVO-BURSATIL">
#          BME Growth - MAB
#         </a>
#        </li>
#        <li it="141">
#         <a class="" href="https://www.bolsamania.com/mercado/MAB-SICAVS">
#          MAB SICAVS
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="ficha-headline-box">
#      <h1>
#       Cotización IBEX 35
#      </h1>
#      <div class="headline-details-module">
#       <div class="headline-details">
#        <div class="headline-details-primary">
#         <div class="headline-box">
#          <div class="box">
#           <time>
#            <span>
#             <span class="ls" data-field="fecha_hora_cotizacion" data-grid="ls_grid" data-item="item_50107012_55_df" data-source="lightstreamer">
#              09:54 22/04/24
#             </span>
#            </span>
#           </time>
#           <h3>
#            <span class="ls" data-field="precio_ultima_cotizacion" data-grid="ls_grid" data-item="item_50107012_55_df" data-source="lightstreamer">
#             10.786,700
#            </span>
#           </h3>
#          </div>
#          <div class="box-column">
#           <div class="status-arrows">
#            <span>
#             <span class="ls" data-field="variacion_puntos" data-grid="ls_grid" data-item="item_50107012_55_df" data-source="lightstreamer">
#              <span class="cgreen">
#               57,200
#              </span>
#             </span>
#            </span>
#            <span>
#             <span class="ls" data-field="variacion_porcentual" data-grid="ls_grid" data-item="item_50107012_55_df" data-source="lightstreamer">
#              <span class="greenarrowleft">
#               0,53%
#              </span>
#             </span>
#            </span>
#           </div>
#          </div>
#         </div>
#         <!-- Grafico rangos -->
#         <div class="chart-range-container">
#          <div class="chart-range-box margin_left">
#           <div class="chart-range-title">
#            <span class="text_title">
#             RANGO DIARIO
#            </span>
#            <span class="text_low">
#             10.786,700
#            </span>
#            <span class="text_high">
#             10.847,000
#            </span>
#           </div>
#           <div class="chart-range-bar">
#            <span class="close_value l-0">
#             <i class="right" title="CIERRE:10.729,500">
#              CIERRE:10.729,500
#             </i>
#            </span>
#            <div class="chart-range-session green r-47 w-53">
#             <span class="last_value l-0">
#              10.786,700
#             </span>
#             <span class="open_value r-0">
#              <i class="" title="APERTURA:10.818,900">
#               APERTURA:10.818,900
#              </i>
#             </span>
#            </div>
#           </div>
#          </div>
#          <div class="chart-range-box anual">
#           <div class="chart-range-title">
#            <span class="text_title">
#             Rango Anual
#            </span>
#            <span class="text_low">
#             8.879,300
#            </span>
#            <span class="text_high">
#             11.140,100
#            </span>
#           </div>
#           <div class="chart-range-bar">
#            <div class="chart-range-session green l-84 w-3">
#             <span class="text_value left" title="Última Sesión:10.729,500">
#              Última Sesión
#             </span>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="banner-box">
#         <figure class="fixed-height-image">
#          <img class="lazy" src="//rsrc.s3wfg.com/web/img/headers_bm/indice.jpg"/>
#         </figure>
#        </div>
#       </div>
#      </div>
#      <div v-ls-conf='{"type":"equal","table":"ls_grid","data":{"precio_ultima_cotizacion":{"dec":3},"variacion_puntos":{"fxSet":"color","cssSet":"color","dec":3}}}'>
#      </div>
#      <div class="is-hidden" v-set-factsheet-last-visited-info='{"ins":"262980*IBEX 35*https:\/\/www.bolsamania.com\/indice\/IBEX-35*item_50107012_55_df**10786.7000*0.53311*2024-04-22 09:54:59","site_folder_securities":""}'>
#      </div>
#      <div id="header-factsheet-social-buttons" v-factsheet-social-buttons='{"site_id":"2","twitter_account":"Bolsamania","module":"html\/bms\/v3\/socialButtons","link":"https:\/\/www.bolsamania.com\/indice\/IBEX-35","csi":"262980","type":"indice","name":"IBEX 35","ticker":"","price":"10.786%2C70","title":"Precios hist\u00f3ricos de IBEX 35","img":"https:\/\/www.bolsamania.com\/motorGraficas\/grafica.php?idCliente=bolsamania&amp;idProyecto=cotizaciones&amp;idOrden=10&amp;key=77df06b9b0a9439b12fa14a17d14e708&amp;numDat=1&amp;dato1=ES0SI0000005%3AIBEX-35%3AI%3A55%3A50107012&amp;periodo=0&amp;stream=1&amp;idGrafica=LIN_001","createSocialMetas":1}'>
#      </div>
#     </div>
#     <div id="lastVisitedCookie" v-factsheet-last-visited-cookie="">
#     </div>
#     <krux-component data="..." id="4474">
#     </krux-component>
#     <div class="bloque container-vertical-navbar menu-scroll-limit">
#      <div class="section75">
#       <aside class="market--first--navegation stickyElement" id="summary" ref="scrollmeContainer" v-infinite-scroll="" v-set-infinite-scroll-items='{"items":{"":{"id":"","headline":"Listado de acciones","launchPageViewEvent":false,"url":"https:\/\/www.bolsamania.com\/indice\/IBEX-35","urlScroll":"https:\/\/www.bolsamania.com\/scroll_0\/indice\/IBEX-35","urlSwipe":"https:\/\/www.bolsamania.com\/swipe_0\/indice\/IBEX-35","children":{"items":{"":{"id":"","headline":"Vista Normal","launchPageViewEvent":false,"url":"https:\/\/www.bolsamania.com\/indice\/IBEX-35","urlScroll":"https:\/\/www.bolsamania.com\/scroll_0\/indice\/IBEX-35","urlSwipe":"https:\/\/www.bolsamania.com\/swipe_0\/indice\/IBEX-35","children":null,"title":"Bolsamania \u00b7 Ficha de Instrumento - Bolsamania.com"},"vista-estadistica":{"id":"vista-estadistica","headline":"Vista Estad\u00edstica","launchPageViewEvent":true,"url":"https:\/\/www.bolsamania.com\/indice\/IBEX-35\/vista-estadistica","urlScroll":"https:\/\/www.bolsamania.com\/scroll_2\/indice\/IBEX-35\/vista-estadistica","urlSwipe":"https:\/\/www.bolsamania.com\/swipe_2\/indice\/IBEX-35\/vista-estadistica","children":null}}},"title":"Cotizaci\u00f3n de IBEX 35: Acciones e informaci\u00f3n - Bolsamania.com","remove":true},"historico-precios":{"id":"historico-precios","headline":"Hist\u00f3rico","launchPageViewEvent":true,"url":"https:\/\/www.bolsamania.com\/indice\/IBEX-35\/historico-precios","urlScroll":"https:\/\/www.bolsamania.com\/scroll_2\/indice\/IBEX-35\/historico-precios","urlSwipe":"https:\/\/www.bolsamania.com\/swipe_2\/indice\/IBEX-35\/historico-precios","children":null,"title":"Precios hist\u00f3ricos de IBEX 35 - Bolsamania.com"},"warrants":{"id":"warrants","headline":"Warrants","launchPageViewEvent":true,"url":"https:\/\/www.bolsamania.com\/indice\/IBEX-35\/warrants","urlScroll":"https:\/\/www.bolsamania.com\/scroll_3\/indice\/IBEX-35\/warrants","urlSwipe":"https:\/\/www.bolsamania.com\/swipe_3\/indice\/IBEX-35\/warrants","children":{"items":{"":{"id":"","headline":"Buscador","launchPageViewEvent":false,"url":"https:\/\/www.bolsamania.com\/indice\/IBEX-35\/warrants","urlScroll":"https:\/\/www.bolsamania.com\/scroll_0\/indice\/IBEX-35\/warrants","urlSwipe":"https:\/\/www.bolsamania.com\/swipe_0\/indice\/IBEX-35\/warrants","children":null,"title":"Bolsamania \u00b7 Ficha de Instrumento - Bolsamania.com"},"simulador-cobertura":{"id":"simulador-cobertura","headline":"Simulador de cobertura","launchPageViewEvent":true,"url":"https:\/\/www.bolsamania.com\/indice\/IBEX-35\/warrants\/simulador-cobertura","urlScroll":"https:\/\/www.bolsamania.com\/scroll_2\/indice\/IBEX-35\/warrants\/simulador-cobertura","urlSwipe":"https:\/\/www.bolsamania.com\/swipe_2\/indice\/IBEX-35\/warrants\/simulador-cobertura","children":null}}},"title":"Warrants del subyacente de IBEX 35 - Bolsamania.com"},"ficha":{"id":"ficha","headline":"Ficha","launchPageViewEvent":true,"url":"https:\/\/www.bolsamania.com\/indice\/IBEX-35\/ficha","urlScroll":"https:\/\/www.bolsamania.com\/scroll_4\/indice\/IBEX-35\/ficha","urlSwipe":"https:\/\/www.bolsamania.com\/swipe_4\/indice\/IBEX-35\/ficha","children":null,"title":"Datos de IBEX 35 - Bolsamania.com"},"noticias":{"id":"noticias","headline":"Noticias","launchPageViewEvent":true,"url":"https:\/\/www.bolsamania.com\/indice\/IBEX-35\/noticias","urlScroll":"https:\/\/www.bolsamania.com\/scroll_5\/indice\/IBEX-35\/noticias","urlSwipe":"https:\/\/www.bolsamania.com\/swipe_5\/indice\/IBEX-35\/noticias","children":{"items":{"":{"id":"","headline":"\u00daltimas","launchPageViewEvent":false,"url":"https:\/\/www.bolsamania.com\/indice\/IBEX-35\/noticias","urlScroll":"https:\/\/www.bolsamania.com\/scroll_0\/indice\/IBEX-35\/noticias","urlSwipe":"https:\/\/www.bolsamania.com\/swipe_0\/indice\/IBEX-35\/noticias","children":null,"title":"Bolsamania \u00b7 Ficha de Instrumento - Bolsamania.com"},"analisis-tecnico":{"id":"analisis-tecnico","headline":"A. T\u00e9cnico","launchPageViewEvent":true,"url":"http ...
#        <div class="sections_container text-uppercase">
#         <ul>
#          <li class="button_sections" id="item-scroll-" ref="item-scroll-">
#           <a href="https://www.bolsamania.com/indice/IBEX-35">
#            <i class="mdi icon icon-list">
#            </i>
#            <span>
#             Listado de acciones
#            </span>
#           </a>
#          </li>
#          <li class="button_sections active" id="item-scroll-historico-precios" ref="item-scroll-historico-precios">
#           <a href="https://www.bolsamania.com/indice/IBEX-35/historico-precios">
#            <i class="mdi icon icon-historic-price">
#            </i>
#            <span>
#             Histórico
#            </span>
#           </a>
#          </li>
#          <li class="button_sections" id="item-scroll-warrants" ref="item-scroll-warrants">
#           <a href="https://www.bolsamania.com/indice/IBEX-35/warrants">
#            <i class="mdi icon icon-warrants">
#            </i>
#            <span>
#             Warrants
#            </span>
#           </a>
#          </li>
#          <li class="button_sections" id="item-scroll-ficha" ref="item-scroll-ficha">
#           <a href="https://www.bolsamania.com/indice/IBEX-35/ficha">
#            <i class="mdi icon icon-file">
#            </i>
#            <span>
#             Ficha
#            </span>
#           </a>
#          </li>
#          <li class="button_sections" id="item-scroll-noticias" ref="item-scroll-noticias">
#           <a href="https://www.bolsamania.com/indice/IBEX-35/noticias">
#            <i class="mdi icon icon-news">
#            </i>
#            <span>
#             Noticias
#            </span>
#           </a>
#          </li>
#         </ul>
#        </div>
#        <a aria-label="button scroll down" class="scrollme" href="javascript:void(0)" ref="scrollme" role="button" v-if="menus.menusEquities &gt; 6" v-more-tabs="">
#         <span class="mdi mdi-chevron-down">
#         </span>
#        </a>
#       </aside>
#       <div class="container-carusel">
#        <div class="height100 d-flex header-carusel">
#         <div class="wrap border-right" ref="scrollCarousel">
#          <ul class="news-guidline-header carousel is-set">
#           <li class="news-guidline-header-story flex items-center carousel-seat" ref="nav-item-scroll-">
#            <span>
#             <div v-bind:style="{width: storiesRelated.scrollNewsPercent + '%'}">
#             </div>
#             <a href="https://www.bolsamania.com/indice/IBEX-35">
#              Listado de acciones
#             </a>
#            </span>
#           </li>
# ...
#        </a>
#       </li>
#       <li>
#        <a href="https://www.bolsamania.com/noticias/mercados/siete-temas-clave-afectaran-mercados-2024-no-perder-vista--16620531.html">
#         7 temas clave que afectarán a los mercados en 2024 y que conviene no perder de vista
#        </a>
#       </li>
#       <li>
#        <a href="https://www.bolsamania.com/noticias/mercados/oportunidades-china-baidu-alibaba-otros-tres-titulos-claramente-infravalorados--16625708.html">
#         Oportunidades en China: "Baidu, Alibaba y otros tres títulos claramente infravalorados"
#        </a>
#       </li>
#       <li>
#        <a href="https://www.bolsamania.com/noticias/empresas/bankinter-recorta-enagas-vender-no-vemos-catalizadores-a-corto--16634531.html">
#         Bankinter recorta drásticamente Enagás a 'vender': "No vemos catalizadores a corto"
#        </a>
#       </li>
#       <li>
#        <a href="https://www.bolsamania.com/noticias/mercados/asia-tine-verde--dejar-china-sin-cambios-tasas-prestamos-referencia--16633797.html">
#         Asia se tiñe de verde tras dejar China sin cambios las tasas de préstamos de referencia
#        </a>
#       </li>
#       <li>
#        <a href="https://www.bolsamania.com/noticias/empresas/tesla-recorta-precios-china-alemania-rebaja-eeuu--16634064.html">
#         Tesla recorta precios en China, Alemania y otros países después de la rebaja en EEUU
#        </a>
#       </li>
#       <li>
#        <a href="https://www.bolsamania.com/noticias/politica/pnv-empata-escanos-bildu-podra-reeditar-gobierno-pse--16633673.html">
#         El PNV empata a escaños con Bildu pero podrá reeditar gobierno con el PSE
#        </a>
#       </li>
#       <li>
#        <a href="https://www.bolsamania.com/noticias/politica/eeuu-ayuda-60000-millones-ucrania--16633800.html">
#         EEUU aprueba una ayuda de más de 60.000 millones de dólares a Ucrania
#        </a>
#       </li>
#      </ol>
#     </section>
#     <section class="card most-read most-read--alt most-read--blue col-3@md col-12@xs">
#      <h2 class="module-headline">
#       Lo más leído
#       <span class="text-bold">
#        - Análisis
#       </span>
#      </h2>
#      <ol>
#       <li>
#        <a href="https://www.bolsamania.com/noticias/analisis-tecnico/dos-valores-del-mercado-continuo-que-tienen-muchas-ganas-de-subir-en-el-corto-plazo--16628464.html">
#         Dos valores del Mercado Continuo que tienen muchas ganas de subir en el corto plazo
#        </a>
#       </li>
#       <li>
#        <a href="https://www.bolsamania.com/noticias/analisis-tecnico/cinco-valores-que-se-deben-tener-muy-en-cuenta-por-tecnico-este-lunes--16629340.html">
#         Cinco valores que se deben tener muy en cuenta por técnico este lunes
#        </a>
#       </li>
#       <li>
#        <a href="https://www.bolsamania.com/noticias/analisis-tecnico/este-valor-rezagado-del-ibex-puede-despertar-en-cualquier-momento--16628654.html">
#         Este valor rezagado del Ibex puede despertar en cualquier momento
#        </a>
#       </li>
#       <li>
#        <a href="https://www.bolsamania.com/noticias/analisis-tecnico/este-chicarro-del-continuo-busca-subirse-por-encima-de-la-media-de-200-sesiones--16629032.html">
#         Este chicharro del Continuo busca subirse por encima de la media de 200 sesiones
#        </a>
#       </li>
#       <li>
#        <a href="https://www.bolsamania.com/noticias/analisis-tecnico/repsol-extiende-la-correccion-del-corto-plazo--16628908.html">
#         Repsol extiende la corrección del corto plazo
#        </a>
#       </li>
#      </ol>
#     </section>
#     <section class="card most-read most-read--alt most-read--green col-3@md col-12@xs">
#      <h2 class="module-headline">
#       Lo más leído
#       <span class="text-bold">
#        - Cripto
#       </span>
#      </h2>
#      <ol>
#       <li>
#        <a href="https://www.bolsamania.com/noticias/criptodivisas/gigantes-bancarios-no-compran-renacer-halving-bitcoin--16629549.html">
#         Los gigantes bancarios no compran un renacer tras el 'halving': "El bitcoin va a caer"
#        </a>
#       </li>
#       <li>
#        <a href="https://www.bolsamania.com/noticias/criptodivisas/bitcoin-pronostico-pesimista-sube-moderacion-halving--16634591.html">
#         El bitcoin cumple el pronóstico pesimista y sube con moderación tras el 'halving'
#        </a>
#       </li>
#       <li>
#        <a href="https://www.bolsamania.com/noticias/criptodivisas/entradas-etf-bitcoin-frenan-halving-encienden-alarmas--16628523.html">
#         Las entradas en los ETF de bitcoin se frenan antes del 'halving' y encienden las alarmas
#        </a>
#       </li>
#       <li>
#        <a href="https://www.bolsamania.com/noticias/criptodivisas/bitcoin-halving-encrucijada-subidas-correccion--16622359.html">
#         El bitcoin llega al 'halving' en una encrucijada: ¿subirá o seguirá corrigiendo?
#        </a>
#       </li>
#       <li>
#        <a href="https://www.bolsamania.com/promocionado/criptodivisas/mega-dice-el-nuevo-token-gamblefi-de-solana-recauda-mas-de-300000-en-preventa.html">
#         Mega Dice, el nuevo token GambleFi de Solana recauda más de 300.000$ en preventa
#        </a>
#       </li>
#      </ol>
#     </section>
#    </div>
#    <div class="bk-white margin-top-md">
#     <div class="container max-width-md">
#      <footer>
#       <div class="footer-header flex flex-column flex-row@md items-center justify-between">
#        <div class="center-box">
#         <a class="main-logo" href="/">
#          <strong class="is-hidden">
#           Bolsamania
#          </strong>
#          <span class="logoBM">
#           <img alt="bolsamania" class="lazy logo" data-original="//rsrc.s3wfg.com/web/img/logos/svg/bolsamania-brand.svg" data-src="//rsrc.s3wfg.com/web/img/logos/svg/bolsamania-brand.svg"/>
#          </span>
#         </a>
#         <ul>
#          <li>
#           <a href="/catalunya">
#            CAT
#           </a>
#          </li>
#          <li>
#           <a href="/mexico">
#            MEX
#           </a>
#          </li>
#          <li>
#           <a href="/argentina">
#            AR
#           </a>
#          </li>
#          <li>
#           <a href="/peru">
#            PER
#           </a>
#          </li>
#          <li>
#           <a href="/colombia">
#            COL
#           </a>
#          </li>
#          <li>
#           <a href="/chile">
#            CHL
#           </a>
#          </li>
#         </ul>
#        </div>
#        <ul class="products-list">
#         <li>
#         </li>
#         <li>
#          <a href="https://www.sharecast.com" rel="nofollow">
#           <img alt="sharecast" class="lazy" data-original="//rsrc.s3wfg.com/web/img/logos/sharecast.png" data-src="//rsrc.s3wfg.com/web/img/logos/sharecast.png"/>
#          </a>
#         </li>
#         <li>
#          <a href="/fundsnews" rel="nofollow">
#           <img alt="fundsnews" class="lazy" data-original="//rsrc.s3wfg.com/web/img/logos/logoFund.svg" data-src="//rsrc.s3wfg.com/web/img/logos/logoFund.svg"/>
#          </a>
#         </li>
#         <li>
#          <a href="https://www.financialred.com" rel="nofollow">
#           <img alt="financialred" class="lazy" data-original="//rsrc.s3wfg.com/web/img/logos/logofinancialred.jpg" data-src="//rsrc.s3wfg.com/web/img/logos/logofinancialred.jpg"/>
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="map-list">
#        <ul>
#         <span>
#          <a href="https://www.bolsamania.com/bolsa-cotizaciones/home.html">
#           Cotizaciones
#          </a>
#         </span>
#         <li>
#          <a href="https://www.bolsamania.com/indice/IBEX-35">
#           Ibex 35
#          </a>
#         </li>
#         <li>
#          <a href="https://www.bolsamania.com/indice/ibex-35">
#           Acciones
#          </a>
#         </li>
#         <li>
#          <a href="https://www.bolsamania.com/bolsa-cotizaciones/indices.html">
#           Índices
#          </a>
#         </li>
#         <li>
#          <a href="https://www.bolsamania.com/criptodivisas/index.html">
#           Criptodivisas
#          </a>
#         </li>
#         <span>
#          <a href="https://www.bolsamania.com/ultimas/index.html">
#           Noticias
#          </a>
#         </span>
#         <li>
#          <a href="https://www.bolsamania.com/noticias/ultima-hora">
#           Última Hora
#          </a>
#         </li>
#         <li>
#          <a href="https://www.bolsamania.com/declaracion-impuestos-renta/">
#           Impuestos Y Fiscalidad
#          </a>
#         </li>
#         <span>
#          <a href="https://www.bolsamania.com/analisis-de-bolsa.html">
#           Análisis
#          </a>
#         </span>
#         <li>
#          <a href="https://www.bolsamania.com/analisis-tecnico/index.html">
#           Análisis Técnico
#          </a>
#         </li>
#         <span>
#          <a href="https://www.bolsamania.com/nota-de-prensa/ultimas">
#           Notas de prensa
#          </a>
#         </span>
#         <span>
#          <a href="https://www.bolsamania.com/herramientas-de-bolsa.html">
#           Herramientas
#          </a>
#         </span>
#        </ul>
#        <ul>
#         <li class="_span_">
#          CONTACTO
#         </li>
#         <li>
#          <a href="/cdn-cgi/l/email-protection#e28b8c848da2808d8e91838f838c8b83cc818d8f" rel="nofollow" target="_blank">
#           Datos de contacto
#          </a>
#         </li>
#         <li>
#          <a href="/cdn-cgi/l/email-protection#7a0a0f18161319131e1b1e3a0c15080e1f02171f1e131b541f09" rel="nofollow" target="_blank">
#           Publicidad
#          </a>
#         </li>
#         <li>
#          <a href="/registro.html" rel="nofollow">
#           Boletines y alertas
#          </a>
#         </li>
#         <li class="_span_">
#          INFORMACIÓN
#         </li>
#         <li>
#          <a href="/legal/aviso-legal" rel="nofollow" target="_blank">
#           Aviso legal
#          </a>
#         </li>
#         <li>
#          <a href="/legal/cookies" rel="nofollow" target="_blank">
#           Política de cookies
#          </a>
#         </li>
#         <li>
#          <a href="/legal/politica-privacidad" rel="nofollow" target="_blank">
#           Política de privacidad
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="flex items-center justify-between">
#        <p>
#         2024 © Bolsamania.com
#        </p>
#        <ul class="follow-us">
#         <li>
#          <a aria-label="button ir a bolsamania twitter" href="https://twitter.com/bolsamania" rel="nofollow" role="button" target="_blank">
#           <svg height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#            <title>
#             Ir a Twitter de Bolsamania
#            </title>
#            <path d="M19.633,7.997c0.013,0.175,0.013,0.349,0.013,0.523c0,5.325-4.053,11.461-11.46,11.461c-2.282,0-4.402-0.661-6.186-1.809	c0.324,0.037,0.636,0.05,0.973,0.05c1.883,0,3.616-0.636,5.001-1.721c-1.771-0.037-3.255-1.197-3.767-2.793	c0.249,0.037,0.499,0.062,0.761,0.062c0.361,0,0.724-0.05,1.061-0.137c-1.847-0.374-3.23-1.995-3.23-3.953v-0.05	c0.537,0.299,1.16,0.486,1.82,0.511C3.534,9.419,2.823,8.184,2.823,6.787c0-0.748,0.199-1.434,0.548-2.032	c1.983,2.443,4.964,4.04,8.306,4.215c-0.062-0.3-0.1-0.611-0.1-0.923c0-2.22,1.796-4.028,4.028-4.028	c1.16,0,2.207,0.486,2.943,1.272c0.91-0.175,1.782-0.512,2.556-0.973c-0.299,0.935-0.936,1.721-1.771,2.22	c0.811-0.088,1.597-0.312,2.319-0.624C21.104,6.712,20.419,7.423,19.633,7.997z">
#            </path>
#           </svg>
#          </a>
#         </li>
#         <li>
#          <a aria-label="button ir a bolsamania facebook" href="https://www.facebook.com/Bolsamania" rel="nofollow" role="button" target="_blank">
#           <svg height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#            <title>
#             Ir a Facebook de Bolsamania
#            </title>
#            <path d="M13.397,20.997v-8.196h2.765l0.411-3.209h-3.176V7.548c0-0.926,0.258-1.56,1.587-1.56h1.684V3.127	C15.849,3.039,15.025,2.997,14.201,3c-2.444,0-4.122,1.492-4.122,4.231v2.355H7.332v3.209h2.753v8.202H13.397z">
#            </path>
#           </svg>
#          </a>
#         </li>
#         <li>
#          <a aria-label="button ir a bolsamania flipboard" href="https://flipboard.com/@Bolsamania?utm_campaign=tools&amp;utm_medium=follow&amp;action=follow&amp;utm_source=www.bolsamania.com" rel="nofollow" role="button" target="_blank">
#           <svg aria-hidden="true" height="24" viewbox="0 0 448 512" width="24">
#            <title>
#             Ir a Flipboard de Bolsamania
#            </title>
#            <path d="M0 32v448h448V32H0zm358.4 179.2h-89.6v89.6h-89.6v89.6H89.6V121.6h268.8v89.6z">
#            </path>
#           </svg>
#          </a>
#         </li>
#         <li>
#          <a aria-label="button ir a bolsamania youtube" href="https://www.youtube.com/user/bolsamaniaTV" rel="nofollow" role="button" target="_blank">
#           <svg height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#            <title>
#             Ir a Bolsamania TV
#            </title>
#            <path d="M21.593,7.203c-0.23-0.858-0.905-1.535-1.762-1.766C18.265,5.007,12,5,12,5S5.736,4.993,4.169,5.404	c-0.84,0.229-1.534,0.921-1.766,1.778c-0.413,1.566-0.417,4.814-0.417,4.814s-0.004,3.264,0.406,4.814	c0.23,0.857,0.905,1.534,1.763,1.765c1.582,0.43,7.83,0.437,7.83,0.437s6.265,0.007,7.831-0.403c0.856-0.23,1.534-0.906,1.767-1.763	C21.997,15.281,22,12.034,22,12.034S22.02,8.769,21.593,7.203z M9.996,15.005l0.005-6l5.207,3.005L9.996,15.005z">
#            </path>
#           </svg>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </footer>
#     </div>
#    </div>
#   </div>
#   <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js">
#   </script>
#   <script>
#    var exdate = new Date();
# 	var extime = 300;
# 	exdate.setSeconds(exdate.getSeconds() + extime);
# 	document.cookie = "html5PopupBMS=1; expires=" + exdate.toUTCString() + "; path=/; SameSite=strict";
#   </script>
#   <script>
#    // Vue
# 	                window.vueConf = {
# 	                    id: '#bmsapp',
# 	                    devMode: false,
# 	                    loginCookieName: 'us_media_users_bolsamania_cn_uid',
# 	                    loginEnabled: true,
# 	                    enableInfiniteScroll: false,
# 	                    swipeNavigationEnabled: 1,
# 	                    locale: 'es',
# 	                    manage: false
# 	                }
#   </script>
#   <script defer="" src="https://rsrc.s3wfg.com/web/webpack/build/js/bolsamania.bundle.js?v=0b2e2a85d530d918b97e8bca76ba51bd_20240422" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    window.ls_dec_sep = ',';
# 		        window.ls_ths_sep = '.';
# 		        window.ls_dec = 2;
# 		        window.ls_symbol_side = 'R';
# 				window.ls_timezone = 'Europe/Madrid';
# 		        window.ls_time_diff = 0;
# 		        window.ls_locale = 'es-ES';
# 		        window.ls_extra_config = {"light":{"up":"#43a047","down":"#c80027","equal":"#000","alert":"#C4E3F3"},"color":{"up":"ls cgreen","down":"ls dred","equal":"ls darkgrey"},"arrow":{"up":"ls greenarrowleft","down":"ls redarrowleft","equal":"ls blackarrowleft"},"image":{"up":"https:\/\/rsrc.s3wfg.com\/web\/img\/whitearrowup.svg","down":"https:\/\/rsrc.s3wfg.com\/web\/img\/whitearrowdown.svg"}};
#   </script>
#   <script data-cfasync="false" src="//rsrc.s3wfg.com/web/js_comun/lightstreamer/ls/lightstreamer-7.0.3.js" type="text/javascript">
#   </script>
#   <script data-cfasync="false" src="//rsrc.s3wfg.com/web/js_comun/lightstreamer/wfgLightstreamer-Media.js" type="text/javascript">
#   </script>
#   <script data-cfasync="false" src="//rsrc.s3wfg.com/web/js_comun/lightstreamer/wfgLightstreamerMediaFunctions-v2.js" type="text/javascript">
#   </script>
#   <script data-cfasync="false" src="//rsrc.s3wfg.com/web/js_comun/lightstreamer/config/bolsamania/ls_bolsamania2020.js" type="text/javascript">
#   </script>
#   <script title="lightstreamer" type="text/javascript">
#    //<![CDATA[
# 					var ls_config = {
# 					    engine: 'bolsamania.com',
# 					    serverlist: ['push.bolsamania.com','push2.bolsamania.com'],
# 					    tables: '\'ls_grid\', \'ls_listado_indices_six\', \'ls_cotation\', \'ls_listado_constituyentes\', \'data_price_fact_sheet_header\''
# 					};
# 					addEvent(window, 'load', addDynamicTables);
# 					addEvent(window, 'load', loadBolsamaniaLS);
#
# 					//]]>
#   </script>
#  </body>
# </html>

# %%
# vamos a seguir usando el metodo ".find_all()", pero en este caso lo que buscaremos son todas las tablas que tenemos en la página web.
tablas = sopa_bolsa.find_all("table")

print("El número de tablas que tenemos en la página web es:", len(tablas))
# Out:
# El número de tablas que tenemos en la página web es: 3

# %%
# veamos que tenemos en cada una de las tablas que hemos extraído de la página web. 
print("En la tabla 1 tenemos: \n ", tablas[0])
print("\n---------------------\n")

print("En la tabla 2 tenemos: \n", tablas[1])
print("\n---------------------\n")

print("En la tabla 3 tenemos: \n", tablas[2])
# Out:
# En la tabla 1 tenemos:
#   <table class="stripped xs-grid-table">
# <tbody>
# <tr>
# <td>Periodo</td>
# <td class="text-right">
#                                     23 mar - 22 abr                                </td>
# </tr>
# <tr>
# <td>Máximo</td>
# <td class="text-right">
#                                     11.140,1000  (27-mar-24)                                </td>
# </tr>
# <tr>
# <td>Mínimo</td>
# <td class="text-right">
#                                     10.499,2000  (16-abr-24)                                </td>
# </tr>
# </tbody>
# </table>
#
# ---------------------
#
# En la tabla 2 tenemos:
#  <table class="stripped xs-grid-table">
# <tbody>
# <tr>
# <td>Diferencia</td>
# <td class="text-right">640,9000</td>
# </tr>
# <tr>
# <td>Promedio</td>
# <td class="text-right">10.851,4167</td>
# </tr>
# <tr>
# <td>Variación %</td>
# <td class="text-right"><span class="dred">-1,91%</span></td>
# </tr>
# </tbody>
# </table>
#
# ---------------------
#
# En la tabla 3 tenemos:
#  <table class="table table-hover cator sortable table-bm xs-grid-table stripped" v-table-sorter="{
#                 'orderBy': 'date',
#                 'orderType': 'asc',
#                 'baseUrl': 'https://www.bolsamania.com/indice/IBEX-35/historico-precios',
#                 'queryString': '?startDate=23-03-2024&amp;endDate=22-04-2024',
#                 'defaultBy': 'date',
#                 'reverse': true
#                 }">
# <thead v-if="tableSorter">
# <tr>
# <th class="text-left" v-table-sorter-by="'date'">Fecha<span></span></th>
# <th class="text-right" v-table-sorter-by="'price'">Precio<span></span></th>
# <th class="text-right" v-table-sorter-by="'fallers'">Variación %<span></span></th>
# <th class="text-right" v-table-sorter-by="'high'">Máximo<span></span></th>
# <th class="text-right" v-table-sorter-by="'low'">Mínimo<span></span></th>
# <th class="text-right" v-table-sorter-by="'open'">Apertura<span></span></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="text-left">25-mar-24</td>
# <td class="text-right">10.952,200</td>
# <td class="text-right"><span class="cgreen">0,08%</span></td>
# <td class="text-right">10.986,000</td>
# <td class="text-right">10.911,500</td>
# <td class="text-right">10.918,000</td>
# </tr>
# <tr>
# <td class="text-left">26-mar-24</td>
# <td class="text-right">10.991,500</td>
# <td class="text-right"><span class="cgreen">0,36%</span></td>
# <td class="text-right">11.008,500</td>
# <td class="text-right">10.950,200</td>
# <td class="text-right">10.965,300</td>
# </tr>
# <tr>
# <td class="text-left">27-mar-24</td>
# <td class="text-right">11.111,300</td>
# <td class="text-right"><span class="cgreen">1,09%</span></td>
# <td class="text-right">11.140,100</td>
# <td class="text-right">11.000,800</td>
# <td class="text-right">11.007,500</td>
# </tr>
# <tr>
# <td class="text-left">28-mar-24</td>
# <td class="text-right">11.074,600</td>
# <td class="text-right"><span class="dred">-0,33%</span></td>
# <td class="text-right">11.105,600</td>
# <td class="text-right">11.057,400</td>
# <td class="text-right">11.075,700</td>
# </tr>
# <tr>
# <td class="text-left">02-abr-24</td>
# <td class="text-right">10.975,600</td>
# <td class="text-right"><span class="dred">-0,89%</span></td>
# <td class="text-right">11.095,500</td>
# <td class="text-right">10.953,900</td>
# <td class="text-right">11.034,600</td>
# </tr>
# <tr>
# <td class="text-left">03-abr-24</td>
# <td class="text-right">11.032,300</td>
# <td class="text-right"><span class="cgreen">0,52%</span></td>
# <td class="text-right">11.052,800</td>
# <td class="text-right">10.959,400</td>
# <td class="text-right">10.981,100</td>
# </tr>
# <tr>
# <td class="text-left">04-abr-24</td>
# <td class="text-right">11.090,900</td>
# <td class="text-right"><span class="cgreen">0,53%</span></td>
# <td class="text-right">11.111,200</td>
# <td class="text-right">11.042,000</td>
# <td class="text-right">11.049,500</td>
# </tr>
# <tr>
# <td class="text-left">05-abr-24</td>
# <td class="text-right">10.916,000</td>
# <td class="text-right"><span class="dred">-1,58%</span></td>
# <td class="text-right">11.000,200</td>
# <td class="text-right">10.879,900</td>
# <td class="text-right">10.967,400</td>
# </tr>
# <tr>
# <td class="text-left">08-abr-24</td>
# <td class="text-right">10.911,800</td>
# <td class="text-right"><span class="dred">-0,04%</span></td>
# <td class="text-right">10.932,300</td>
# <td class="text-right">10.846,000</td>
# <td class="text-right">10.864,200</td>
# </tr>
# <tr>
# <td class="text-left">09-abr-24</td>
# <td class="text-right">10.816,000</td>
# <td class="text-right"><span class="dred">-0,88%</span></td>
# <td class="text-right">10.909,100</td>
# <td class="text-right">10.809,500</td>
# <td class="text-right">10.909,100</td>
# </tr>
# <tr>
# <td class="text-left">10-abr-24</td>
# <td class="text-right">10.775,000</td>
# <td class="text-right"><span class="dred">-0,38%</span></td>
# <td class="text-right">10.879,200</td>
# <td class="text-right">10.697,400</td>
# <td class="text-right">10.863,300</td>
# </tr>
# <tr>
# <td class="text-left">11-abr-24</td>
# <td class="text-right">10.649,800</td>
# <td class="text-right"><span class="dred">-1,16%</span></td>
# <td class="text-right">10.782,600</td>
# <td class="text-right">10.591,400</td>
# <td class="text-right">10.761,000</td>
# </tr>
# <tr>
# <td class="text-left">12-abr-24</td>
# <td class="text-right">10.686,000</td>
# <td class="text-right"><span class="cgreen">0,34%</span></td>
# <td class="text-right">10.781,600</td>
# <td class="text-right">10.660,700</td>
# <td class="text-right">10.707,700</td>
# </tr>
# <tr>
# <td class="text-left">15-abr-24</td>
# <td class="text-right">10.687,200</td>
# <td class="text-right"><span class="cgreen">0,01%</span></td>
# <td class="text-right">10.750,200</td>
# <td class="text-right">10.660,200</td>
# <td class="text-right">10.668,700</td>
# </tr>
# <tr>
# <td class="text-left">16-abr-24</td>
# <td class="text-right">10.526,900</td>
# <td class="text-right"><span class="dred">-1,50%</span></td>
# <td class="text-right">10.605,500</td>
# <td class="text-right">10.499,200</td>
# <td class="text-right">10.575,800</td>
# </tr>
# <tr>
# <td class="text-left">17-abr-24</td>
# <td class="text-right">10.633,900</td>
# <td class="text-right"><span class="cgreen">1,02%</span></td>
# <td class="text-right">10.704,200</td>
# <td class="text-right">10.530,000</td>
# <td class="text-right">10.532,000</td>
# </tr>
# <tr>
# <td class="text-left">18-abr-24</td>
# <td class="text-right">10.765,000</td>
# <td class="text-right"><span class="cgreen">1,23%</span></td>
# <td class="text-right">10.776,300</td>
# <td class="text-right">10.686,200</td>
# <td class="text-right">10.694,900</td>
# </tr>
# <tr>
# <td class="text-left">19-abr-24</td>
# <td class="text-right">10.729,500</td>
# <td class="text-right"><span class="dred">-0,33%</span></td>
# <td class="text-right">10.747,100</td>
# <td class="text-right">10.611,900</td>
# <td class="text-right">10.680,100</td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# **Cuando estamos trabajando con tablas, es importante tener claro cual es la sintaxis de los distintos elementos HTML que componen la tabla, aquí os dejamos un resumen**:
#
# En HTML, los elementos . Aquí hay algunos elementos relacionados con `<tr>` que se utilizan comúnmente:
#
# 1. `<table>`: Este elemento se utiliza para crear una tabla en HTML y envuelve todas las filas y columnas de la tabla.
#
# 2. `<tr>`: Se utilizan para definir filas dentro de una tabla. Estos elementos hacen referencia a las filas de la tabla y deben estar ubicados dentro del elemento `<table>`
#
# 3. `<td>`: Representa una celda de datos en una tabla. Los elementos `<td>` deben estar ubicados dentro de un elemento `<tr>` para crear una celda en una fila.
#
# 4. `<th>`: Representa una celda de encabezado en una tabla. Al igual que `<td>`, los elementos `<th>` también deben estar ubicados dentro de un elemento `<tr>`, pero se utilizan para resaltar los encabezados de columna o fila.

# %%
# La tabla que nos interesa es la última por lo que vamos a crear una nueva variable donde almacenemos los resultados de la tabla que nos interesa
nuestra_tabla = tablas[2]

# lo primero que nos va a interesar es extraer los encabezados de la tabla, teniendo en cuenta las definiciones que hemos visto antes, 
# seleccionaremos la etiqueta "th" usando el método "th"
lista_ecabezados = nuestra_tabla.find_all("th")

print("La lista que nos devuelve el metodo '.find_all()' es:\n", lista_ecabezados)

# como hemos estado haciendo hasta ahora, tendremos que iterar por la lista obtenida en el paso anterior y extraer el texto de cada elemento
encabezados_ibex = [columna.text for columna in lista_ecabezados]

print("\n-------------------------\n")
print("Los encabezados de la tabla son:", encabezados_ibex)
# Out:
# La lista que nos devuelve el metodo '.find_all()' es:
#  [<th class="text-left" v-table-sorter-by="'date'">Fecha<span></span></th>, <th class="text-right" v-table-sorter-by="'price'">Precio<span></span></th>, <th class="text-right" v-table-sorter-by="'fallers'">Variación %<span></span></th>, <th class="text-right" v-table-sorter-by="'high'">Máximo<span></span></th>, <th class="text-right" v-table-sorter-by="'low'">Mínimo<span></span></th>, <th class="text-right" v-table-sorter-by="'open'">Apertura<span></span></th>]
#
# -------------------------
#
# Los encabezados de la tabla son: ['Fecha', 'Precio', 'Variación %', 'Máximo', 'Mínimo', 'Apertura']

# %% [markdown]
# Vale ... hasta ahora hemos conseguido sacar los encabezados, ahora nos toca sacar la información de las filas, que como hemos dicho antes, tendremos que usar la etiqueta `tr`. Pongamonos manos a la obra:

# %%
# sacamos todas las filas de la variable que nos hemos creado previamente (nuestra tabla), usando el método .find_all()
filas_ibex = nuestra_tabla.find_all("tr")

print("La cantidad de filas que hemos extraido de la tabla es:", len(filas_ibex))

print("\n----------------------\n")
print("El contenido que tenemos en la primera fila es:\n", filas_ibex[0] )

print("\n----------------------\n")
print("El contenido que tenemos en la segunda fila es:\n", filas_ibex[1] )
# Out:
# La cantidad de filas que hemos extraido de la tabla es: 19
#
# ----------------------
#
# El contenido que tenemos en la primera fila es:
#  <tr>
# <th class="text-left" v-table-sorter-by="'date'">Fecha<span></span></th>
# <th class="text-right" v-table-sorter-by="'price'">Precio<span></span></th>
# <th class="text-right" v-table-sorter-by="'fallers'">Variación %<span></span></th>
# <th class="text-right" v-table-sorter-by="'high'">Máximo<span></span></th>
# <th class="text-right" v-table-sorter-by="'low'">Mínimo<span></span></th>
# <th class="text-right" v-table-sorter-by="'open'">Apertura<span></span></th>
# </tr>
#
# ----------------------
#
# El contenido que tenemos en la segunda fila es:
#  <tr>
# <td class="text-left">25-mar-24</td>
# <td class="text-right">10.952,200</td>
# <td class="text-right"><span class="cgreen">0,08%</span></td>
# <td class="text-right">10.986,000</td>
# <td class="text-right">10.911,500</td>
# <td class="text-right">10.918,000</td>
# </tr>

# %% [markdown]
# Si nos fijamos el primer elemento de la lista de las filas nos esta dando la información de los encabezados, pero a partir del segundo elemento tenemos todos los valores de la tabla que queremos. Como hasta ahora tendremos que iterar por toda la lista y sacar el texto, pero en este caso empezaremos a interar desde el elemento que esté en segunda posición ya que los encabezados los hemos sacado en el paso anterior.

# %%
# Creamos una lista llamada 'resultados_ibex' para almacenar los resultados obtenidos.
resultados_ibex = []

# Iniciamos un bucle 'for' para iterar a través de la lista 'filas_ibex', pero comenzamos desde el segundo elemento de la lista.
for fila in filas_ibex[1:]:
    # Para cada 'fila', extraemos el texto, lo dividimos en una lista usando '\n' como separador y eliminamos el primer y último elemento de la lista.
    fila_texto = fila.text
    elementos_fila = fila_texto.split("\n")[1:-1]

    # Añadimos la lista de elementos a la lista 'resultados_ibex'.
    resultados_ibex.append(elementos_fila)

# Imprimimos los resultados obtenidos después de iterar por la lista.
print("Los resultados de iterar por la lista son:\n", resultados_ibex)
# Out:
# Los resultados de iterar por la lista son:
#  [['25-mar-24', '10.952,200', '0,08%', '10.986,000', '10.911,500', '10.918,000'], ['26-mar-24', '10.991,500', '0,36%', '11.008,500', '10.950,200', '10.965,300'], ['27-mar-24', '11.111,300', '1,09%', '11.140,100', '11.000,800', '11.007,500'], ['28-mar-24', '11.074,600', '-0,33%', '11.105,600', '11.057,400', '11.075,700'], ['02-abr-24', '10.975,600', '-0,89%', '11.095,500', '10.953,900', '11.034,600'], ['03-abr-24', '11.032,300', '0,52%', '11.052,800', '10.959,400', '10.981,100'], ['04-abr-24', '11.090,900', '0,53%', '11.111,200', '11.042,000', '11.049,500'], ['05-abr-24', '10.916,000', '-1,58%', '11.000,200', '10.879,900', '10.967,400'], ['08-abr-24', '10.911,800', '-0,04%', '10.932,300', '10.846,000', '10.864,200'], ['09-abr-24', '10.816,000', '-0,88%', '10.909,100', '10.809,500', '10.909,100'], ['10-abr-24', '10.775,000', '-0,38%', '10.879,200', '10.697,400', '10.863,300'], ['11-abr-24', '10.649,800', '-1,16%', '10.782,600', '10.591,400', '10.761,000'], ['12-abr-24', '10.686,000', '0,34%', '10.781,600', '10.660,700', '10.707,700'], ['15-abr-24', '10.687,200', '0,01%', '10.750,200', '10.660,200', '10.668,700'], ['16-abr-24', '10.526,900', '-1,50%', '10.605,500', '10.499,200', '10.575,800'], ['17-abr-24', '10.633,900', '1,02%', '10.704,200', '10.530,000', '10.532,000'], ['18-abr-24', '10.765,000', '1,23%', '10.776,300', '10.686,200', '10.694,900'], ['19-abr-24', '10.729,500', '-0,33%', '10.747,100', '10.611,900', '10.680,100']]

# %% [markdown]
# Si nos fijamos, al igual que en el ejemplo anterior tenemos los números como *strings*, por lo que lo vamos a cambiar para tener los formatos corretos:
#
# - En concreto cambiaremos las "," por "."
#
# - Quitaremos los % que tenemos en algunos de los valores.

# %%
# Iteramos a través de cada lista en 'resultados_ibex' y sus elementos usando 'enumerate'.
for indice_lista, lista in enumerate(resultados_ibex):
    for indice_elemento, elemento in enumerate(lista):
        try:
            # Intentamos convertir cada elemento de la lista en un número de punto flotante.
            # Para ello, eliminamos caracteres especiales como '%' y reformateamos la puntuación.
            resultados_ibex[indice_lista][indice_elemento] = float(elemento.replace("%", "").replace(".", "").replace(",", "."))
        except:
            # Si se produce una excepción (por ejemplo, si el elemento no es convertible a flotante), 
            # mantenemos el elemento original en la lista.
            resultados_ibex[indice_lista][indice_elemento] = elemento
            
# Imprimimos los resultados después de limpiar los datos.
print("Los resultados después de limpiar los datos son: \n", resultados_ibex)
# Out:
# Los resultados después de limpiar los datos son:
#  [['25-mar-24', 10952.2, 0.08, 10986.0, 10911.5, 10918.0], ['26-mar-24', 10991.5, 0.36, 11008.5, 10950.2, 10965.3], ['27-mar-24', 11111.3, 1.09, 11140.1, 11000.8, 11007.5], ['28-mar-24', 11074.6, -0.33, 11105.6, 11057.4, 11075.7], ['02-abr-24', 10975.6, -0.89, 11095.5, 10953.9, 11034.6], ['03-abr-24', 11032.3, 0.52, 11052.8, 10959.4, 10981.1], ['04-abr-24', 11090.9, 0.53, 11111.2, 11042.0, 11049.5], ['05-abr-24', 10916.0, -1.58, 11000.2, 10879.9, 10967.4], ['08-abr-24', 10911.8, -0.04, 10932.3, 10846.0, 10864.2], ['09-abr-24', 10816.0, -0.88, 10909.1, 10809.5, 10909.1], ['10-abr-24', 10775.0, -0.38, 10879.2, 10697.4, 10863.3], ['11-abr-24', 10649.8, -1.16, 10782.6, 10591.4, 10761.0], ['12-abr-24', 10686.0, 0.34, 10781.6, 10660.7, 10707.7], ['15-abr-24', 10687.2, 0.01, 10750.2, 10660.2, 10668.7], ['16-abr-24', 10526.9, -1.5, 10605.5, 10499.2, 10575.8], ['17-abr-24', 10633.9, 1.02, 10704.2, 10530.0, 10532.0], ['18-abr-24', 10765.0, 1.23, 10776.3, 10686.2, 10694.9], ['19-abr-24', 10729.5, -0.33, 10747.1, 10611.9, 10680.1]]

# %% [markdown]
# Igual que en el caso anterior, es el momento de crear una función con todo el código que hemos ido creando hasta ahora, para unificarlo todo.

# %%
def sacar_tabla_ibex(url):
    
    """
    Extrae datos de una tabla en una página web y devuelve los encabezados y los resultados de la tabla.

    Parameters:
    url (str): La URL de la página web de la que se extraerán los datos de la tabla.

    Returns:
    tuple: Una tupla que contiene dos elementos.
        - Una lista de encabezados de columna de la tabla.
        - Una lista de listas que representan los resultados de la tabla.
    """
    # al igual que en el ejemplo anterior lo primero que haremos será definir la url de la página de la vamos a sacar datos
    url_bolsa_ibex = "https://www.bolsamania.com/indice/IBEX-35/historico-precios"

    # hacemos la request a la página de la que queremos sacar la info
    res_bolsa_ibex = requests.get(url_bolsa_ibex)

    # vemos si todo ha ido bien
    print("La respuesta de la petición es:", res_bolsa_ibex.status_code)
    
    # creamos el objeto BeautifulSoup para poder acceder al contenido solicitado
    sopa_bolsa_historico = BeautifulSoup(res_bolsa_ibex.content, 'html.parser')
    
    # vamos a seguir usando el metodo ".find_all()", pero en este caso lo que buscaremos son todas las tablas que tenemos en la página web.
    tablas_historico = sopa_bolsa.find_all("table")
    
    # La tabla que nos interesa es la última por lo que vamos a crear una nueva variable donde almacenemos los resultados de la tabla que nos interesa
    nuestra_tabla_historico = tablas_historico[2]

    # lo primero que nos va a interesar es extraer los encabezados de la tabla, teniendo en cuenta las definiciones que hemos visto antes, 
    # seleccionaremos la etiqueta "th" usando el método "th"
    lista_ecabezados_historico = nuestra_tabla_historico.find_all("th")

    print("La lista que nos devuelve el metodo '.find_all()' es:\n", lista_ecabezados_historico)

    # como hemos estado haciendo hasta ahora, tendremos que iterar por la lista obtenida en el paso anterior y extraer el texto de cada elemento
    encabezados_ibex_historico = [columna.text for columna in lista_ecabezados_historico]
    
    # sacamos todas las filas de la variable que nos hemos creado previamente (nuestra tabla), usando el método .find_all()
    filas_ibex_historico = nuestra_tabla_historico.find_all("tr")
    
    # creamos una lista para almacenar todos los resultados obtenidos de la lista de  "filas_ibex"
    resultados_ibex_historico = []

    # empezamos a iterar por la lista, pero fijaos que en este caso empezamos desde el segundo elemento de la lista
    for fila in filas_ibex_historico[1:]:
        # añadimos cada elemento a la lista que hemos creado previamente. 
        resultados_ibex_historico.append(fila.text.split("\n")[1:-1])
        
    resultados_ibex_limpio_historico = []
    for indice_lista, lista in enumerate(resultados_ibex_historico):
        for indice_elemento, elemento in enumerate(lista):
            try:
                resultados_ibex_historico[indice_lista][indice_elemento] = float(elemento.replace("%", "").replace(".", "").replace(",", "."))
            except:
                resultados_ibex_historico[indice_lista][indice_elemento]  = elemento
                
    return encabezados_ibex_historico, resultados_ibex_historico

# %%
encabezados_ibex_final, datos_ibex_final = sacar_tabla_ibex(url_bolsa)
# Out:
# La respuesta de la petición es: 200
# La lista que nos devuelve el metodo '.find_all()' es:
#  [<th class="text-left" v-table-sorter-by="'date'">Fecha<span></span></th>, <th class="text-right" v-table-sorter-by="'price'">Precio<span></span></th>, <th class="text-right" v-table-sorter-by="'fallers'">Variación %<span></span></th>, <th class="text-right" v-table-sorter-by="'high'">Máximo<span></span></th>, <th class="text-right" v-table-sorter-by="'low'">Mínimo<span></span></th>, <th class="text-right" v-table-sorter-by="'open'">Apertura<span></span></th>]

# %% [markdown]
# Si nos fijamos ahora, lo que tenemos es una lista de listas. Lo siguiente que querremos hacer en convertirlo en tabla (*DataFrame*) con Pandas como hicimos antes con el ejemplo ed Ebay. Pero antes teníamos un diccionario, ¿podremos convertir esta lista de listas a *DataFrame*? La respuesta es sí, de la misma forma que lo hicimos antes, usando el método de Pandas `pd.DataFrame`. Resumiendo, podremos convertir a *DataFrame*:
#
# - Un diccionario
#
# - Una lista de listas

# %%
# convertimos la lista de listas a DataFrame usando el método 'pd.DataFrame()'. 
df_ibex = pd.DataFrame(datos_ibex_final)

# mostramos las 5 primeras filas del DataFrame
# pero si nos fijamos ahora, los nombres de nuestras columnas son números y no los nombres de los encabezados que sacamos de la tabla de la página web
display("Mostramos las 5 primeras filas del DataFrame",df_ibex.head())
print("-------------------------")
# para poder poner nombre a las columnas en Pandas tenemos varios métodos, pero uno de los más comunes es el método '.columns' 
# en este caso le estamos diciendo que las columnas de nuestro DataFrane queremos que correspondan con los valores de la listas de encabezados_index que creamos al inicio
df_ibex.columns = encabezados_ibex_final


# Mostramos las dos primeras filas del DataFrame
# ahora vemos que las columnas ya no son números, si no los encabezamos que sacamos al inicio
display("Mostramos las 2 primeras filas del DataFrame", df_ibex.head(2))
print("-------------------------")

# el número de filas y columnas del DataFrame son
print("El número de filas y columnas es:", df_ibex.shape)
# Out:
# 'Mostramos las 5 primeras filas del DataFrame'
#            0        1     2        3        4        5
# 0  25-mar-24  10952.2  0.08  10986.0  10911.5  10918.0
# 1  26-mar-24  10991.5  0.36  11008.5  10950.2  10965.3
# 2  27-mar-24  11111.3  1.09  11140.1  11000.8  11007.5
# 3  28-mar-24  11074.6 -0.33  11105.6  11057.4  11075.7
# 4  02-abr-24  10975.6 -0.89  11095.5  10953.9  11034.6
# -------------------------
# 'Mostramos las 2 primeras filas del DataFrame'
#        Fecha   Precio  Variación %   Máximo   Mínimo  Apertura
# 0  25-mar-24  10952.2         0.08  10986.0  10911.5   10918.0
# 1  26-mar-24  10991.5         0.36  11008.5  10950.2   10965.3
# -------------------------
# El número de filas y columnas es: (18, 6)

# %%
# si recordamos teníamos el método '.dtypes' nos permitía saber cuales eran los tipos de los datos de las distintas columnas que tenemos en el DataFrame
df_ibex.dtypes
# Out:
# Fecha           object
# Precio         float64
# Variación %    float64
# Máximo         float64
# Mínimo         float64
# Apertura       float64
# dtype: object

# %%
# sigamos conociendo algunos métodos nuevos, en este caso sacaremos los valores únicos que tenemos en algunas de las columnas
# para eso usaremos el método '.unique()'. Lo que nos va a mostrar esto son las fechas diferentes que tenemos en la columna de Fecha 
print("Los valores únicos que tenemos en la columna de Fecha son:\n", df_ibex["Fecha"].unique())

print("Los valores únicos que tenemos en la columna de Fecha son:\n", df_ibex["Máximo"].unique())
# Out:
# Los valores únicos que tenemos en la columna de Fecha son:
#  ['25-mar-24' '26-mar-24' '27-mar-24' '28-mar-24' '02-abr-24' '03-abr-24'
#  '04-abr-24' '05-abr-24' '08-abr-24' '09-abr-24' '10-abr-24' '11-abr-24'
#  '12-abr-24' '15-abr-24' '16-abr-24' '17-abr-24' '18-abr-24' '19-abr-24']
# Los valores únicos que tenemos en la columna de Fecha son:
#  [10986.  11008.5 11140.1 11105.6 11095.5 11052.8 11111.2 11000.2 10932.3
#  10909.1 10879.2 10782.6 10781.6 10750.2 10605.5 10704.2 10776.3 10747.1]

# %%
# otro de los métodos que más usaremos es el método '.value_counts()' 
# este método lo que va a hacer es contar cuántas veces aparecen cada una de los valores únicos que tenemos en esa columna
# en este caso lo que vemos es que cada una de las fechas que tenemos en la columna aparecen solo una vez. 
df_ibex["Fecha"].value_counts()
# Out:
# 25-mar-24    1
# 26-mar-24    1
# 18-abr-24    1
# 17-abr-24    1
# 16-abr-24    1
# 15-abr-24    1
# 12-abr-24    1
# 11-abr-24    1
# 10-abr-24    1
# 09-abr-24    1
# 08-abr-24    1
# 05-abr-24    1
# 04-abr-24    1
# 03-abr-24    1
# 02-abr-24    1
# 28-mar-24    1
# 27-mar-24    1
# 19-abr-24    1
# Name: Fecha, dtype: int64

# %%
# de la misma forma que le hemos preguntado antes a Pandas cuántos valores nulos tenemos por columnas, 
# también le podemos preguntar cuántos valores no nulos tenemos en cada una de ellas usando el método 'notnull()'
df_ibex.notnull().sum()
# Out:
# Fecha          18
# Precio         18
# Variación %    18
# Máximo         18
# Mínimo         18
# Apertura       18
# dtype: int64

# %%
# por último, nos puede interesar guardar estos datos en un csv en nuestro ordenador para utilizarla en otro momento
# para esto tendremos que usar el método "pd.to_csv()"

df_ibex.to_csv("datos_ibex.csv")

# %% [markdown]
# # Resumen de los métodos aprendidos de Pandas
#
# Pandas es una poderosa herramienta para el análisis y manipulación de datos. Aquí os dejamos un resumen de los métodos de Pandas que hemos aprendido durante la lección:
#
# 1. **head() y tail()**: Estos métodos se utilizan para mostrar las primeras filas o las últimas filas de un DataFrame. Son útiles para obtener una vista previa rápida de los datos.
#    ```python
#    # Mostrar las primeras 5 filas del DataFrame
#    df.head()
#
#    # Mostrar las últimas 5 filas del DataFrame
#    df.tail()
#    ```
#
# 2. **info()**: El método `info()` muestra un resumen conciso de un DataFrame, incluyendo el tipo de datos de cada columna y la cantidad de valores no nulos. Es útil para comprender la estructura de tus datos.
#    ```python
#    # Mostrar información resumida del DataFrame
#    df.info()
#    ```
#
# 3. **describe()**: El método `describe()` genera estadísticas descriptivas de las columnas numéricas de un DataFrame, como la cuenta, media, desviación estándar, mínimo, máximo y percentiles. Proporciona información útil sobre la distribución de los datos.
#    ```python
#    # Mostrar estadísticas descriptivas del DataFrame
#    df.describe()
#    ```
#
# 4. **shape**: El atributo `shape` devuelve una tupla que representa las dimensiones del DataFrame, es decir, el número de filas y columnas.
#    ```python
#    # Obtener las dimensiones del DataFrame
#    df.shape
#    ```
#
# 5. **columns**: El atributo `columns` devuelve una lista de las columnas del DataFrame.
#    ```python
#    # Obtener la lista de columnas del DataFrame
#    df.columns
#    ```
#
# 6. **value_counts()**: El método `value_counts()` cuenta los valores únicos en una columna y los muestra en orden descendente. Es útil para realizar un recuento de categorías o valores específicos en una columna.
#    ```python
#    # Contar los valores únicos en una columna
#    df['columna'].value_counts()
#    ```
#
# 7. **unique()**: El método `unique()` devuelve una lista de los valores únicos en una columna. Es útil para obtener una lista de categorías o valores distintos.
#    ```python
#    # Obtener los valores únicos en una columna
#    df['columna'].unique()
#    ```
#
# 8. **isnull() y notnull()**: Estos métodos se utilizan para verificar la presencia de valores nulos en un DataFrame. Devuelven una máscara booleana que indica si cada valor es nulo o no nulo.
#    ```python
#    # Verificar valores nulos en el DataFrame
#    df.isnull()
#
#    # Verificar valores no nulos en el DataFrame
#    df.notnull()
#    ```

# %% [markdown]
# # Ejercicios
#
# 1. Usa la [siguiente](https://es.wikipedia.org/wiki/Anexo:Medallero_de_los_Juegos_Ol%C3%ADmpicos_de_Tokio_2020) página web.
#
# 2. Extrae la tabla de las medallas olímpicas que tenéis en la página web.
#
# 3. Mete todo el código de la extracción de datos en una función.
#
# 4. Los resultados deben estar en un *DataFrame* y hacer una exploración básica con los métodos aprendidos en la lección.

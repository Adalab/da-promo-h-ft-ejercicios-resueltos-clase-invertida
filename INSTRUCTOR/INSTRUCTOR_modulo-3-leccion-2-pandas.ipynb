# %%
# importando librerias
import pandas as pd

pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %% [markdown]
# # series

# %%
# creando una serie vacia con pd.Series()
serie = pd.Series()
serie
# Out:
# C:\Users\Ignacio\AppData\Local\Temp\ipykernel_12040\4113019959.py:2: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   serie = pd.Series()
# Series([], dtype: float64)

# %%
lista = [10,23,54,98,63]

# %%
serie = pd.Series(lista)
serie
# Out:
# 0    10
# 1    23
# 2    54
# 3    98
# 4    63
# dtype: int64

# %%
serie = pd.Series(lista, index = [10.5,11.5,12.5,13.5,14.5])
serie
# Out:
# 10.5    10
# 11.5    23
# 12.5    54
# 13.5    98
# 14.5    63
# dtype: int64

# %%
data_diccionario = {
    'Marca': ['Renault', 'Mazda', 'Nissan', 'Ferrari'],
    'Preco': [5000, 3000, 2800, 00000],
    'Origen': ['Francia', 'Japon', 'Corea', 'Italia']
}

# %%
autos = pd.Series(data_diccionario)

# %%
autos
# Out:
# Marca     [Renault, Mazda, Nissan, Ferrari]
# Preco                 [5000, 3000, 2800, 0]
# Origen      [Francia, Japon, Corea, Italia]
# dtype: object

# %%
# agregando una lista  o diccionario a mi serie

# %%
# podemos cambiar el indice de nuestra serie?

# %%
# indexando nuestra serie

serie = pd.Series(lista, index = [10,11,12,13,14])
serie
# Out:
# 10    10
# 11    23
# 12    54
# 13    98
# 14    63
# dtype: int64

# %%
# quiero 10, 54 y 63

serie[::2]
# Out:
# 10    10
# 12    54
# 14    63
# dtype: int64

# %%
serie[2:4]
# Out:
# 12    54
# 13    98
# dtype: int64

# %%
serie[12]
# Out:
# 54

# %%
# values, index, dtype, size, shape

print(serie.values)
# Out:
# [10 23 54 98 63]

# %%
print(serie.index)
# Out:
# Int64Index([10, 11, 12, 13, 14], dtype='int64')

# %%
print(serie.dtype)
# Out:
# int64

# %%
print(serie.size)
# Out:
# 5

# %%
print(serie.shape)
# Out:
# (5,)

# %%
# indexacion con series

# %% [markdown]
# ## Abriendo archivos

# %%
# pd.read_csv
# pd.read_excel
# pd.read_json
# pd.read_pickle

# %%
aire = pd.read_csv("aire.csv",sep=";")

# %%
aire.to_csv("aire.csv",index=False)

# %%
silvia = pd.read_csv("silvia.csv")

# %%
silvia
# Out:
#      provincia  municipio  estacion  magnitud  punto_muestreo   ano  mes  dia  \
# 0           28        102         1         1   28102001_1_38  2022    1   30
# 1           28        102         1         6   28102001_6_48  2022    1   30
# 2           28        102         1         7    28102001_7_8  2022    1   30
# 3           28        102         1         8    28102001_8_8  2022    1   30
# 4           28        102         1        10  28102001_10_49  2022    1   30
# ..         ...        ...       ...       ...             ...   ...  ...  ...
# 155         28         92         5         7    28092005_7_8  2022    1   30
# 156         28         92         5         8    28092005_8_8  2022    1   30
# 157         28         92         5        10  28092005_10_49  2022    1   30
# 158         28         92         5        12   28092005_12_8  2022    1   30
# 159         28         92         5        14   28092005_14_6  2022    1   30
#
# ...

# %%
pd.read_csv?
# Out:
# Signature:
# pd.read_csv(
#     filepath_or_buffer: 'FilePathOrBuffer',
#     sep=<no_default>,
#     delimiter=None,
#     header='infer',
#     names=<no_default>,
#     index_col=None,
#     usecols=None,
#     squeeze=False,
#     prefix=<no_default>,
#     mangle_dupe_cols=True,
#     dtype: 'DtypeArg | None' = None,
#     engine=None,
#     converters=None,
#     true_values=None,
#     false_values=None,
#     skipinitialspace=False,
#     skiprows=None,
#     skipfooter=0,
#     nrows=None,
#     na_values=None,
#     keep_default_na=True,
#     na_filter=True,
#     verbose=False,
#     skip_blank_lines=True,
#     parse_dates=False,
#     infer_datetime_format=False,
#     keep_date_col=False,
#     date_parser=None,
#     dayfirst=False,
#     cache_dates=True,
#     iterator=False,
#     chunksize=None,
#     compression='infer',
#     thousands=None,
#     decimal: 'str' = '.',
#     lineterminator=None,
#     quotechar='"',
#     quoting=0,
#     doublequote=True,
# ...

# %% [markdown]
# # indexando loc y iloc

# %%
# primero traigamos el archivo titanic...

df = pd.read_csv("titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# loc y iloc ...diferencias?

#loc: a traves de etiquetas

#iloc: a traves de numeros (posiciones)

# %%
# usando una condicion de filtro con loc y iloc
# todos los registros de personas de mas de 35 años

may_35 = df[df["Age"]>35]
# creen una coloumna

# %%
may_35
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 6              7         0       1
# 11            12         1       1
# 13            14         0       3
# 15            16         1       2
# ..           ...       ...     ...
# 865          866         1       2
# 871          872         1       1
# 873          874         0       3
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# delimito por edad
# saco solamente mujeres
# quiero los de "Fare"<50

# %% [markdown]
# # creando columnas

# %%
may_35.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# creacion normal, assign e insert
# precio = Fare / Pclass

df["precio"] = df["Fare"]/df["Pclass"]
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["precio"] = df["Fare"]/df["Pclass"]

# %%
nuevo = df.assign(precio_assign=(df["Fare"]/df["Pclass"]))

# %%
nuevo
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
nuevo["precio"] = nuevo["Name"]

# %%
nuevo.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  \
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
#
# ...

# %%
# quiero insertar una columna que se llame "numeros", en la posicion 2 de mi dataframe que contenga valores correlativos.

nuevo.insert(2,"numeros",range(0,len(nuevo)),allow_duplicates=True)

# %%
nuevo.head()
# Out:
#    PassengerId  Survived  numeros  numeros  Pclass  \
# 0            1         0        0      891       3
# 1            2         1        1      891       1
# 2            3         1        2      891       3
# 3            4         1        3      891       1
# 4            5         0        4      891       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  \
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
limpio = nuevo.drop(["precio","precio_assign"],axis=1)

# %%
muy_limpio = limpio.drop(["Pclass","Age"],axis=1)

# %%
muy_limpio
# Out:
#      PassengerId  Survived  numeros  numeros  \
# 0              1         0        0      891
# 1              2         1        1      891
# 2              3         1        2      891
# 3              4         1        3      891
# 4              5         0        4      891
# ..           ...       ...      ...      ...
# 886          887         0      886      891
# 887          888         1      887      891
# 888          889         0      888      891
# 889          890         1      889      891
# 890          891         0      890      891
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# ...

# %%
nuevo.drop?
# Out:
# Signature:
# nuevo.drop(
#     labels=None,
#     axis: 'Axis' = 0,
#     index=None,
#     columns=None,
#     level: 'Level | None' = None,
#     inplace: 'bool' = False,
#     errors: 'str' = 'raise',
# )
# Docstring:
# Drop specified labels from rows or columns.
#
# Remove rows or columns by specifying label names and corresponding
# axis, or by specifying directly index or column names. When using a
# multi-index, labels on different levels can be removed by specifying
# the level. See the `user guide <advanced.shown_levels>`
# for more information about the now unused levels.
#
# Parameters
# ----------
# labels : single label or list-like
#     Index or column labels to drop.
# axis : {0 or 'index', 1 or 'columns'}, default 0
#     Whether to drop labels from the index (0 or 'index') or
#     columns (1 or 'columns').
# index : single label or list-like
#     Alternative to specifying axis (``labels, axis=0``
#     is equivalent to ``index=labels``).
# ...
